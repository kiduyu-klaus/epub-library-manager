# %%
import csv
import logging
import os
import random
import re
import time
import urllib.parse
import urllib.request
from pathlib import Path
from urllib.parse import urlparse
from googlesearch import search
import bs4  # Optional: if you use `bs4.BeautifulSoup` instead of `from bs4 import BeautifulSoup`
import requests
from bs4 import BeautifulSoup
# Constants
GOODREADS_URL = 'https://www.goodreads.com'
import random
# List of user agents for rotation
LIST_OF_USER_AGENTS = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
    'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)'
]

import zipfile
from lxml import etree

from ebooklib import epub  # EPUB file manipulation library
import google.generativeai as genai
import csv

#import pandas as pd
Gemini_key = 'AIzaSyCASKQRxoOKw3ZLgGIdEQHUc2d-E0EXUHQ'
import pprint
import shutil
from bingsearch.bingsearch import BingSearch
import mysql.connector

# %%
# Configure Gemini AI with the API key from the environment variable
genai.configure(api_key=Gemini_key)

# Create the model configuration
generation_config = {
    "temperature": 0.7,  # Lower temperature for deterministic responses
    "top_p": 0.95,  # Use nucleus sampling
    "top_k": 40,  # Consider top-k tokens
    "max_output_tokens": 512,  # Limit response length
    "response_mime_type": "text/plain",  # Expect text response
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-2.0-flash-exp",  # Use the appropriate model name
    generation_config=generation_config,
)

genre_chat_session = model.start_chat(history=[])

def get_goodreads_title(book_title, author_name):
    """
    Passes a book title and author to Gemini AI to get the Goodreads official book link.

    Args:
        book_title (str): The title of the book.
        author_name (str): The name of the author.

    Returns:
        str: The Goodreads official book link or an error message.
    """
    # Start a new chat session
    chat_session = model.start_chat(history=[])

    # Construct the input prompt
    prompt = (
        f"Find the official Goodreads title for the book titled '{book_title}' "
        f"written by the author '{author_name}'. Return only the goodreads title."
    )

    # Send the message to the Gemini model
    response = chat_session.send_message(prompt)

    # Extract the text response
    response_text = response.text.strip()
    if response_text.strip().lower() == book_title.strip().lower():
        return None
    return response_text

def fix_ebook_title_with_gemini(unconfirmed_title: str, author_name: str) -> str | None:
    """
    Use Gemini AI to fix or verify an incorrect or approximate eBook title
    by matching it to the official Goodreads title, given the author.

    Args:
        unconfirmed_title (str): The guessed or unclean eBook title.
        author_name (str): The confirmed name of the author.

    Returns:
        str | None: The corrected official title if found, else None.
    """
    prompt = (
        f"this book called: '{unconfirmed_title}' "
        f"by the author '{author_name}' has an incorrect book title. Please return the correct official title "
        "of the book as it appears on Goodreads. Respond with only the exact title, no links or explanations. and make sure the book title is correct "
    )

    try:
        chat = model.start_chat()
        response = chat.send_message(prompt)
        result = response.text.strip()

        # Optionally avoid returning the same name if not corrected
        if result.lower() == unconfirmed_title.strip().lower():
            return None

        return result

    except Exception as e:
        print(f"[Gemini Error] Failed to fix title: {e}")
        return None
    
def get_author_name_with_gemini(unconfirmed_title: str) -> str | None:
    """
    Use Gemini AI to identify the official author of a book given only its title.

    Args:
        unconfirmed_title (str): The possibly incorrect or informal book title.

    Returns:
        str | None: The correct author's name if found, otherwise None.
    """
    prompt = (
        f"A book has the title '{unconfirmed_title}', but the author's name is unknown. "
        f"Please provide the full name of the primary author as listed on Goodreads. "
        "Respond with only the author's full name and nothing else."
    )

    try:
        chat = model.start_chat()
        response = chat.send_message(prompt)
        author_name = response.text.strip()

        # Basic validation
        if not author_name or len(author_name.split()) < 2:
            return None

        return author_name

    except Exception as e:
        print(f"[Gemini Error] Failed to get author: {e}")
        return None

def get_book_genre_with_gemini(ebook_title: str, author_name: str) -> str | None:
    """
    Use Gemini AI to determine the primary Goodreads genre of a book
    based on its title and author.

    Args:
        ebook_title (str): The title of the eBook.
        author_name (str): The name of the author.

    Returns:
        str | None: The most appropriate genre from Goodreads if found, else None.
    """
    prompt = (
        f"The book titled '{ebook_title}' by '{author_name}' is listed on Goodreads. "
        "Please return only the **primary** book genre as it appears on Goodreads "
        "(e.g., Fiction, Romance, Historical Fiction, Thriller, Fantasy, Non-Fiction, etc.). "
        "Do not include explanations, quotes, links, or multiple genres—respond with one genre only."
    )

    try:
        response = genre_chat_session.send_message(prompt)
        genre = response.text.strip()

        # Optional sanity check: ensure single-word or hyphenated genre
        if not genre or len(genre.split()) > 3:
            return None

        return genre

    except Exception as e:
        #print(f"[Gemini Error] Failed to get genre: {e}")
        return None

# %%
genre = get_book_genre_with_gemini("The Night Circus", "Erin Morgenstern")
print("Primary genre:", genre)

# %%
genre

# %%
book_title = "BreakingthePlayboysCurse"
author = get_author_name_with_gemini(book_title)
print("Author:", author)

# %%
corrected_title = fix_ebook_title_with_gemini("Casacelli Brides Four powerful", "Clare Connelly")
print("Corrected Title:", corrected_title)

# %% [markdown]
# ## 📘 Overview of Extracted Functions
#
# This part contains all the helper functions required by the `scrape_book` function, which scrapes detailed book information from a Goodreads book page. Below is a summary of each extracted function:
#
# ---
#
# ### 🔍 `scrape_book(book_url, book_url_local, random_header)`
# Main function that scrapes metadata from a Goodreads book page using the provided URL and request headers.
#
# Returns a dictionary with:
# - Book ID, title, description, category and subcategory IDs
# - Author ID, cover image, ratings, and local file reference
#
# ---
#
# ### 🏷️ `get_genre_list(soup)`
# Parses the Goodreads HTML page to extract the book's listed genres and returns them as a comma-separated string.
#
# ---
#
# ### 📂 `process_subcategories(sub_cat_id_string, csv_file='subcategories.csv')`
# Converts the genre string into internal category (`cat_id`) and subcategory (`sid`) IDs by matching against a CSV file. Falls back to default values if none found.
#
# ---
#
# ### 🆔 `get_id(bookid)`
# Extracts the numeric portion of the Goodreads book ID from its URL or slug.
#
# ---
#
# ### 🧑‍💻 `get_author_id(soup)`
# Finds and returns the Goodreads author ID by parsing the contributor link in the book page HTML.
#
# ---
#
# ### 📝 `get_book_description(soup)`
# Retrieves the book's description text from the Goodreads page. Returns a default message if none is found.
#
# ---
#
# ### 🖼️ `get_book_cover(soup)`
# Extracts the book's cover image URL. If no image is found, returns a placeholder image URL.
#
# ---
#
# ### 📇 `get_sub_category_id(sub_category_name, csv_file='subcategories.csv')`
# Helper for `process_subcategories` that looks up a single subcategory name in the CSV file and returns its associated IDs.
#
# ---
#
# These functions are modular and reusable across your scraping pipeline, and they are now grouped in a single file for maintainability and clarity.

# %%
def get_id(bookid):
    pattern = re.compile("([^.-]+)")
    bookdd = bookid.split('-')[0]
    bookdd = bookdd.split('.')[0]
    return bookdd

def get_genre_list(soup):
    genres = []
    genres_container = soup.find("div", {"data-testid": "genresList"})
    if genres_container:
        genre_links = genres_container.find("ul").find("span").find_all("a")
        for link in genre_links:
            genre = link.find("span").text
            genres.append(genre)
        return ', '.join(genres)
    return None


def get_sub_category_id(sub_category_name, csv_file='subcategories.csv'):
    sub_category_name = sub_category_name.strip().lower()
    try:
        with open(csv_file, mode='r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                if row['sub_category_name'].strip().lower() == sub_category_name.strip().lower():
                    return {
                        'sid': int(row['id']),  # Changed from 'sid' to 'id'
                        'cat_id': int(row['cat_id'])
                    }
        return None
    except FileNotFoundError:
        print(f"Error: The file {csv_file} does not exist.")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

def get_next_sid(csv_file='subcategories.csv'):
    """Get the next available id by finding the maximum existing id"""
    try:
        if not os.path.exists(csv_file):
            return 1
        
        with open(csv_file, mode='r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            max_id = 0
            for row in reader:
                if row['id'].isdigit():  # Changed from 'sid' to 'id'
                    max_id = max(max_id, int(row['id']))
            return max_id + 1
    except Exception as e:
        print(f"Error getting next id: {e}")
        return 1

def add_new_subcategory(sub_category_name, csv_file='subcategories.csv'):
    """Add a new subcategory to the CSV file and return its info"""
    try:
        next_id = get_next_sid(csv_file)
        
        # Create the image filename (same as subcategory name)
        sub_category_image = f"upload/{sub_category_name.lower()}.png"
        
        # Check if file exists, if not create with header
        file_exists = os.path.exists(csv_file) and os.path.getsize(csv_file) > 0
        
        with open(csv_file, mode='a', encoding='utf-8', newline='') as file:
            fieldnames = ['id', 'cat_id', 'sub_category_name', 'sub_category_image', 'status']
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            
            # Write header if file doesn't exist or is empty
            if not file_exists:
                writer.writeheader()
            
            writer.writerow({
                'id': next_id,  # Changed from 'sid' to 'id'
                'cat_id': 1,  # Default category ID
                'sub_category_name': sub_category_name,  # Changed from 'sub_cat_name'
                'sub_category_image': sub_category_image,
                'status': 1  # Added status field with default value
            })
        
        print(f"Added new subcategory: {sub_category_name} with id: {next_id}, image: {sub_category_image}")
        return {
            'sid': next_id,
            'cat_id': 1
        }
    
    except Exception as e:
        print(f"Error adding new subcategory: {e}")
        return None

def process_subcategories(sub_cat_id_string, csv_file='subcategories.csv'):
    if sub_cat_id_string:
        subcategories = [sub.strip() for sub in sub_cat_id_string.split(',')]
        
        # Define priority order (optional)
        priority_genres = ['Fiction', 'Fantasy', 'Psychology', 'Non-Fiction']
        
        # Check priority genres first
        for priority_genre in priority_genres:
            if priority_genre.lower() in [sub.lower() for sub in subcategories]:
                subcategory_info = get_sub_category_id(priority_genre, csv_file)
                if subcategory_info:
                    return {
                        'sid': subcategory_info['sid'],
                        'cat_id': subcategory_info['cat_id'],
                        'sub_cat_name': priority_genre
                    }
        
        # Then check all other subcategories
        for subcategory in subcategories:
            subcategory_info = get_sub_category_id(subcategory, csv_file)
            if subcategory_info:
                return {
                    'sid': subcategory_info['sid'],
                    'cat_id': subcategory_info['cat_id'],
                    'sub_cat_name': subcategory
                }
        
        # If none exist, add the first one
        first_subcategory = subcategories[0]
        new_subcategory_info = add_new_subcategory(first_subcategory, csv_file)
        if new_subcategory_info:
            return {
                'sid': new_subcategory_info['sid'],
                'cat_id': new_subcategory_info['cat_id'],
                'sub_cat_name': first_subcategory
            }
    
    return {
        'sid': 1,
        'cat_id': 1,
        'sub_cat_name': 'Default'
        }  

def get_author_id(soup):
    """
    Retrieves one or more author IDs from a Goodreads book page.

    Args:
        soup (bs4.BeautifulSoup): The BeautifulSoup object representing the HTML page.

    Returns:
        str: A single author ID or multiple author IDs separated by commas.
    """
    author_ids = []
    contributors_section = soup.find('div', class_='ContributorLinksList')

    if contributors_section:
        author_links = contributors_section.find_all('a', class_='ContributorLink')
        for link in author_links:
            author_url = link.get('href', '')
            if '/author/show/' in author_url:
                author_id = author_url.split('/')[-1].split('.')[0]
                author_ids.append(author_id)

    return ','.join(author_ids) if author_ids else None

def get_author_name(soup):
    author_name_span = soup.find('span', class_='ContributorLink__name', attrs={'data-testid': 'name'})
    if author_name_span:
        return author_name_span.text.strip()
    return 'Unknown Author'


def get_book_description(soup):
    try:
        desc = soup.find("div", {"class": "DetailsLayoutRightParagraph__widthConstrained"})
        return desc.get_text().strip() if desc else 'No Description available'
    except AttributeError:
        return 'No Description available'

def get_book_cover(soup):
    cover = soup.find('img', {'class': 'ResponsiveImage'})
    return cover['src'] if cover and 'src' in cover.attrs else 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/No-Image-Placeholder.svg/1665px-No-Image-Placeholder.svg.png'

def scrape_book(book_url, book_url_local, random_header):
    header = {
        "User-Agent": random.choice(LIST_OF_USER_AGENTS),
        "Accept-Language": "en-US,en;q=0.9",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp",
        "Referer": "https://www.google.com/"
    }
    
    source = requests.get(book_url, headers=header)
    time.sleep(2)
    soup = BeautifulSoup(source.content, 'html.parser')

    book_title_elem = soup.find('h1', class_='Text Text__title1', attrs={'data-testid': 'bookTitle'})
    book_title = ' '.join(book_title_elem.text.split()) if book_title_elem else 'Unknown Title'

    book_id_beta = book_url.replace(GOODREADS_URL + '/book/show/', '')
    book_id_beta1 = book_id_beta.replace(GOODREADS_URL + '/en/book/show/', '')
    a_name=get_author_name(soup)
    #print(a_name)

    genre_string = get_genre_list(soup)
    #print(genre_string)
    # try:
    #     genre_string = get_book_genre_with_gemini(book_title, get_author_name(soup))
    # except Exception as e:
    #     print(f"Gemini failed, using scraping fallback: {e}")
    #     genre_string = get_genre_list(soup)
    category_ids = process_subcategories(genre_string)
    #print(f"  📚 Genre: {genre_string}")
    
    bookinfo={
        'id': get_id(book_id_beta1),
        'cat_id': category_ids.get('cat_id'),
        'sub_cat_id': category_ids.get('sid'),
        'author_ids': get_author_id(soup),
        'book_access': 'Free',
        'title': book_title,
        'description': get_book_description(soup),
        'image': get_book_cover(soup),
        'url_type': 'server_url',
        'url': book_url_local,
        'download_enable': '1',
        'book_on_rent': '',
        'book_rent_price': '',
        'book_rent_time': '',
        'featured': '1',
        'status': '1'
    }

    return bookinfo,a_name

# %%
# Sample book page URL (public Goodreads book page)
book_url = "https://www.goodreads.com/book/show/5679963"
book_url_local = "books/the-great-gatsby.epub"

# Choose a random header
random_header = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}

# Run the function
book_data,a_name = scrape_book(book_url, book_url_local, random_header)

# Print output
import pprint
pprint.pprint(a_name)
# Out:
# 'Mwangi Gicheru'

# %%
book_data
# Out:
# {'id': '5679963',
#  'cat_id': 1,
#  'sub_cat_id': 3,
#  'author_ids': '1521574',
#  'book_access': 'Free',
#  'title': 'Across the bridge',
#  'description': 'Before I met Caroline, I had never dreamt of achieving anything beyond a bicycle and probably a tin-roofed slum. Now I was thinking of cars, bungalows, servants and whatever else Caroline missed by changing sides. But for a poor house-boy who has fallen in love with the beautiful daughter of his civil-servant master, the path to riches is not easy. In desperation Chuma moves from petty crime to a world of gangsters. It is only after much heartache on both sides that the two lovers are united.',
#  'image': 'https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1463367237i/5679963.jpg',
#  'url_type': 'server_url',
#  'url': 'books/the-great-gatsby.epub',
#  'download_enable': '1',
#  'book_on_rent': '',
#  'book_rent_price': '',
#  'book_rent_time': '',
#  'featured': '1',
#  'status': '1'}

# %% [markdown]
# ## 👩‍💻 Overview of Author Scraping Functions
# This part provides a comprehensive set of tools to scrape and enrich author profiles from Goodreads. These functions are used by the core `scrape_author()` function and include data extraction, parsing, and third-party enrichment via web search.
#
# ---
#
# ### 🧠 `scrape_author(author_id)`
# Main driver function that scrapes and assembles an author's metadata from Goodreads using their author ID (e.g., `2614.Lora_Leigh`). It fetches and parses the HTML, then compiles:
#
# - Author ID and name
# - Biography and place of birth
# - Author photo
# - Website and social media links (YouTube, Instagram, Facebook)
# - Status indicator for downstream processing
#
# ---
#
# ### 🔎 Helper Functions
#
# #### 🆔 `get_id_number(author_id)`
# Extracts the numeric portion from a combined author ID (e.g., `2614` from `2614.Lora_Leigh`).
#
# #### 📚 `get_author_info(soup)`
# Parses sidebar metadata from the author's profile page, including birth location, influences, and website.
#
# #### ✍️ `get_author_description(soup, id_number)`
# Finds and extracts the author's biography based on a unique HTML ID tied to the author ID.
#
# #### 🖼️ `get_author_image(soup, author_name)`
# Returns the URL of the author's profile image. If not found, falls back to a default placeholder image.
#
# ---
#
# ### 🌐 External Search Helpers
#
# These functions use Google search results to infer the author’s online presence:
#
# - 🔴 `author_youtube_search(author_name)` – Finds a likely YouTube channel
# - 🟣 `author_instagram_search(author_name)` – Finds their Instagram profile
# - 🔵 `author_facebook_search(author_name)` – Finds their Facebook page
# - 🌍 `author_website_search(author_name)` – Attempts to locate their official website
#
# All use the `googlesearch` package and return the first relevant result.
#
# ---
#
# ### 🛡️ Additional Notes
# - Each request to Goodreads uses a **rotating User-Agent** from `LIST_OF_USER_AGENTS` to mimic a browser and avoid blocks.
# - HTTP headers include `Referer` and `Accept` fields for better anti-bot evasion.
# - All major scrapers are modular and testable individually or in pipeline mode.

# %%
def get_id_number(author_id):
    pattern = re.compile("([^.-]+)")
    aid = pattern.search(author_id).group()
    author_split = aid.split(".")
    return author_split[0]

def get_author_info(soup):
    container = soup.find('div', attrs={'class': 'rightContainer'})
    author_info = {}
    data_div = container.find('br', attrs={'class': 'clear'})
    while data_div:
        if data_div.name:
            data_class = data_div.get('class')[0]
            if data_class == 'aboutAuthorInfo':
                break
            elif data_class == 'dataTitle':
                key = data_div.text.strip()
                author_info[key] = []
            if data_div.text == 'Born':
                data_div = data_div.next_sibling
                author_info[key].append(data_div.strip())
            elif data_div.text == 'Influences':
                data_div = data_div.next_sibling.next_sibling
                data_items = data_div.findAll('span')[-1].findAll('a')
                for data_a in data_items:
                    author_info[key].append(data_a.text.strip())
            elif data_div.text == 'Member Since':
                data_div = data_div.next_sibling.next_sibling
                author_info[key].append(data_div.text.strip())
            else:
                data_items = data_div.find_all('a')
                for data_a in data_items:
                    author_info[key].append(data_a.text.strip())
        data_div = data_div.next_sibling
    return author_info

def get_author_description(soup, id_number):
    cell = soup.find("span", {"id": f"freeTextContainerauthor{id_number}"})
    return cell.text.strip() if cell else None

def get_author_image(soup, author_name):
    cell = soup.find("img", {"alt": author_name, "itemprop": "image"})
    if cell:
        return cell.attrs.get("src")
    return 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/No-Image-Placeholder.svg/1665px-No-Image-Placeholder.svg.png'

def author_youtube_search(author_name):
    try:
        search_txt = author_name + ' channel youtube'
        results = search(search_txt, num_results=10)
        for url in results:
            if 'https://www.youtube.com' in url:
                return url
    except Exception as e:
        print(f"YouTube search error: {e}")
    return ''

def author_instagram_search(author_name):
    try:
        search_txt = author_name + ' instagram official'
        results = search(search_txt, num_results=10)
        for url in results:
            if 'https://www.instagram.com' in url:
                return url
    except Exception as e:
        print(f"Instagram search error: {e}")
    return ''

def author_facebook_search(author_name):
    try:
        search_txt = author_name + ' facebook official'
        results = search(search_txt, num_results=10)
        for url in results:
            if 'https://www.facebook.com' in url:
                return url
    except Exception as e:
        print(f"Facebook search error: {e}")
    return ''

def author_website_search(author_name):
    try:
        search_txt = author_name + ' official website'
        results = search(search_txt, num_results=10)
        for url in results:
            return url  # First valid hit
    except Exception as e:
        print(f"Website search error: {e}")
    return ''

def scrape_author(author_id):
        """
        Scrapes the author information from the Goodreads website.

        Args:
            author_id (str): The author ID.

        Returns:
            dict: A dictionary containing the scraped author information.
        """
        user_agent = random.choice(LIST_OF_USER_AGENTS)  # Select a random user agent
        random_header = {'User-Agent': user_agent}  # Create a header with the selected user agent

        url = "https://www.goodreads.com/author/show/" + author_id

        time.sleep(3)  # Pause execution for 3 seconds

        try:
            source = requests.get(url, headers=random_header).content  # Open the URL and retrieve the HTML source with the header
            soup = BeautifulSoup(source, "html.parser")  # Create a BeautifulSoup object for parsing the HTML

            author_name = soup.find("span", {"itemprop": "name"}).text.strip()  # Extract the author name from the HTML
            id_number = get_id_number(author_id)  # Call a helper function to get the ID number

            author_info = get_author_info(soup)  # Call a helper function to get additional author information
            if author_info:
                if 'Born' in author_info:
                    author_city_name = author_info["Born"][0]  # Extract the author's city name if available
                else:
                    author_city_name = 'No City Name Found'

                if 'Website' in author_info:
                    author_website = author_info["Website"]  # Extract the author's website if available
                else:
                    author_website = 'none'
            else:
                author_city_name = 'No City Name Found'
                author_website = 'none'

            #info["author_name"] = author_name  # Add the author name to the 'info' dictionary

            author_des = get_author_description(soup, id_number)
            if not author_des:  # Check if author_des is empty (None or empty string)
                author_des = "No Author Description"


            

        except AttributeError as e:
            print(f"An AttributeError occurred while scraping author information: {e}")
            return None
     
        #"id","name","description","image","facebook_url","instagram_url","youtube_url","website_url","status"
        return {
            "id": id_number,
            "name": author_name,
            "description": author_des,
            "image": get_author_image(soup, author_name),
            "facebook_url": author_facebook_search(author_name),
            "instagram_url": author_instagram_search(author_name),
            "youtube_url": author_youtube_search(author_name),
            "website_url": author_website_search(author_name),
            "status": '1'
        }

def is_author_id_in_csv(aid, csv_file= 'authors.csv'):
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.reader(file)
            for row in reader:
                if row[0] == str(aid):  # Check if the first column matches the author ID
                    return True
        return False
    except FileNotFoundError:
        print(f"File {csv_file} not found.")
        return False
    
    
def is_author_id_in_local_csv(aid, csv_file):
    """
    Checks if a given author ID exists in the specified CSV file.

    Args:
        aid (int or str): The author ID to search for.
        csv_file (str): The path to the CSV file where the author ID is stored.

    Returns:
        bool: True if the author ID is found in the CSV file, False otherwise.
    """
    try:
        # Open the CSV file in read mode, specifying UTF-8 encoding for compatibility
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.reader(file)  # Create a CSV reader object to read rows from the file
            for row in reader:
                # Check if the first column matches the provided author ID
                if row[0] == str(aid):  # Convert 'aid' to string for comparison
                    return True  # Return True if a matching author ID is found
        return False  # Return False if the author ID is not found after reading all rows
    except FileNotFoundError:
        # Handle the case where the CSV file does not exist
        print(f"File {csv_file} not found.")
        return False
    
def append_author_to_csv(file_name, author_data):
    """
    Appends the scraped author data to a CSV file.

    Args:
        file_name (str): The name of the CSV file.
        author_data (dict): A dictionary containing the scraped author information.
    """
    fieldnames = [
        'id', 'name', 'description', 'image',
        'facebook_url', 'instagram_url', 'youtube_url',
        'website_url', 'status'
    ]


    # Check if the file exists and write header if not
    try:
        with open(file_name, mode='r', newline='', encoding='utf-8') as file:
            pass
    except FileNotFoundError:
        with open(file_name, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()

    # Append author data to the CSV file
    with open(file_name, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writerow(author_data)

# %%
print(scrape_author('4601681'))

# %%
import re
def clean_url(url):
    return url.split('?')[0] if '?' in url else url
    
def simple_bing_search(name):
    try:
        search_txt = name + ' goodreads book show'
        
        headers = {
            "User-Agent": random.choice(LIST_OF_USER_AGENTS)
        }
        
        search_url = f"https://www.bing.com/search?q={search_txt.replace(' ', '+')}"
        response = requests.get(search_url, headers=headers)
        
        if response.status_code != 200:
            return ''
            
        soup = BeautifulSoup(response.text, "html.parser")
        results = soup.find_all("li", class_="b_algo", limit=10)
        
        if not results:
            return ''
        
        for result in results:
            link_element = result.find("a")
            if link_element and "href" in link_element.attrs:
                url = link_element["href"]
                
                # Handle Bing's redirect URLs
                if 'bing.com/ck/a' in url:
                    # Extract the actual URL from Bing's redirect parameter
                    import urllib.parse
                    parsed = urllib.parse.parse_qs(urllib.parse.urlparse(url).query)
                    if 'u' in parsed:
                        # Decode the base64-like encoding that Bing uses
                        encoded_url = parsed['u'][0]
                        if encoded_url.startswith('a1'):
                            # Remove Bing's encoding prefix and decode
                            import base64
                            try:
                                decoded_bytes = base64.b64decode(encoded_url[2:] + '==')
                                actual_url = decoded_bytes.decode('utf-8')
                                if 'https://www.goodreads.com/book/' in actual_url:
                                    #print(actual_url)
                                    return actual_url
                            except:
                                pass
                
                # Fallback: check if it's already a direct URL
                if 'https://www.goodreads.com/book/' in url:
                    return url
                    
    except Exception as e:
        print(f"goodreads search error: {e}")
    
    return ''
        
def simple_google_search(name):
    try:
        search_txt = name + ' goodreads book show'
        results = search(search_txt, num_results=10)
        for url in results:
            if 'https://www.goodreads.com/book/' in url:
                return url
    except Exception as e:
        print(f"goodreads search error: {e}")
    return ''

def get_cover_images(search_term):
    # Add headers to mimic browser request
    headers = {
            "User-Agent": random.choice(LIST_OF_USER_AGENTS)
        }
    
    # Format search URL
    search_term1=search_term+' cover'
    search_url = f'https://www.google.com/search?q={search_term1}&tbm=isch'
    
    # Get page content
    response = requests.get(search_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all images
    image_urls = set()
    
    # Look for image URLs in script tags
    for script in soup.find_all('script'):
        if script.string:
            urls = re.findall(r'https?://[^"\']+(?:jpg|jpeg|png|gif)', script.string)
            for url in urls:
                if not url.startswith('data:'):
                    image_urls.add(url)
    
    # Also check <img> tags
    for img in soup.find_all('img'):
        src = img.get('src', '')
        if src.startswith('http') and not src.startswith('data:'):
            image_urls.add(src)
            
    # Also check metadata
    for meta in soup.find_all('meta'):
        content = meta.get('content', '')
        if content.startswith('http') and any(ext in content.lower() for ext in ['.jpg', '.jpeg', '.png', '.gif']):
            image_urls.add(content)

    image_list = list(image_urls)

    # Check for Amazon image URLs
    amazon_patterns = [
        "https://m.media-amazon.com/images/",
        "https://images-na.ssl-images-amazon.com/images"
    ]
    
    for url in image_list:
        if any(url.startswith(pattern) for pattern in amazon_patterns):
            return url  # return first Amazon match
    
    # If no Amazon image, return first image found (if any)
    # If no Amazon image, return first image with a valid extension
    for url in image_list:
        print(url)
        if re.search(r'\.(jpg|jpeg|png|gif)$', url, re.IGNORECASE):
            return url
    return None
    
def extract_search_query(url):
    parsed_url = urllib.parse.urlparse(url)
    params = urllib.parse.parse_qs(parsed_url.query)
    return params.get('q', [''])[0]


def remove_extra_spaces(text):
    return ' '.join(text.split())


def remove_parentheses_content(title):
    cleaned_title = re.sub(r'\([^)]*\)', '', title)
    return remove_extra_spaces(cleaned_title)


def normalize_text(text):
    import string
    text = remove_parentheses_content(text)
    text = remove_extra_spaces(text.lower())
    return text.translate(str.maketrans('', '', string.punctuation))


def calculate_similarity_score(search_title, book_title):
    search_words = set(normalize_text(search_title).split())
    book_words = set(normalize_text(book_title).split())
    common_words = {'the', 'a', 'an', 'and', 'or', 'but', 'in', 'on', 'at', 'to', 'for', 'of', 'with', 'by'}
    search_words -= common_words
    book_words -= common_words
    if not search_words:
        return 0
    return len(search_words & book_words) / len(search_words | book_words)


def is_author_match(search_author, book_authors):
    search_author_norm = normalize_text(search_author)
    for author in book_authors:
        author_norm = normalize_text(author)
        if search_author_norm == author_norm or \
           search_author_norm in author_norm or \
           author_norm in search_author_norm:
            return True
        if len(search_author_norm.split()) >= 2 and len(author_norm.split()) >= 2:
            if search_author_norm.split()[0] in author_norm and \
               search_author_norm.split()[-1] in author_norm:
                return True
    return False

def clean_title_for_comparison(title):
    if not title:
        return title
    cleaned = re.sub(r'\([^)]*\)', '', title)
    cleaned = re.sub(r'\(.*$', '', cleaned)
    return ' '.join(cleaned.split()).strip()


def parse_filename(filename):
    name_without_ext = filename.replace('.epub', '')
    if ' - ' in name_without_ext:
        parts = name_without_ext.split(' - ')
        if len(parts) >= 2:
            return ' - '.join(parts[:-1]).strip(), parts[-1].strip()
    return None, None


def clean_search_query(book_title, author_name):
    """
    Cleans and formats the search query for Goodreads search.

    Args:
        book_title (str): The title of the book.
        author_name (str): The name of the author.

    Returns:
        str: A cleaned search query string suitable for Goodreads search.
    """
    # Remove parentheses and extra content from the book title
    cleaned_title = clean_title_for_comparison(book_title)
    # If author name is unknown or not provided, use only the title
    if author_name.lower().strip() in ['unknown', 'n/a', 'na', 'anonymous', '']:
        query = cleaned_title
    else:
        # Otherwise, combine title and author for better search accuracy
        query = f"{cleaned_title} by {author_name}"
    # Replace problematic characters with spaces and strip leading/trailing spaces
    return re.sub(r'[&<>"|{}\\^`\[\]#%]', ' ', query).strip()

def check_file_exists(relative_path, base_path=r"C:\xampp8.2\htdocs\php_web_services_final\public"):
    """
    Check if a file exists by combining relative path with base path
    
    Args:
        relative_path (str): Relative path like "upload\Stephen Deas\The_King_of_the_Crags_-_Stephen_Deas.epub"
        base_path (str): Base directory path
    
    Returns:
        dict: Contains 'exists' (bool), 'full_path' (str), 'size_bytes', 'size_mb', etc.
    """
    try:
        # Normalize the paths to handle different slash types
        relative_path = relative_path.replace('/', os.sep).replace('\\', os.sep)
        
        # Combine base path with relative path
        full_path = os.path.join(base_path, relative_path)
        
        # Normalize the full path
        normalized_path = os.path.normpath(full_path)
        
        # Check if file exists
        file_exists = os.path.exists(normalized_path) and os.path.isfile(normalized_path)
        
        size_bytes = None
        size_mb = None
        
        if file_exists:
            size_bytes = os.path.getsize(normalized_path)
            size_mb = round(size_bytes / (1024 * 1024), 2)  # Convert bytes to MB
        
        return {
            'exists': file_exists,
            'full_path': normalized_path,
            'relative_path': relative_path,
            'size_bytes': size_bytes,
            'size_mb': size_mb
        }
        
    except Exception as e:
        return {
            'exists': False,
            'full_path': None,
            'relative_path': relative_path,
            'error': str(e),
            'size_bytes': None,
            'size_mb': None
        }

def save_results_to_file(results, output_file="goodreads_search_results.txt"):
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write("Goodreads Search Results\n" + "=" * 50 + "\n\n")
            for filename, result in results.items():
                f.write(f"File: {filename}\n")
                for key, val in result.items():
                    f.write(f"{key.capitalize()}: {val}\n")
                f.write("\n")
        print(f"\n📄 Results saved to: {output_file}")
    except Exception as e:
        print(f"Error saving results: {e}")


def scrape_goodreads_books(url, author_name, book_title=None):
    try:
        headers = {
        "User-Agent": random.choice(LIST_OF_USER_AGENTS),
        "Accept-Language": "en-US,en;q=0.9",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp",
        "Referer": "https://www.google.com/"
        }
        request = urllib.request.Request(url, headers=headers)
        with urllib.request.urlopen(request) as response:
            source = response.read()

        soup = BeautifulSoup(source, "html.parser")
        book_containers = soup.find_all('tr', itemtype='http://schema.org/Book')

        if not book_containers:
            book_containers = soup.find_all('tr', {'itemtype': 'http://schema.org/Book'})
        if not book_containers:
            return None

        book_matches = []
        search_query = extract_search_query(url)
        search_title = book_title if book_title else search_query

        for container in book_containers:
            try:
                title_element = container.find('a', class_='bookTitle')
                if not title_element:
                    continue
                title_link = title_element.get("href")
                raw_title = title_element.text.strip()
                if not title_link:
                    continue

                cleaned_title = remove_parentheses_content(raw_title)
                authors = [a.text.strip() for a in container.find_all('a', class_='authorName')]
                complete_book_url = clean_url(GOODREADS_URL + title_link)
                author_match = is_author_match(author_name, authors)
                title_similarity = calculate_similarity_score(search_title, cleaned_title)
                score = 0.7 * (1.0 if author_match else 0.0) + 0.3 * title_similarity

                book_matches.append({
                    'title': raw_title,
                    'cleaned_title': cleaned_title,
                    'authors': authors,
                    'url': complete_book_url,
                    'author_match': author_match,
                    'title_similarity': title_similarity,
                    'score': score
                })
            except Exception as e:
                print(f"Error processing container: {e}")

        book_matches.sort(key=lambda x: x['score'], reverse=True)

        if book_matches:
            best_match = book_matches[0]
            confidence = (
                "High" if best_match['author_match'] and best_match['title_similarity'] > 0.5
                else "Medium" if best_match['author_match'] or best_match['title_similarity'] > 0.3
                else "Low"
            )
            return best_match['url']

        return None

    except Exception as e:
        return None

def scrape_goodreads_books_raw(url, author_name, book_title=None):
    try:
        headers = {
        "User-Agent": random.choice(LIST_OF_USER_AGENTS),
        "Accept-Language": "en-US,en;q=0.9",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp",
        "Referer": "https://www.google.com/"
        }
        request = urllib.request.Request(url, headers=headers)
        with urllib.request.urlopen(request) as response:
            source = response.read()

        soup = BeautifulSoup(source, "html.parser")
        book_containers = soup.find_all('tr', itemtype='http://schema.org/Book')

        if not book_containers:
            book_containers = soup.find_all('tr', {'itemtype': 'http://schema.org/Book'})
        if not book_containers:
            return None

        book_matches = []
        search_query = extract_search_query(url)
        search_title = book_title if book_title else search_query

        for container in book_containers:
            try:
                title_element = container.find('a', class_='bookTitle')
                if not title_element:
                    continue
                title_link = title_element.get("href")
                raw_title = title_element.text.strip()
                if not title_link:
                    continue

                cleaned_title = remove_parentheses_content(raw_title)
                authors = [a.text.strip() for a in container.find_all('a', class_='authorName')]
                complete_book_url = clean_url(GOODREADS_URL + title_link)
                author_match = is_author_match(author_name, authors)
                title_similarity = calculate_similarity_score(search_title, raw_title)
                score = 0.7 * (1.0 if author_match else 0.0) + 0.3 * title_similarity

                book_matches.append({
                    'title': raw_title,
                    'cleaned_title': cleaned_title,
                    'authors': authors,
                    'url': complete_book_url,
                    'author_match': author_match,
                    'title_similarity': title_similarity,
                    'score': score
                })
            except Exception as e:
                print(f"Error processing container: {e}")

        book_matches.sort(key=lambda x: x['score'], reverse=True)
        print(f"Found {len(book_matches)} matches for '{search_title}' by '{author_name}'")
        for match in book_matches:
            print(f"  - {match['title']} by {', '.join(match['authors'])} (Score: {match['score']:.2f})")

        if book_matches:
            best_match = book_matches[0]
            confidence = (
                "High" if best_match['author_match'] and best_match['title_similarity'] > 0.5
                else "Medium" if best_match['author_match'] or best_match['title_similarity'] > 0.3
                else "Low"
            )
            return best_match['url']

        return None

    except Exception as e:
        print(f"Error scraping Goodreads books: {e}")
        return None
    
    
def process_epub_folder(folder_path, delay_seconds=2):
    folder_path = Path(folder_path)
    if not folder_path.exists():
        return {}

    epub_files = list(folder_path.glob('*.epub'))
    if not epub_files:
        return {}

    results = {}
    for i, epub_file in enumerate(epub_files, 1):
        filename = epub_file.name
        book_title, author_name = parse_filename(filename)
        book_url_local = filename.replace(' ', '_')

        if not book_title or not author_name:
            results[filename] = {'status': 'failed', 'reason': 'Could not parse filename'}
            continue

        search_query = clean_search_query(book_title, author_name)
        search_url = GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': search_query})
        print(f"  🔍 Searching: {search_url} for '{book_title}' by '{author_name}'")
        goodreads_url = scrape_goodreads_books(search_url, author_name, book_title)

        if goodreads_url:
            headers = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}
            book_info = scrape_book(goodreads_url, book_url_local, headers)
            results[filename] = {'status': 'success', 'goodreads_url': goodreads_url, 'book_info': book_info}
        else:
            #results[filename] = extract_epub_metadata(fname)
            corrected_title = fix_ebook_title_with_gemini(book_title, author_name)
            search_query = clean_search_query(corrected_title, author_name)
            search_url = GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': search_query})
            print(f"  🔍 Searching again: {search_url} for '{book_title}' by '{author_name}'")
            goodreads_url = scrape_goodreads_books(search_url, author_name, corrected_title)
            if goodreads_url:
                headers = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}
                #book_info = scrape_book(goodreads_url, book_url_local, headers)
                results[filename] = {'status': 'success', 'goodreads_url': goodreads_url, 'book_info': book_info}
            else:
                results[filename] = {'status': 'not_found'}
            

        if i < len(epub_files):
            time.sleep(delay_seconds)

    return results



def search_book_id(book_id,csv_file = 'books.csv'):
    """
    Search for a specific book ID in the 'tbl_books.csv' file.

    Args:
        csv_file (str): Path to the CSV file containing book data.
        book_id (int or str): The book ID to search for in the CSV file.

    Returns:
        bool: True if the book ID is found, False otherwise.

    Raises:
        FileNotFoundError: If the CSV file cannot be found or opened.

    
    """
    
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            
            # Loop through each row in the CSV
            for row in reader:
                # Check if the current row's 'id' matches the given book_id
                if row['id'] == str(book_id):
                    return True  # Return True if the book_id is found
        return False  # Return False if not found
    except FileNotFoundError:
        print(f"Error: The file {csv_file} was not found.")
        return False            

def check_book_id(book_id,csv_file):
    """
    Search for a specific book ID in the 'tbl_books.csv' file.

    Args:
        csv_file (str): Path to the CSV file containing book data.
        book_id (int or str): The book ID to search for in the CSV file.

    Returns:
        bool: True if the book ID is found, False otherwise.

    Raises:
        FileNotFoundError: If the CSV file cannot be found or opened.

    
    """
    
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            
            # Loop through each row in the CSV
            for row in reader:
                # Check if the current row's 'id' matches the given book_id
                if row['id'] == str(book_id):
                    return True  # Return True if the book_id is found
        return False  # Return False if not found
    except FileNotFoundError:
        print(f"Error: The file {csv_file} was not found.")
        return False            


def check_and_append_aid(aid, csv_file='aid1.csv'):
    """
    Checks if an author ID exists in the CSV file, and if not, appends it on a new line.
    If the file is empty, adds a header before appending the ID.

    Args:
        aid (str): The author ID to search for.
        csv_file (str): The path to the CSV file (default is 'aid1.csv').

    Returns:
        bool: True if the ID was appended, False if it already existed.
    """
    aid_exists = False
    
    # Check if the file exists and is empty
    file_exists = os.path.exists(csv_file)
    file_empty = os.path.getsize(csv_file) == 0 if file_exists else True

    # Read the CSV and check if the ID exists
    if not file_empty:
        try:
            with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
                reader = csv.DictReader(file)
                for row in reader:
                    if row['aid'] == str(aid):
                        aid_exists = True
                        break
        except FileNotFoundError:
            print(f"File {csv_file} not found, creating a new one.")

    # If the ID doesn't exist, append it to the file
    if not aid_exists:
        with open(csv_file, mode='a', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            if file_empty:  # Add header if the file is empty or newly created
                writer.writerow(['aid'])
            writer.writerow([aid])  # Append the ID on a new line
        print(f"Appended ID {aid} to {csv_file}.")
        return True
    else:
        print(f"ID {aid} already exists in {csv_file}.")
        return False

def append_to_book_csv(book_data, csv_file):
    """
    Appends the book data to the specified CSV file.

    Args:
        book_data (dict): A dictionary containing book details.
        csv_file (str): The path to the CSV file where the data should be appended.
    """
    fieldnames = ['id', 'cat_id', 'sub_cat_id', 'author_ids', 'book_access', 'title', 
                  'description', 'image', 'url_type', 'url', 'download_enable',
                  'book_on_rent', 'book_rent_price', 'book_rent_time', 'featured', 'status']

    # Check if the file exists to write the header only if it's a new file
    try:
        with open(csv_file, mode='a', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)

            # Write header only if file is empty or does not exist
            if file.tell() == 0:
                writer.writeheader()

            # Write the book data
            writer.writerow(book_data)
            print(f"Appended data for book '{book_data['title']}' to {csv_file}.")
    
    except IOError as e:
        print(f"An I/O error occurred: {e}")

def move_and_rename_epub(source_path, destination_directory, new_name):
    """
    Move an EPUB file from the source path to the destination directory and rename it.

    Args:
        source_path (str): The path to the source EPUB file.
        destination_directory (str): The path to the destination directory.
        new_name (str): The new name for the EPUB file (including .epub extension).

    Returns:
        str: The path to the newly moved and renamed EPUB file.
    """
    if not os.path.isfile(source_path):
        print(f"Source file '{source_path}' does not exist.")
        return None

    if not os.path.isdir(destination_directory):
        print(f"Destination directory '{destination_directory}' does not exist.")
        return None

    new_file_path = os.path.join(destination_directory, new_name)

    try:
        shutil.move(source_path, new_file_path)
        print(f"File moved and renamed to '{new_file_path}'.")
        return new_file_path
    except Exception as e:
        print(f"Error moving or renaming file: {e}")
        return None

# %%
 # Example usage:
book_url = get_cover_images("The Great Gatsby")
print(book_url)
# Out:
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQay2uxNHo4_cbMD5IFWsQ7Tp9Oz5JrFIYIkeSHltlkS_fENL2q6Vs6TUqM5iA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTJGHrhHUTVGAuAEzIEnsGogSFddkj5p3opSLWmhfX1nL5gY2c0eelzOqPexUk&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQd7RY-XmTYug8x2v2hDSUr2HlNYgHMSd2ez4BfMT5BI05fhtj3H4UUE7LfWQ&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQxW3tLup3oOvlAnoOjdm2_ZcenyIM94DO66kt29EdbmmA_j3tAHpwkDQqoSQ&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrAPXFHjIc953Qc2oOGEqEYQst2Yjl5RWRDPyA68kqB_1lyl_CVU6zY-DeDs8&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQTkQTDvjv8IXfJf-HvQnFW-9lCb9NOZnl0nmsUntH_eEP6v3Q8FmFMo8kqYw&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8Tj6R6VAHDS0sapvAVWhTPgdFh8FajJAKlbXPSbaanUorbo_9dESZtVvtxY0&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTurUGSp_OLSSmvsaXnqYg3o62fWsBPR7Sx2ZrRl1TdmpKHmZlGr5yK2s6kTg&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTipSd42a7cX810yTO9OiVndPO9m7KrpNACVbuHbK5MAQo2PzYAMf-YLOSDvY8&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQCQpuNRvqUptnEhiDBDftlpWnDZrY0Ht8p61y7aREAHQlYl_BPTQVXqA7KeMU&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSpsS6dTk6xWHZ8aTpK8mTRTDPwKJj8-48ULc_CyvYQZXkh6iLmx6xfemOMLQ&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQnzllSFsYpPNW_msgKRyw21jaBmzwLTxYz-Vbhxlqsy1g5s_rLL8Ue1gVlTEM&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQegrVnKzH9AGvOeXu6kQxxeT7Ql0yVuvt0VE0EwGCagpfRAbTf-bQbZ9DfFgo&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSr51FK21M64T0RdwEXFyLntU3NPAbbqZXaNOZ-5NoApzZbSmwkveaLa4EcFHA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAVTxb7G1ltih0VivRMGlz-mI_Nlba19-VUH92I88czv4FAIBRYnOMeu97Qg&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSDGpwWELTVv1AghV1sWOtdK7T9GWQJniT-drehXBnM3OhD_AmW0jzJpQl7-IE&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQw-vH5M_4iVFeBvSB18eLs7BuwG1j3jCWoV5J2qJqsCSalGDj0IjcHxk_ZOw&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjP4w0O7BeV0MY023jdRtvh4W6QDp6RLcViUbN0IRUwPKIWbPQ4JLQttUBZwE&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSwJ-B72dPIMrvprXCM7N30bVUt558aCbRa2u3whvNUKKcfVzmtcMTb3AP3oQ&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpr7JP9rVF7n5h0wJJ2ONiJptIU2ELfjFR2z4miz-aAe7fLCV7iVZDQIpJ8gs&s
# None

# %%
book='The Awakeni - Kelley Armstrong.epub'
book_title, author_name = parse_filename(book)
print(f"Book Title: {book_title}, Author Name: {author_name}")
bookname = f"{book_title} by {author_name}"
search_url = GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': bookname})
print(f"  🔍 Searching: {search_url} for '{book_title}' by '{author_name}'")


url=simple_bing_search(bookname)
if url:
    print(f"Found Goodreads URL via Google search: {url}")
    goodreads_url = url
else:
    print("No matching book found on Goodreads.")
# Out:
# Book Title: The Awakeni, Author Name: Kelley Armstrong
#   🔍 Searching: https://www.goodreads.com/search?q=The+Awakeni+by+Kelley+Armstrong for 'The Awakeni' by 'Kelley Armstrong'
# No matching book found on Goodreads.

# %%
def get_epub_info(fname):
    """
    Extracts metadata from an EPUB file.

    Args:
        fname (str): The path to the EPUB file.

    Returns:
        dict: A dictionary containing the extracted metadata, including 'title' and 'creator',
              or None if an error occurs.
    """
    ns = {
        # Namespace for the container.xml file
        'n': 'urn:oasis:names:tc:opendocument:xmlns:container',
        'pkg': 'http://www.idpf.org/2007/opf',  # Namespace for the package metadata
        'dc': 'http://purl.org/dc/elements/1.1/'  # Namespace for Dublin Core metadata
    }

    try:
        # Open the EPUB file
        zip = zipfile.ZipFile(fname)

        # Read the content of the container.xml file
        txt = zip.read('META-INF/container.xml')
        tree = etree.fromstring(txt)  # Parse the XML content
        
        # Extract the path of the contents metafile
        cfname = tree.xpath('n:rootfiles/n:rootfile/@full-path', namespaces=ns)[0]

        # Read the contents metafile
        cf = zip.read(cfname)  # Read the contents metafile
        tree = etree.fromstring(cf)  # Parse the XML content

        # Extract the metadata block
        p = tree.xpath('/pkg:package/pkg:metadata', namespaces=ns)[0]

        # Repackage the data
        res = {}  # Initialize a dictionary to store the metadata
        for s in ['title', 'creator']:
            # Extract the text content of each metadata element
            res[s] = p.xpath(f'dc:{s}/text()', namespaces=ns)[0]

        return res  # Return the metadata dictionary
    
    except (zipfile.BadZipFile, KeyError, etree.XMLSyntaxError, IndexError) as e:
        # Handle specific exceptions (e.g., invalid EPUB format, missing metadata)
        print(f"Error reading EPUB file '{fname}': {e}")
        return None
    except Exception as e:
        # Handle other unexpected exceptions
        print(f"An unexpected error occurred: {e}")
        return None
    
def extract_epub_metadata(fname):
    """
    Extract title and author from an EPUB file using ebooklib.

    Args:
        fname (str): Path to the EPUB file.

    Returns:
        dict: Dictionary with keys 'title' and 'creator' (author), or None if reading fails.
    """
    try:
        book = epub.read_epub(fname)
        title = book.get_metadata('DC', 'title')
        creator = book.get_metadata('DC', 'creator')

        return {
            'title': title[0][0] if title else None,
            'creator': creator[0][0] if creator else None
        }
    except Exception:
        return None


def is_book_id_in_books_csv(book_id, csv_file='books.csv'):
    """
    Check if a book ID exists in the specified books CSV file.

    Args:
        book_id (int or str): The book ID to search for.
        csv_file (str): Path to the CSV file containing book data.

    Returns:
        bool: True if the book ID is found, False otherwise.
    """
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                if row['id'] == str(book_id):
                    return True
        return False
    except FileNotFoundError:
        print(f"Error: The file '{csv_file}' was not found.")
        return False


def book_exists_in_csv(book_id, csv_file):
    """
    Same as is_book_id_in_books_csv but for generic use with explicit csv_file.

    Args:
        book_id (int or str): The book ID to search for.
        csv_file (str): Path to the CSV file containing book data.

    Returns:
        bool: True if found, False otherwise.
    """
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                if row['id'] == str(book_id):
                    return True
        return False
    except FileNotFoundError:
        print(f"Error: The file '{csv_file}' was not found.")
        return False


def is_author_id_in_authors_csv(aid, csv_file='authors.csv'):
    """
    Check if an author ID exists in the specified authors CSV file.

    Args:
        aid (int or str): Author ID to check.
        csv_file (str): Path to the author CSV file.

    Returns:
        bool: True if the author ID is found, False otherwise.
    """
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.reader(file)
            for row in reader:
                if row[0] == str(aid):
                    return True
        return False
    except FileNotFoundError:
        print(f"File '{csv_file}' not found.")
        return False

def is_book_in_csv(book_file_url, csv_file):
    """
    Checks if a book with the given file URL is present in the specified CSV file.

    Args:
        book_file_url (str): The file URL of the book to search for.
        csv_file (str): The path to the CSV file.

    Returns:
        bool: True if the book is found in the CSV file, otherwise False.
    """
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)

            if 'url' not in reader.fieldnames:
                print("Error: The CSV file does not contain a 'url' column.")
                return False

            for row in reader:
                if row['url'].strip() == book_file_url.strip():
                    return True

        return False

    except FileNotFoundError:
        print(f"Error: The file '{csv_file}' does not exist.")
        return False
    except Exception as e:
        print(f"An error occurred while reading the CSV: {e}")
        return False

def search_epub_by_name(epub_name, root_dir=r'C:\xampp8.2\htdocs\php_web_services_final\public\upload'):
    """
    Searches for an EPUB file by name within the specified root directory and its subdirectories.
    
    Args:
        epub_name (str): The name of the EPUB file to search for (can be full name or partial match).
        root_dir (str): The root directory to start the search from.
        
    Returns:
        str: The full path to the EPUB file if found, otherwise None.
    """
    for dirpath, _, filenames in os.walk(root_dir):
        for file in filenames:
            if file.lower().endswith(".epub") and epub_name.lower() in file.lower():
                return os.path.join(dirpath, file)
    
    return None  # Not found

# %%
csv_file1 = 'authorsoceanofpdf.csv'
csv_file = csv.reader(open('aid1.csv', "r", encoding='utf-8'), delimiter=",")
next(csv_file)
for row in csv_file:
    try:
        if row:
            a_id = row[0].strip()
            if not is_author_id_in_csv(a_id) and not is_author_id_in_local_csv(a_id, csv_file1):
                print('========> adding author id '+a_id)
                author_data = scrape_author(a_id)  # Scrape author data
                append_author_to_csv('authorsoceanofpdf.csv', author_data)
                print(f"+++++++++> {author_data['name']} added")
                time.sleep(3)
            else:
                print(f"{a_id} is already in the CSV file.")
    except Exception as e:
        print(f"Error processing author ID {a_id}: {e}")
        continue

# %%
import os
import csv
import random
import urllib.parse
import time  # <-- Added for tracking execution time

# === Track start time ===
start_time = time.time()

# === Constants ===
START_DIR = r'C:\cracks\My_App\epub-library-manager\All_Books'
BOOKS_FOLDER = os.path.join(os.getcwd(), 'books')
CSV_FILE = os.path.join(BOOKS_FOLDER, 'allbooks.csv')
AUTHOR_ID_CSV = 'aid1.csv'
UPLOAD_FOLDER = 'upload'
GOODREADS_URL = 'https://www.goodreads.com'

# === Ensure required folders and files exist ===
os.makedirs(BOOKS_FOLDER, exist_ok=True)
if not os.path.exists(CSV_FILE):
    with open(CSV_FILE, mode='w', newline='') as f:
        pass

# === Counters ===
processed_books = 0
skipped_books = 0
already_added_books = 0

# === Count EPUBs ===
total_epub_files = sum(
    file.lower().endswith('.epub') for _, _, files in os.walk(START_DIR) for file in files
)

print(f"📚 Found {total_epub_files} EPUB files to process...")
print("=" * 50)

# === Helper function to process valid scraped book ===
def process_scraped_book(book_info, epub_path, current_csv, author_name, book_url_local):
    try:
        authorid = book_info["author_ids"]
        author_ids = authorid.split(',') if ',' in authorid else [authorid]

        for author in author_ids:
            check_and_append_aid(author.strip(), csv_file=AUTHOR_ID_CSV)

        if author_name.lower() == 'unknown':
            new_author_id = author_ids[0].strip()

        print('Book scraped ----> ' + book_info['id'])

        dest = os.path.join(UPLOAD_FOLDER, author_name)
        os.makedirs(dest, exist_ok=True)

        new_file_path = move_and_rename_epub(epub_path, dest, book_url_local)
        book_info['url'] = new_file_path

        append_to_book_csv(book_info, current_csv)
        return True

    except Exception as e:
        print(f"❌ Error during book processing: {e}")
        return False

# === Main EPUB Processing Loop ===
current_book = 0
for root, _, files in os.walk(START_DIR):
    for file in files:
        if not file.lower().endswith('.epub'):
            continue

        current_book += 1
        epub_path = os.path.join(root, file)
        book_title, author_name = parse_filename(file)

        if not book_title or not author_name:
            print(f"❌ Ebook {current_book} of {total_epub_files}: Skipping '{file}' due to missing title or author.")
            skipped_books += 1
            continue

        book_url_local = file.replace(' ', '_')
        url_book = os.path.join(UPLOAD_FOLDER, book_url_local)

        if is_book_in_csv(url_book, CSV_FILE):
            print(f"📋 Ebook {current_book} of {total_epub_files}: '{file}' already exists in CSV, skipping...")
            already_added_books += 1
            continue

        bookname = f"{book_title} by {author_name}"
        print(f'📖 Ebook {current_book} of {total_epub_files}: Working on {bookname}')

        search_url = GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': bookname})
        print(f"  🔍 Searching: {search_url} for '{book_title}' by '{author_name}'")

        # === Try multiple search methods with debug prints ===
        goodreads_url = None
        search_attempts = [
            ("Goodreads Search", lambda: scrape_goodreads_books(search_url, author_name, book_title)),
            ("Raw Goodreads Search", lambda: scrape_goodreads_books_raw(
                GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': clean_search_query(book_title, author_name)}),
                author_name, None
            )),
            ("Google Search", lambda: simple_google_search(bookname)),
            ("Bing Search", lambda: simple_bing_search(bookname))
        ]

        for label, method in search_attempts:
            print(f"🔍 Trying method: {label}")
            try:
                goodreads_url = method()
            except Exception as e:
                print(f"⚠️ Error during '{label}': {e}")
                goodreads_url = None

            if goodreads_url:
                print(f"✅ Method '{label}' succeeded with URL: {goodreads_url}")
                break
            else:
                print(f"❌ Method '{label}' failed to find a result.")

        if goodreads_url:
            try:
                headers = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}
                book_info, author_folder = scrape_book(goodreads_url, book_url_local, headers)

                if not search_book_id(book_info['id']) and not check_book_id(book_info['id'], CSV_FILE):
                    success = process_scraped_book(book_info, epub_path, CSV_FILE, author_folder, book_url_local)
                    if success:
                        processed_books += 1
                        print(f'✅ Ebook {current_book} of {total_epub_files}: Processing {bookname} completed! (Total processed: {processed_books})')
                    else:
                        skipped_books += 1
                else:
                    print(f"🔄 Ebook {current_book} of {total_epub_files}: {book_info['title']} already in database, deleting file...")
                    try:
                        os.remove(epub_path)
                    except Exception as e:
                        print(f"⚠️ Could not delete file {epub_path}: {e}")
                    already_added_books += 1
            except Exception as e:
                print(f"❌ Error scraping from Goodreads: {e}")
                skipped_books += 1
        else:
            print(f"❌ Ebook {current_book} of {total_epub_files}: No Goodreads URL found for '{bookname}'")
            skipped_books += 1

# === Final Summary ===
end_time = time.time()
duration = end_time - start_time
hours, remainder = divmod(duration, 3600)
minutes, seconds = divmod(remainder, 60)

print("\n" + "=" * 60)
print("📊 PROCESSING SUMMARY")
print("=" * 60)
print(f"📚 Total EPUB files found: {total_epub_files}")
print(f"✅ Successfully processed: {processed_books}")
print(f"🔄 Already in database (deleted): {already_added_books}")
print(f"⚠️  Skipped due to missing info or errors: {skipped_books}")
print(f"📈 Success rate: {(processed_books / total_epub_files * 100):.1f}%" if total_epub_files else "📈 Success rate: 0%")
print("=" * 60)
print(f"⏱️  Total time taken: {int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}")
print("=" * 60)

# %%
# ==== Your existing constants ====
BOOKS_FOLDER = os.path.join(os.getcwd(), 'books')
CSV_FILE = os.path.join(BOOKS_FOLDER, 'final_allbooks.csv')

# ==== MySQL Connection (XAMPP) ====
conn = mysql.connector.connect(
    host="localhost",     # XAMPP MySQL host
    user="root",          # XAMPP MySQL username
    password="",          # XAMPP MySQL password (empty by default)
    database="final_klaus_ebooks_library"
)
cursor = conn.cursor()

# ==== MySQL Check if Book Exists ====
def check_book_url_id(book_id):
    """
    Checks if a book with the given URL already exists in MySQL.
    """
    cursor.execute("SELECT COUNT(*) FROM books WHERE id = %s", (book_id,))
    count = cursor.fetchone()[0]
    return count > 0

# ==== MySQL Insert Function ====
def insert_book_to_mysql(book_data):
    try:
        insert_query = """
            INSERT INTO books (
                id, cat_id, sub_cat_id, author_ids, book_access,
                title, description, image, url_type, url,
                download_enable, book_on_rent, book_rent_price, book_rent_time,
                featured, status
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """
        cursor.execute(insert_query, (
            book_data.get("id", ""),
            book_data.get("cat_id", ""),
            book_data.get("sub_cat_id", ""),
            book_data.get("author_ids", ""),
            book_data.get("book_access", ""),
            book_data.get("title", ""),
            book_data.get("description", ""),
            book_data.get("image", ""),
            book_data.get("url_type", ""),
            book_data.get("url", ""),
            book_data.get("download_enable", ""),
            book_data.get("book_on_rent", ""),
            book_data.get("book_rent_price", ""),
            book_data.get("book_rent_time", ""),
            book_data.get("featured", ""),
            book_data.get("status", "")
        ))
        conn.commit()
        print(f"📚 Book '{book_data.get('title', '')}' inserted into MySQL successfully.")
    except Exception as e:
        print(f"❌ MySQL insert error: {e}")

# ==== Read CSV ====
csv_file = csv.reader(open('_final1.csv', "r", encoding='utf-8'), delimiter=",")
next(csv_file)  # Skip header row

# Count total rows for progress display
with open('_final1.csv', "r", encoding='utf-8') as f:
    total_epub_files = sum(1 for _ in f) - 1  # minus header

counter = 0

# ==== Main Loop ====
for i, row in enumerate(csv_file):
    if i >= 1200:  # Limit for testing
        break
    if row:
        counter += 1
        author_book_id = row[0].strip()
        cat_id = row[1].strip() if len(row) > 1 else ""
        sub_cat_id = row[2].strip() if len(row) > 2 else ""
        author_ids = row[3].strip() if len(row) > 3 else ""
        book_access = row[4].strip() if len(row) > 4 else ""
        title = row[5].strip() if len(row) > 5 else ""
        description = row[6].strip() if len(row) > 6 else ""
        image = row[7].strip() if len(row) > 7 else ""
        url_type = row[8].strip() if len(row) > 8 else ""
        book_url_local = row[9].strip() if len(row) > 9 else ""
        download_enable = row[10].strip() if len(row) > 10 else ""
        book_on_rent = row[11].strip() if len(row) > 11 else ""
        book_rent_price = row[12].strip() if len(row) > 12 else ""
        book_rent_time = row[13].strip() if len(row) > 13 else ""
        featured = row[14].strip() if len(row) > 14 else ""
        status = row[15].strip() if len(row) > 15 else ""

        try:
            goodreads_url = 'https://www.goodreads.com/book/show/' + author_book_id
            headers = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}
            filename = os.path.basename(book_url_local)

            if not check_book_url_id(author_book_id):
                result = search_epub_by_name(filename)
                if result:
                    print(f"✅ Found: {result}")
                    book_info, author_folder = scrape_book(goodreads_url, book_url_local, headers)

                    # Use the scraped book_info instead of CSV data
                    insert_book_to_mysql(book_info)
                    print(f'✅✅✅ Ebook {counter} of {total_epub_files}: "{book_info["title"]}" processed!')
                else:
                    print(f'❌❌ Ebook {counter} of {total_epub_files}: "{title}" not found.')
            else:
                print(f'⏩ Ebook "{title}" already in database.')

        except Exception as e:
            print(f"❌ Error processing row: {e}")

# ==== Close MySQL ====
cursor.close()
conn.close()

print(f'Total books processed: {counter}')
# Out:
# ⏩ Ebook "Nauti Nights" already in database.
# ⏩ Ebook "Mission: Make-Over" already in database.
# ⏩ Ebook "Soul of the Fire" already in database.
# ⏩ Ebook "Hidden Riches" already in database.
# ⏩ Ebook "Carrera's Bride" already in database.
# ⏩ Ebook "Time to Hunt" already in database.
# ⏩ Ebook "Passion's Promise" already in database.
# ⏩ Ebook "Crossings" already in database.
# ⏩ Ebook "Leap of Faith" already in database.
# ⏩ Ebook "Last Sword of Power" already in database.
# ⏩ Ebook "Deryni Checkmate" already in database.
# ⏩ Ebook "The Price of a Bride" already in database.
# ⏩ Ebook "Stray" already in database.
# ⏩ Ebook "Big Girls Don't Cry" already in database.
# ⏩ Ebook "Thick as Thieves" already in database.
# ⏩ Ebook "Gryphon's Eyrie" already in database.
# ⏩ Ebook "Blue Moon Rising" already in database.
# ⏩ Ebook "Without a Trace" already in database.
# ⏩ Ebook "Hero!" already in database.
# ⏩ Ebook "Crewel Lye: A Caustic Yarn" already in database.
# ⏩ Ebook "Acorna's Search" already in database.
# ⏩ Ebook "It" already in database.
# ⏩ Ebook "A Pocket Full of Rye" already in database.
# ⏩ Ebook "Exile's Gate" already in database.
# ⏩ Ebook "A Long Tall Texan Summer" already in database.
# ⏩ Ebook "No Humans Involved" already in database.
# ⏩ Ebook "A Perfect Stranger" already in database.
# ⏩ Ebook "Season of Passion" already in database.
# ⏩ Ebook "Full Circle" already in database.
# ⏩ Ebook "Palomino" already in database.
# ⏩ Ebook "Loving" already in database.
# ⏩ Ebook "Dating Game" already in database.
# ⏩ Ebook "Calling All Creeps!" already in database.
# ⏩ Ebook "One Chance at Love" already in database.
# ⏩ Ebook "Master of Pleasure" already in database.
# ⏩ Ebook "Remembrance of Things Paris: Sixty Years of Writing from Gourmet" already in database.
# ⏩ Ebook "In the Realm of the Wolf" already in database.
# ⏩ Ebook "Carolina Girl" already in database.
# ⏩ Ebook "Sky Full of Promise (The Coltons: Comanche Blood, #6)" already in database.
# ⏩ Ebook "Daddy" already in database.
# ⏩ Ebook "The Wary Transgressor" already in database.
# ⏩ Ebook "Mallory" already in database.
# ⏩ Ebook "Well, Now, My Pretty" already in database.
# ⏩ Ebook "The Paw in the Bottle" already in database.
# ⏩ Ebook "The World in My Pocket" already in database.
# ⏩ Ebook "The Sucker Punch" already in database.
# ⏩ Ebook "In a Vain Shadow" already in database.
# ⏩ Ebook "Just Another Sucker" already in database.
# ⏩ Ebook "A Lotus for Miss Quon" already in database.
# ⏩ Ebook "A House to Let" already in database.
# ⏩ Ebook "Castle Rouge" already in database.
# ⏩ Ebook "Toll the Hounds" already in database.
# ⏩ Ebook "The Grey Horse" already in database.
# ⏩ Ebook "The Book of Kells" already in database.
# ⏩ Ebook "Lens of the World" already in database.
# ⏩ Ebook "Invasion" already in database.
# ⏩ Ebook "Lye Street" already in database.
# ⏩ Ebook "Desperado" already in database.
# ⏩ Ebook "Renegade" already in database.
# ⏩ Ebook "Lord of the Desert" already in database.
# ⏩ Ebook "Fit for a King" already in database.
# ⏩ Ebook "Love with a Long, Tall Texan" already in database.
# ⏩ Ebook "Matt Caldwell: Texas Tycoon" already in database.
# ⏩ Ebook "Night of Love" already in database.
# ⏩ Ebook "A Man of Means" already in database.
# ⏩ Ebook "Passion Flower" already in database.
# ⏩ Ebook "Circle of Gold" already in database.
# ⏩ Ebook "Reluctant Father" already in database.
# ⏩ Ebook "Once In Paris" already in database.
# ⏩ Ebook "Heather's Song" already in database.
# ⏩ Ebook "Cattleman's Pride" already in database.
# ⏩ Ebook "Cattleman's Choice" already in database.
# ⏩ Ebook "His Girl Friday" already in database.
# ⏩ Ebook "Plague Ship" already in database.
# ⏩ Ebook "Deathstalker Return" already in database.
# ⏩ Ebook "Camber the Heretic" already in database.
# ⏩ Ebook "Affaire Royale" already in database.
# ⏩ Ebook "American Gods" already in database.
# ⏩ Ebook "A Killing in the Market" already in database.
# ⏩ Ebook "Needful Things" already in database.
# ⏩ Ebook "Princess of Convenience" already in database.
# ⏩ Ebook "The Birthgrave" already in database.
# ⏩ Ebook "The Mirror of Worlds" already in database.
# ⏩ Ebook "Like a Hole in the Head" already in database.
# ⏩ Ebook "Stormrider" already in database.
# ⏩ Ebook "Prescription: One Husband" already in database.
# ⏩ Ebook "A Royal Proposition" already in database.
# ⏩ Ebook "Prescription - One Bride" already in database.
# ⏩ Ebook "Hijacked Honeymoon" already in database.
# ⏩ Ebook "HER ROYAL BABY" already in database.
# ⏩ Ebook "In Dr Darling's Care" already in database.
# ⏩ Ebook "Love Unspoken" already in database.
# ⏩ Ebook "The Sheikh's Seduction" already in database.
# ⏩ Ebook "What's Better Than Money?" already in database.
# ⏩ Ebook "The Way the Cookie Crumbles" already in database.
# ⏩ Ebook "Trusted Like the Fox" already in database.
# ⏩ Ebook "Why Pick on Me?" already in database.
# ⏩ Ebook "Eve" already in database.
# ⏩ Ebook "Femme Fatale" already in database.
# ⏩ Ebook "Child of Thunder" already in database.
# ⏩ Ebook "The Western Wizard" already in database.
# ⏩ Ebook "The Last of the Renshai" already in database.
# ⏩ Ebook "The Plot" already in database.
# ⏩ Ebook "Saying Yes to the Boss" already in database.
# ⏩ Ebook "The Sorcerers' Plague" already in database.
# ⏩ Ebook "The White Order" already in database.
# ⏩ Ebook "Final Cut" already in database.
# ⏩ Ebook "See No Evil" already in database.
# ⏩ Ebook "Cult of Crime" already in database.
# ⏩ Ebook "Line of Fire" already in database.
# ⏩ Ebook "The Pacific Conspiracy" already in database.
# ⏩ Ebook "The Deadliest Dare" already in database.
# ⏩ Ebook "Trouble in the Pipeline" already in database.
# ⏩ Ebook "Street Spies" already in database.
# ⏩ Ebook "The Borderline Case" already in database.
# ⏩ Ebook "Deathgame" already in database.
# ⏩ Ebook "The Crowning Terror" already in database.
# ⏩ Ebook "Blood Money" already in database.
# ⏩ Ebook "The Number File" already in database.
# ⏩ Ebook "Strategic Moves" already in database.
# ⏩ Ebook "Collision Course" already in database.
# ⏩ Ebook "Castle Fear" already in database.
# ⏩ Ebook "Disaster for Hire" already in database.
# ⏩ Ebook "Hostages of Hate" already in database.
# ⏩ Ebook "Perfect Getaway" already in database.
# ⏩ Ebook "Too Many Traitors" already in database.
# ⏩ Ebook "Highway Robbery" already in database.
# ⏩ Ebook "Running on Empty" already in database.
# ⏩ Ebook "Last Laugh" already in database.
# ⏩ Ebook "Witness to Murder" already in database.
# ⏩ Ebook "Blood Relations" already in database.
# ⏩ Ebook "Countdown to Terror" already in database.
# ⏩ Ebook "The Early Asimov: Volume 1" already in database.
# ⏩ Ebook "Enamored" already in database.
# ⏩ Ebook "Sutton's Way" already in database.
# ⏩ Ebook "Emmett" already in database.
# ⏩ Ebook "Callaghan's Bride" already in database.
# ⏩ Ebook "Calhoun" already in database.
# ⏩ Ebook "Donavan" already in database.
# ⏩ Ebook "Evan" already in database.
# ⏩ Ebook "Harden" already in database.
# ⏩ Ebook "Regan's Pride" already in database.
# ⏩ Ebook "Child of a Dead God" already in database.
# ⏩ Ebook "Dancing With Werewolves" already in database.
# ⏩ Ebook "The Vulture Is a Patient Bird" already in database.
# ⏩ Ebook "The Gathering Storm" already in database.
# ⏩ Ebook "Darkhenge" already in database.
# ⏩ Ebook "The Scarab" already in database.
# ⏩ Ebook "A Wilderness Christmas" already in database.
# ⏩ Ebook "Gryphon in Glory" already in database.
# ⏩ Ebook "Ware Hawk" already in database.
# ⏩ Ebook "Horn Crown" already in database.
# ⏩ Ebook "Postmarked the Stars" already in database.
# ⏩ Ebook "Three Against the Witch World" already in database.
# ⏩ Ebook "Key Out of Time" already in database.
# ⏩ Ebook "Derelict for Trade" already in database.
# ⏩ Ebook "Playing for Pizza" already in database.
# ⏩ Ebook "Dolores Claiborne / Nightmares and Dreamscapes" already in database.
# ⏩ Ebook "Tagged for Terror" already in database.
# ⏩ Ebook "Evil, Inc." already in database.
# ⏩ Ebook "The Lazarus Plot" already in database.
# ⏩ Ebook "The Wise Man's Fear" already in database.
# ⏩ Ebook "His Cinderella Mistress" already in database.
# ⏩ Ebook "Lady Surrender" already in database.
# ⏩ Ebook "The Shining" already in database.
# ⏩ Ebook "A Thousand Suns" already in database.
# ⏩ Ebook "Perilous Seas" already in database.
# ⏩ Ebook "Rescued by a Millionaire" already in database.
# ⏩ Ebook "Killer Heat" already in database.
# ⏩ Ebook "Most Eligible Doctor" already in database.
# ⏩ Ebook "Heart Mate" already in database.
# ⏩ Ebook "Heart Quest" already in database.
# ⏩ Ebook "Heart Choice" already in database.
# ⏩ Ebook "The Appeal" already in database.
# ⏩ Ebook "Irene At Large" already in database.
# ⏩ Ebook "The Greek's Chosen Wife" already in database.
# ⏩ Ebook "The Belly of the Wolf" already in database.
# ⏩ Ebook "The Third Eagle" already in database.
# ⏩ Ebook "Ghost Beach" already in database.
# ⏩ Ebook "Shadowfire" already in database.
# ⏩ Ebook "Impossible Dreams" already in database.
# ⏩ Ebook "Fires of Azeroth" already in database.
# ⏩ Ebook "Succubus on Top" already in database.
# ⏩ Ebook "Quest for the White Witch" already in database.
# ⏩ Ebook "The Blob That Ate Everyone" already in database.
# ⏩ Ebook "The Midwife's Marriage Proposal" already in database.
# ⏩ Ebook "The Pearls" already in database.
# ⏩ Ebook "A Christmas Affair" already in database.
# ⏩ Ebook "The Sheikh's Innocent Bride" already in database.
# ⏩ Ebook "An Arabian Courtship" already in database.
# ⏩ Ebook "The Sicilian's Mistress" already in database.
# ⏩ Ebook "Alien Vengeance" already in database.
# ⏩ Ebook "Applying the Kingdom: Rediscovering the Priority of God for Mankind" already in database.
# ⏩ Ebook "A Lick of Frost" already in database.
# ⏩ Ebook "The Sheikh's Wife" already in database.
# ⏩ Ebook "Vampires are Forever" already in database.
# ⏩ Ebook "Vampire, Interrupted" already in database.
# ⏩ Ebook "The Accidental Vampire" already in database.
# ⏩ Ebook "A Heartless Marriage" already in database.
# ⏩ Ebook "Plum Lucky" already in database.
# ⏩ Ebook "Answered Prayers" already in database.
# ⏩ Ebook "Bittersweet" already in database.
# ⏩ Ebook "Daddy" already in database.
# ⏩ Ebook "Marriage in Name Only" already in database.
# ⏩ Ebook "Before the Golden Age: A Science Fiction Anthology of the 1930s" already in database.
# ⏩ Ebook "That Touch of Pink" already in database.
# ⏩ Ebook "At the Millionaire's Request" already in database.
# ⏩ Ebook "Dark Wraith of Shannara" already in database.
# ⏩ Ebook "A State of Disobedience" already in database.
# ⏩ Ebook "A Passionate Surrender" already in database.
# ⏩ Ebook "Far from Over" already in database.
# ⏩ Ebook "The Italian's Price" already in database.
# ⏩ Ebook "The Billionaire's Bride" already in database.
# ⏩ Ebook "Personal Demon" already in database.
# ⏩ Ebook "The Texas Ranger" already in database.
# ⏩ Ebook "Damiano" already in database.
# ⏩ Ebook "Rogue's Lady" already in database.
# ⏩ Ebook "Remember the Magic" already in database.
# ⏩ Ebook "And Less than Kind" already in database.
# ⏩ Ebook "Not Safe to be Free" already in database.
# ⏩ Ebook "But a Short Time to Live" already in database.
# ⏩ Ebook "Consider Yourself Dead" already in database.
# ⏩ Ebook "Warlock of the Witch World" already in database.
# ⏩ Ebook "Aiden's Charity" already in database.
# ⏩ Ebook "Cross Country" already in database.
# ⏩ Ebook "Firefly Island" already in database.
# ⏩ Ebook "SUNDAY GENTLEMAN" already in database.
# ⏩ Ebook "Wolf in Shadow" already in database.
# ⏩ Ebook "The Last Honest Woman" already in database.
# ⏩ Ebook "Destiny Kills" already in database.
# ⏩ Ebook "The Oxford Dictionary of Modern Quotations" already in database.
# ⏩ Ebook "A Desert Called Peace" already in database.
# ⏩ Ebook "Redline The Stars" already in database.
# ⏩ Ebook "Night Life" already in database.
# ⏩ Ebook "The Gap Into Madness: Chaos and Order" already in database.
# ⏩ Ebook "The Magic Thief" already in database.
# ⏩ Ebook "Magic Burns" already in database.
# ⏩ Ebook "Wedding Spell" already in database.
# ⏩ Ebook "Magical Memories" already in database.
# ⏩ Ebook "Zero Minus Ten" already in database.
# ⏩ Ebook "Eternity in Death" already in database.
# ⏩ Ebook "I Hold the Four Aces" already in database.
# ⏩ Ebook "A Can of Worms" already in database.
# ⏩ Ebook "The Dead Stay Dumb" already in database.
# ⏩ Ebook "I'll Get You for This" already in database.
# ⏩ Ebook "You're Lonely When You're Dead" already in database.
# ⏩ Ebook "Want to Stay Alive?" already in database.
# ⏩ Ebook "You Find Him, I'll Fix Him" already in database.
# ⏩ Ebook "Believed Violent" already in database.
# ⏩ Ebook "The Things Men Do" already in database.
# ⏩ Ebook "Heart of the Mirage" already in database.
# ⏩ Ebook "Song of the Shiver Barrens" already in database.
# ⏩ Ebook "A No Risk Affair" already in database.
# ⏩ Ebook "Fear of Love" already in database.
# ⏩ Ebook "Ill Met in the Arena" already in database.
# ⏩ Ebook "Shadow Gate" already in database.
# ⏩ Ebook "To Kiss a Sheik" already in database.
# ⏩ Ebook "Miss Shumway Waves a Wand" already in database.
# ⏩ Ebook "Tyler" already in database.
# ⏩ Ebook "Justin" already in database.
# ⏩ Ebook "The Tender Stranger" already in database.
# ⏩ Ebook "Night Shift" already in database.
# ⏩ Ebook "Valentine's Night" already in database.
# ⏩ Ebook "Don't Hex with Texas" already in database.
# ⏩ Ebook "Tribute" already in database.
# ⏩ Ebook "Foreign Body" already in database.
# ⏩ Ebook "The Moonlight Pegasus" already in database.
# ⏩ Ebook "The Immortal Prince" already in database.
# ⏩ Ebook "The Runaway Jury" already in database.
# ⏩ Ebook "Miracle on the 17th Green" already in database.
# ⏩ Ebook "The Darkest Kiss" already in database.
# ⏩ Ebook "Tales From the Hood" already in database.
# ⏩ Ebook "A Vengeful Passion" already in database.
# ⏩ Ebook "Iron Cowboy" already in database.
# ⏩ Ebook "Goodbye 20th Century: A Biography of Sonic Youth" already in database.
# ⏩ Ebook "Carnifex" already in database.
# ⏩ Ebook "Siege of Heaven" already in database.
# ⏩ Ebook "Tree and Leaf: Including the Poem Mythopoeia" already in database.
# ⏩ Ebook "Last Light" already in database.
# ⏩ Ebook "The Time Paradox" already in database.
# ⏩ Ebook "Daemons Are Forever" already in database.
# ⏩ Ebook "The Spy Who Haunted Me" already in database.
# ⏩ Ebook "Fractured" already in database.
# ⏩ Ebook "The Greek's Convenient Wife" already in database.
# ⏩ Ebook "You've Got It Coming" already in database.
# ⏩ Ebook "Nauti Dreams" already in database.
# ⏩ Ebook "Red Bird" already in database.
# ⏩ Ebook "Fearless Fourteen" already in database.
# ⏩ Ebook "This Kiss" already in database.
# ⏩ Ebook "Acheron" already in database.
# ⏩ Ebook "Heart Dance" already in database.
# ⏩ Ebook "Armed & Magical" already in database.
# ⏩ Ebook "The Shadow Isle" already in database.
# ⏩ Ebook "Rogue" already in database.
# ⏩ Ebook "Turncoat" already in database.
# ⏩ Ebook "Provenance" already in database.
# ⏩ Ebook "The Perfect Mom" already in database.
# ⏩ Ebook "The Fabulous Showman: The Life and Times of P. T. Barnum" already in database.
# ⏩ Ebook "The Last Celtic Witch" already in database.
# ⏩ Ebook "Ink and Steel" already in database.
# ⏩ Ebook "Hell and Earth" already in database.
# ⏩ Ebook "Her L. A. Knight" already in database.
# ⏩ Ebook "Midnight Seduction" already in database.
# ⏩ Ebook "The Desert Sheikh's Captive Wife" already in database.
# ⏩ Ebook "The Gods of Amyrantha" already in database.
# ⏩ Ebook "The Palace of Impossible Dreams" already in database.
# ⏩ Ebook "The Heiress and the Sheriff" already in database.
# ⏩ Ebook "Little Girl Found" already in database.
# ⏩ Ebook "Return of the Crimson Guard" already in database.
# ⏩ Ebook "Monster Blood For Breakfast!" already in database.
# ⏩ Ebook "Major Attraction" already in database.
# ⏩ Ebook "Out of the Night" already in database.
# ⏩ Ebook "The Friendship Barrier" already in database.
# ⏩ Ebook "Because Your Vampire Said So" already in database.
# ⏩ Ebook "Sturmnacht" already in database.
# ⏩ Ebook "Dark Deceiver" already in database.
# ⏩ Ebook "The Unexpected Baby" already in database.
# ⏩ Ebook "The Recovery Assignment" already in database.
# ⏩ Ebook "Consultant In Crisis" already in database.
# ⏩ Ebook "One Night in Emergency" already in database.
# ⏩ Ebook "The Game Show Bride" already in database.
# ⏩ Ebook "Backup" already in database.
# ⏩ Ebook "The New Man" already in database.
# ⏩ Ebook "Jack Murray, Sheriff" already in database.
# ⏩ Ebook "Granny Dan" already in database.
# ⏩ Ebook "Coltrain's Proposal - Pinangan Coltrain" already in database.
# ⏩ Ebook "A Husband in Her Eyes" already in database.
# ⏩ Ebook "Mommy Said Goodbye" already in database.
# ⏩ Ebook "Danse Macabre" already in database.
# ⏩ Ebook "Pure Blood" already in database.
# ⏩ Ebook "Love's Only Deception" already in database.
# ⏩ Ebook "Lovers in the Afternoon" already in database.
# ⏩ Ebook "Prince's Love-Child" already in database.
# ⏩ Ebook "Scene of the Crime" already in database.
# ⏩ Ebook "The Gypsy Morph" already in database.
# ⏩ Ebook "Forgotten Passion" already in database.
# ⏩ Ebook "A Reason for Being" already in database.
# ⏩ Ebook "Levelling the Score" already in database.
# ⏩ Ebook "Payment in Love" already in database.
# ⏩ Ebook "The Rancher's Bride" already in database.
# ⏩ Ebook "The Darkest Pleasure" already in database.
# ⏩ Ebook "Just the Man She Needed" already in database.
# ⏩ Ebook "Willow" already in database.
# ⏩ Ebook "The Brass Verdict" already in database.
# ⏩ Ebook "The Hero of Ages" already in database.
# ⏩ Ebook "Once Upon a Pregnancy" already in database.
# ⏩ Ebook "A Royal Marriage of Convenience" already in database.
# ⏩ Ebook "The Summoning" already in database.
# ⏩ Ebook "An Echo in the Bone" already in database.
# ⏩ Ebook "Adopt-a-Dad" already in database.
# ⏩ Ebook "Doctor on Loan" already in database.
# ⏩ Ebook "Bachelor Cure" already in database.
# ⏩ Ebook "Unfriendly Alliance" already in database.
# ⏩ Ebook "Come Easy Go Easy" already in database.
# ⏩ Ebook "Blood Memories" already in database.
# ⏩ Ebook "The Mammoth Book of Vampire Romance" already in database.
# ⏩ Ebook "Lightning'S Lady" already in database.
# ⏩ Ebook "Doomwyte" already in database.
# ⏩ Ebook "Wolfsbane and Mistletoe" already in database.
# ⏩ Ebook "Desire for Revenge" already in database.
# ⏩ Ebook "Pria Penuh Teka-Teki [An Enigmatic Man]" already in database.
# ⏩ Ebook "Armed and Devastating" already in database.
# ⏩ Ebook "A Good Woman" already in database.
# ⏩ Ebook "Tergila-gila Padamu / Crazy for Lovin You" already in database.
# ⏩ Ebook "Percayalah Padaku" already in database.
# ⏩ Ebook "Jutawan Pilihan Molly" already in database.
# ⏩ Ebook "The Phoenix Endangered" already in database.
# ⏩ Ebook "Hired: The Sheikh's Secretary Mistress" already in database.
# ⏩ Ebook "The Devil's Punchbowl" already in database.
# ⏩ Ebook "The Rogue Hunter" already in database.
# ⏩ Ebook "The Doctor's Pregnancy Bombshell" already in database.
# ⏩ Ebook "Eon: Dragoneye Reborn" already in database.
# ⏩ Ebook "Gabriel's Horn" already in database.
# ⏩ Ebook "Ethan" already in database.
# ⏩ Ebook "Edge of Destruction" already in database.
# ⏩ Ebook "Fated Attraction" already in database.
# ⏩ Ebook "Brimstone Kiss" already in database.
# ⏩ Ebook "Ice in His Veins" already in database.
# ⏩ Ebook "Darkness Into Light" already in database.
# ⏩ Ebook "Pagan Enchantment" already in database.
# ⏩ Ebook "Fantasy Girl" already in database.
# ⏩ Ebook "After the Loving" already in database.
# ⏩ Ebook "Married by Christmas" already in database.
# ⏩ Ebook "Plague Ship / Voodoo Planet" already in database.
# ⏩ Ebook "Hostage to Pleasure" already in database.
# ⏩ Ebook "Accidentally Dead" already in database.
# ⏩ Ebook "All the Windwracked Stars" already in database.
# ⏩ Ebook "The Heart Surgeon's Secret Son" already in database.
# ⏩ Ebook "Run for Your Life" already in database.
# ⏩ Ebook "A SPANISH VENGEANCE" already in database.
# ⏩ Ebook "A Suspicious Proposal" already in database.
# ⏩ Ebook "A Spanish Marriage" already in database.
# ⏩ Ebook "Response" already in database.
# ⏩ Ebook "Man and Wife" already in database.
# ⏩ Ebook "A Virgin For The Taking" already in database.
# ⏩ Ebook "Passion Becomes You" already in database.
# ⏩ Ebook "The Nurse's Rescue" already in database.
# ⏩ Ebook "Without Trust" already in database.
# ⏩ Ebook "Permission to Love" already in database.
# ⏩ Ebook "Destiny Paradise" already in database.
# ⏩ Ebook "Against Medical Advice" already in database.
# ⏩ Ebook "Gracious Lady" already in database.
# ⏩ Ebook "Ritual in Death" already in database.
# ⏩ Ebook "Beloved Intruder" already in database.
# ⏩ Ebook "The Hollow" already in database.
# ⏩ Ebook "Four Past Midnight: The Sun Dog" already in database.
# ⏩ Ebook "Plum Spooky" already in database.
# ⏩ Ebook "The Warded Man" already in database.
# ⏩ Ebook "Forever Princess" already in database.
# ⏩ Ebook "In Shade and Shadow" already in database.
# ⏩ Ebook "Wait Till Your Vampire Gets Home" already in database.
# ⏩ Ebook "A Spanish Affair" already in database.
# ⏩ Ebook "The Celtic Witch and the Sorcerer" already in database.
# ⏩ Ebook "One Day at a Time" already in database.
# ⏩ Ebook "The Associate" already in database.
# ⏩ Ebook "A Honeyed Seduction" already in database.
# ⏩ Ebook "It Takes Three" already in database.
# ⏩ Ebook "Midnight, Moonlight & Miracles" already in database.
# ⏩ Ebook "Blood Sins" already in database.
# ⏩ Ebook "A Pretend Engagement" already in database.
# ⏩ Ebook "Coyote's Mate" already in database.
# ⏩ Ebook "Nauti Intentions" already in database.
# ⏩ Ebook "The Horsemen's Gambit" already in database.
# ⏩ Ebook "Just Another Judgement Day" already in database.
# ⏩ Ebook "A Husband's Price" already in database.
# ⏩ Ebook "Angels' Blood" already in database.
# ⏩ Ebook "Do Me a Favour -Drop Dead" already in database.
# ⏩ Ebook "At the Sicilian Count's Command" already in database.
# ⏩ Ebook "Bought: The Greek's Innocent Virgin" already in database.
# ⏩ Ebook "A Drop of Red" already in database.
# ⏩ Ebook "Darkness Unknown" already in database.
# ⏩ Ebook "The Tales of Beedle the Bard" already in database.
# ⏩ Ebook "The Demigod Files" already in database.
# ⏩ Ebook "Letter to My Daughter" already in database.
# ⏩ Ebook "Traitors' Gate" already in database.
# ⏩ Ebook "Frostbitten" already in database.
# ⏩ Ebook "8th Confession" already in database.
# ⏩ Ebook "The Truro Bear and Other Adventures: Poems and Essays" already in database.
# ⏩ Ebook "Magic Strikes" already in database.
# ⏩ Ebook "Fractured" already in database.
# ⏩ Ebook "Heart of a Warlock" already in database.
# ⏩ Ebook "A Guilty Affair" already in database.
# ⏩ Ebook "A Mere Formality" already in database.
# ⏩ Ebook "Gone Tomorrow" already in database.
# ⏩ Ebook "Second Skin" already in database.
# ⏩ Ebook "Spanish Doctor, Pregnant Nurse" already in database.
# ⏩ Ebook "The Scarecrow" already in database.
# ⏩ Ebook "Pride" already in database.
# ⏩ Ebook "Lethal Legacy" already in database.
# ⏩ Ebook "Fire Raiser" already in database.
# ⏩ Ebook "Imager" already in database.
# ⏩ Ebook "Virgin: Wedded at the Italian's Convenience" already in database.
# ⏩ Ebook "Dust of Dreams" already in database.
# ⏩ Ebook "A High Price to Pay" already in database.
# ⏩ Ebook "Ashes of Midnight" already in database.
# ⏩ Ebook "The Everafter War" already in database.
# ⏩ Ebook "Polar Quest" already in database.
# ⏩ Ebook "The Mammoth Book of Paranormal Romance" already in database.
# ⏩ Ebook "Glimmers: Prologue to Crossroads of Twilight" already in database.
# ⏩ Ebook "Best of Makeovers Bundle: The Cinderella Project\When the Lights Go Down\Cruise Control\Her Wildest Dreams\Texas Fire\Breathless Passion" already in database.
# ⏩ Ebook "Succubus Heat" already in database.
# ⏩ Ebook "Dead and Gone" already in database.
# ⏩ Ebook "Were-Wrath" already in database.
# ⏩ Ebook "Heart's Fury" already in database.
# ⏩ Ebook "The Trouble with Demons" already in database.
# ⏩ Ebook "Don't Judge a Girl by Her Cover" already in database.
# ⏩ Ebook "The Shadow of Tyr" already in database.
# ⏩ Ebook "Conspirator" already in database.
# ⏩ Ebook "The Awakening" already in database.
# ⏩ Ebook "The Alchemist's Pursuit" already in database.
# ⏩ Ebook "Swimsuit" already in database.
# ⏩ Ebook "Bengal's Heart" already in database.
# ⏩ Ebook "Burning Wild" already in database.
# ⏩ Ebook "October Skies" already in database.
# ⏩ Ebook "A Vow A Ring A Baby Swing" already in database.
# ⏩ Ebook "Across the bridge" already in database.
# ⏩ Ebook "Italian Doctor, Full-time Father" already in database.
# ⏩ Ebook "Lost" already in database.
# ⏩ Ebook "The Murder of King Tut" already in database.
# ⏩ Ebook "Julius Caesar" already in database.
# ⏩ Ebook "Dark Places" already in database.
# ⏩ Ebook "Kindred in Death" already in database.
# ⏩ Ebook "The Chaos Crystal" already in database.
# ⏩ Ebook "Cowboy for Keeps" already in database.
# ⏩ Ebook "Matters of the Heart" already in database.
# ⏩ Ebook "A Taste of Magic" already in database.
# ⏩ Ebook "Desire Untamed" already in database.
# ⏩ Ebook "Finger Lickin' Fifteen" already in database.
# ⏩ Ebook "Where the Heart Is" already in database.
# ⏩ Ebook "Bad Moon Rising" already in database.
# ⏩ Ebook "Getting Lucky" already in database.
# ⏩ Ebook "Beyond Compare" already in database.
# ⏩ Ebook "Diamond in the Rough" already in database.
# ⏩ Ebook "The Surgeon's Rescue Mission" already in database.
# ⏩ Ebook "With a Southern Touch: WITH Adam AND Garden Cop AND A Night in Paradise" already in database.
# ⏩ Ebook "White Cat" already in database.
# ⏩ Ebook "A Series of Unfortunate Events Pack" already in database.
# ⏩ Ebook "Byron in Love" already in database.
# ⏩ Ebook "Eternal Journey" already in database.
# ⏩ Ebook "Prey" already in database.
# ⏩ Ebook "Demon Inside" already in database.
# ⏩ Ebook "The Maze Runner" already in database.
# ⏩ Ebook "Escape From Desire" already in database.
# ⏩ Ebook "A Touch of Dead" already in database.
# ⏩ Ebook "The Iron Thorn" already in database.
# ⏩ Ebook "The Renegade Hunter" already in database.
# ⏩ Ebook "Obsession Untamed" already in database.
# ⏩ Ebook "Witch Craft" already in database.
# ⏩ Ebook "Unholy Ghosts" already in database.
# ⏩ Ebook "Alex Cross's Trial" already in database.
# ⏩ Ebook "Artemis Fowl and the Time Paradox" already in database.
# ⏩ Ebook "Lovers Touch" already in database.
# ⏩ Ebook "The Baby Emergency" already in database.
# ⏩ Ebook "Tall, Dark & Fangsome" already in database.
# ⏩ Ebook "Hot for the Holidays" already in database.
# ⏩ Ebook "A Bad Enemy" already in database.
# ⏩ Ebook "Mistaken Adversary" already in database.
# ⏩ Ebook "Passion Untamed" already in database.
# ⏩ Ebook "Heart Change" already in database.
# ⏩ Ebook "Passionate Scandal" already in database.
# ⏩ Ebook "The Unusual Suspects" already in database.
# ⏩ Ebook "The Law of Nines" already in database.
# ⏩ Ebook "Marrying the Virgin Nanny" already in database.
# ⏩ Ebook "Friday Night Bites" already in database.
# ⏩ Ebook "Under the Dome" already in database.
# ⏩ Ebook "The Accidental Billionaires: The Founding of Facebook, a Tale of Sex, Money, Genius, and Betrayal" already in database.
# ⏩ Ebook "Pleasure of a Dark Prince" already in database.
# ⏩ Ebook "Apocalypse Happens" already in database.
# ⏩ Ebook "Blood Game" already in database.
# ⏩ Ebook "The Legend of Sigurd & Gudrún" already in database.
# ⏩ Ebook "The Phoenix Transformed" already in database.
# ⏩ Ebook "Half Broke Horses" already in database.
# ⏩ Ebook "The Mammoth Book of Vampire Romance 2: Love Bites" already in database.
# ⏩ Ebook "The Vásquez Baby" already in database.
# ⏩ Ebook "Passionate Relationship" already in database.
# ⏩ Ebook "By the Mountain Bound" already in database.
# ⏩ Ebook "I, Alex Cross" already in database.
# ⏩ Ebook "Imager's Challenge" already in database.
# ⏩ Ebook "Pregnant with the Billionaire's Baby" already in database.
# ⏩ Ebook "Nine Dragons" already in database.
# ⏩ Ebook "Footprints" already in database.
# ⏩ Ebook "Alpha" already in database.
# ⏩ Ebook "Chaosbound" already in database.
# ⏩ Ebook "Vampire Sunrise" already in database.
# ⏩ Ebook "Magic Bleeds" already in database.
# ⏩ Ebook "The Mortal Instruments Boxed Set: City of Bones; City of Ashes; City of Glass" already in database.
# ⏩ Ebook "Jumper Cable" already in database.
# ⏩ Ebook "Tickle My Fantasy" already in database.
# ⏩ Ebook "Missing in Death" already in database.
# ⏩ Ebook "Born to Bite" already in database.
# ⏩ Ebook "Hungry for You" already in database.
# ⏩ Ebook "Gnomes of Suburbia" already in database.
# ⏩ Ebook "Finding Fiona" already in database.
# ⏩ Ebook "Gnomes of Suburbia" already in database.
# ⏩ Ebook "Haunting Hannah" already in database.
# ⏩ Ebook "Overcoming Crisis: The Secrets to Thriving in Challenging Times" already in database.
# ⏩ Ebook "Tales of the Otherworld" already in database.
# ⏩ Ebook "The Winner Stands Alone" already in database.
# ⏩ Ebook "The Carole Mortimer Collection: A Lost Love / A Past Revenge" already in database.
# ⏩ Ebook "The Ragged Man" already in database.
# ⏩ Ebook "Archangel's Kiss" already in database.
# ⏩ Ebook "The Silver Mage" already in database.
# ⏩ Ebook "Accidentally Demonic" already in database.
# ⏩ Ebook "Nauti Deceptions" already in database.
# ⏩ Ebook "Paradox" already in database.
# ⏩ Ebook "I'll Bury My Dead" already in database.
# ⏩ Ebook "Demon Possessed" already in database.
# ⏩ Ebook "The Mammoth Book of Special Ops Romance" already in database.
# ⏩ Ebook "Through Stone and Sea" already in database.
# ⏩ Ebook "Chasing Carolyn" already in database.
# ⏩ Ebook "Hot Rocks" already in database.
# ⏩ Ebook "Much Fall of Blood" already in database.
# ⏩ Ebook "The Good, the Bad, and the Uncanny" already in database.
# ⏩ Ebook "Eight Days To Live" already in database.
# ⏩ Ebook "Prince's Passion" already in database.
# ⏩ Ebook "The Desert Spear" already in database.
# ⏩ Ebook "Fire With Fire" already in database.
# ⏩ Ebook "Amazing Grace / Honor Thyself / Rogue" already in database.
# ⏩ Ebook "City of Fallen Angels" already in database.
# ⏩ Ebook "Emergency in Alaska" already in database.
# ⏩ Ebook "The Last Stormlord" already in database.
# ⏩ Ebook "You Never Know with Women" already in database.
# ⏩ Ebook "TimeRiders" already in database.
# ⏩ Ebook "Afterlight" already in database.
# ⏩ Ebook "Savor the Moment" already in database.
# ⏩ Ebook "An Artificial Night" already in database.
# ⏩ Ebook "Needles of Stone" already in database.
# ⏩ Ebook "The Trial by Franz Kafka and The Metamorphosis by Franz Kafka" already in database.
# ⏩ Ebook "Faith Of The Fallen" already in database.
# ⏩ Ebook "Abandon" already in database.
# ⏩ Ebook "Archive" already in database.
# ⏩ Ebook "Illusions" already in database.
# ⏩ Ebook "The Mammoth Book of Wolf Men" already in database.
# ⏩ Ebook "The Lotus Eaters" already in database.
# ⏩ Ebook "Found" already in database.
# ⏩ Ebook "Divine Beginnings" already in database.
# ⏩ Ebook "The King of the Crags" already in database.
# ⏩ Ebook "61 Hours" already in database.
# ⏩ Ebook "Masked by Moonlight" already in database.
# ⏩ Ebook "Her Lone Cowboy" already in database.
# ⏩ Ebook "Food Rules: An Eater's Manual" already in database.
# ⏩ Ebook "Betrothed: To the People's Prince" already in database.
# ⏩ Ebook "Chaos Bites" already in database.
# ⏩ Ebook "Keys to the Repository" already in database.
# ⏩ Ebook "Once Burned" already in database.
# ⏩ Ebook "Bonds of Justice" already in database.
# ⏩ Ebook "Twice Bitten" already in database.
# ⏩ Ebook "The Search" already in database.
# ⏩ Ebook "Big Girl" already in database.
# ⏩ Ebook "The Red Pyramid" already in database.
# ⏩ Ebook "From Hell with Love" already in database.
# ⏩ Ebook "Broken" already in database.
# ⏩ Ebook "Demon from the Dark" already in database.
# ⏩ Ebook "Death's Excellent Vacation" already in database.
# ⏩ Ebook "Running Scared" already in database.
# ⏩ Ebook "Hell Gate" already in database.
# ⏩ Ebook "The Oldest Elf" already in database.
# ⏩ Ebook "Cold Magic" already in database.
# ⏩ Ebook "Bayou Moon" already in database.
# ⏩ Ebook "Sidney Sheldon's After the Darkness" already in database.
# ⏩ Ebook "Crack'd Pot Trail" already in database.
# ⏩ Ebook "Bewitched & Betrayed" already in database.
# ⏩ Ebook "The 9th Judgment" already in database.
# ⏩ Ebook "Clockwork Angel" already in database.
# ⏩ Ebook "Crimes by Moonlight: Mysteries from the Dark Side" already in database.
# ⏩ Ebook "The Doctor's Secret Baby" already in database.
# ⏩ Ebook "Crowned: The Palace Nanny" already in database.
# ⏩ Ebook "Spider Bones" already in database.
# ⏩ Ebook "Nightside" already in database.
# ⏩ Ebook "Satanic, Versus" already in database.
# ⏩ Ebook "Actor" already in database.
# ⏩ Ebook "Yours For Eternity" already in database.
# ⏩ Ebook "High on the Hog: A Culinary Journey from Africa to America" already in database.
# ⏩ Ebook "The Way of Kings" already in database.
# ⏩ Ebook "Scarlet Nights" already in database.
# ⏩ Ebook "Dolores Claiborne" already in database.
# ⏩ Ebook "Daughter of Troy" already in database.
# ⏩ Ebook "Bearers of the Black Staff" already in database.
# ⏩ Ebook "Wedding Rings And Baby Things" already in database.
# ⏩ Ebook "Man-Hater" already in database.
# ⏩ Ebook "Crocodile Creek" already in database.
# ⏩ Ebook "All Things Except Blood" already in database.
# ⏩ Ebook "Passionate Protection" already in database.
# ⏩ Ebook "The Darkslayer" already in database.
# ⏩ Ebook "Chased by Moonlight" already in database.
# ⏩ Ebook "Captured by Moonlight" already in database.
# ⏩ Ebook "His Mistress for a Million" already in database.
# ⏩ Ebook "The Innocent's Surrender" already in database.
# ⏩ Ebook "A View to a Kill" already in database.
# ⏩ Ebook "Oprah" already in database.
# ⏩ Ebook "Untamed Lover" already in database.
# ⏩ Ebook "Grey's Ghost" already in database.
# ⏩ Ebook "Indulgence in Death" already in database.
# ⏩ Ebook "Single White Vampire" already in database.
# ⏩ Ebook "The Black Ice" already in database.
# ⏩ Ebook "Dangerous" already in database.
# ⏩ Ebook "No Business of Mine" already in database.
# ⏩ Ebook "The Sleeping Beauty" already in database.
# ⏩ Ebook "Devil Lover" already in database.
# ⏩ Ebook "Origins" already in database.
# ⏩ Ebook "The Lost Hero" already in database.
# ⏩ Ebook "A Memory of Light" already in database.
# ⏩ Ebook "I Am Number Four" already in database.
# ⏩ Ebook "The Scent of Jasmine" already in database.
# ⏩ Ebook "The Skin Map" already in database.
# ⏩ Ebook "A Dinner, a Date, a Desert Sheikh" already in database.
# ⏩ Ebook "The Texas Billionaire's Baby" already in database.
# ⏩ Ebook "10 Minutes to Powerful Prayer" already in database.
# ⏩ Ebook "Stormlord Rising" already in database.
# ⏩ Ebook "One Word Answer" already in database.
# ⏩ Ebook "Play of Passion" already in database.
# ⏩ Ebook "Back to the Moon" already in database.
# ⏩ Ebook "Ghost of a Chance" already in database.
# ⏩ Ebook "Bound to a Warrior" already in database.
# ⏩ Ebook "Cross Fire" already in database.
# ⏩ Ebook "The Master's Mistress" already in database.
# ⏩ Ebook "Forbidden: The Sheikh's Virgin" already in database.
# ⏩ Ebook "Silver Zombie" already in database.
# ⏩ Ebook "The Death Cure" already in database.
# ⏩ Ebook "The Rescue Doctor's Baby Miracle (Medical Romance)" already in database.
# ⏩ Ebook "Chill" already in database.
# ⏩ Ebook "Intrigues" already in database.
# ⏩ Ebook "The Gathering" already in database.
# ⏩ Ebook "The Broken Kingdoms" already in database.
# ⏩ Ebook "Their Child?" already in database.
# ⏩ Ebook "The Kingdom of Gods" already in database.
# ⏩ Ebook "Now You See Her" already in database.
# ⏩ Ebook "The Deputy's Lost and Found" already in database.
# ⏩ Ebook "The Wheel of time series by Robert Jordan" already in database.
# ⏩ Ebook "Max: A Maximum Ride Novel:" already in database.
# ⏩ Ebook "The Confession" already in database.
# ⏩ Ebook "The Reversal" already in database.
# ⏩ Ebook "The Short Second Life of Bree Tanner" already in database.
# ⏩ Ebook "Malcolm X: A Life of Reinvention" already in database.
# ⏩ Ebook "Blockade Billy" already in database.
# ⏩ Ebook "Single, Married, Separated, and Life After Divorce: Expanded Edition" already in database.
# ⏩ Ebook "Convenient Wife, Pleasured Lady" already in database.
# ⏩ Ebook "City Surgeon, Small Town Miracle" already in database.
# ⏩ Ebook "Rainbow Magic" already in database.
# ⏩ Ebook "Memories of Envy" already in database.
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Janice Lynn\Playboy_Surgeon,_Top-Notch_Dad_-_Janice_Lynn.epub
# 📚 Book 'Playboy Surgeon, Top-Notch Dad' inserted into MySQL successfully.
# ✅✅✅ Ebook 701 of 7961: "Playboy Surgeon, Top-Notch Dad" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Alison Goodman\Eona__The_Last_Dragoneye_-_Alison_Goodman.epub
# 📚 Book 'Eona: The Last Dragoneye' inserted into MySQL successfully.
# ✅✅✅ Ebook 702 of 7961: "Eona: The Last Dragoneye" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Penny Jordan\The_Wealthy_Greek's_Contract_Wi_-_Penny_Jordan.epub
# 📚 Book 'The Wealthy Greek's Contract Wife' inserted into MySQL successfully.
# ✅✅✅ Ebook 703 of 7961: "The Wealthy Greek's Contract Wife" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Elizabeth Bear\The_Sea_Thy_Mistress_-_Elizabeth_Bear.epub
# 📚 Book 'The Sea Thy Mistress' inserted into MySQL successfully.
# ✅✅✅ Ebook 704 of 7961: "The Sea Thy Mistress" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Jim  Butcher\Ghost_Story_-_Jim_Butcher.epub
# 📚 Book 'Ghost Story' inserted into MySQL successfully.
# ✅✅✅ Ebook 705 of 7961: "Ghost Story" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Nalini Singh\Archangel's_Blade_-_Nalini_Singh.epub
# 📚 Book 'Archangel's Blade' inserted into MySQL successfully.
# ✅✅✅ Ebook 706 of 7961: "Archangel's Blade" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Patricia Briggs\River_Marked_-_Patricia_Briggs.epub
# 📚 Book 'River Marked' inserted into MySQL successfully.
# ✅✅✅ Ebook 707 of 7961: "River Marked" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Penny Jordan\Marriage__To_Claim_His_Twins_-_Penny_Jordan.epub
# 📚 Book 'Marriage: To Claim his Twins' inserted into MySQL successfully.
# ✅✅✅ Ebook 708 of 7961: "Marriage: To Claim his Twins" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Judy Duarte\And_Babies_Make_Five_-_Judy_Duarte.epub
# 📚 Book 'And Babies Make Five' inserted into MySQL successfully.
# ✅✅✅ Ebook 709 of 7961: "And Babies Make Five" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Melissa de la Cruz\Witches_of_East_End_-_Melissa_de_la_Cruz.epub
# 📚 Book 'Witches of East End' inserted into MySQL successfully.
# ✅✅✅ Ebook 710 of 7961: "Witches of East End" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Charlaine Harris\The_Sookie_Stackhouse_Companion_-_Charlaine_Harris.epub
# 📚 Book 'The Sookie Stackhouse Companion' inserted into MySQL successfully.
# ✅✅✅ Ebook 711 of 7961: "The Sookie Stackhouse Companion" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Carole Mortimer\'Tis_the_Season_-_Carole_Mortimer.epub
# 📚 Book ''Tis the Season: Snowbound with the Billionaire / Twins for Christmas / The Millionaire's Mistletoe Mistress' inserted into MySQL successfully.
# ✅✅✅ Ebook 712 of 7961: "'Tis the Season: Snowbound with the Billionaire / Twins for Christmas / The Millionaire's Mistletoe Mistress" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lara Adrian\Deeper_Than_Midnight_-_Lara_Adrian.epub
# 📚 Book 'Deeper Than Midnight' inserted into MySQL successfully.
# ✅✅✅ Ebook 713 of 7961: "Deeper Than Midnight" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Kresley Cole\MacRieve_(Immortals_After_Dark_-_Kresley_Cole.epub
# 📚 Book 'MacRieve' inserted into MySQL successfully.
# ✅✅✅ Ebook 714 of 7961: "MacRieve" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lee Child\JR14_-_61_Hours_-_Lee_Child.epub
# 📚 Book '61 Hours' inserted into MySQL successfully.
# ✅✅✅ Ebook 715 of 7961: "61 Hours" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Barb Hendee\In_Memories_We_Fear_-_Barb_Hendee.epub
# 📚 Book 'In Memories We Fear' inserted into MySQL successfully.
# ✅✅✅ Ebook 716 of 7961: "In Memories We Fear" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Barb Hendee\Ghosts_of_Memories_-_Barb_Hendee.epub
# 📚 Book 'Ghosts of Memories' inserted into MySQL successfully.
# ✅✅✅ Ebook 717 of 7961: "Ghosts of Memories" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Viola Grace\A_Nexus_Xmas_-_Viola_Grace.epub
# 📚 Book 'A Nexus Xmas' inserted into MySQL successfully.
# ✅✅✅ Ebook 718 of 7961: "A Nexus Xmas" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Robert Jordan\Towers_of_Midnight_-_Robert_Jordan.epub
# 📚 Book 'Towers of Midnight' inserted into MySQL successfully.
# ✅✅✅ Ebook 719 of 7961: "Towers of Midnight" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lora Leigh\Anthology_-_Primal_-_Lora_Leigh_Michelle_Rowan_Jory_Strong_Ava_Gray.epub
# 📚 Book 'Primal' inserted into MySQL successfully.
# ✅✅✅ Ebook 720 of 7961: "Primal" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Simon R. Green\A_Hard_Day's_Knight_-_Simon_R._Green.epub
# 📚 Book 'A Hard Day's Knight' inserted into MySQL successfully.
# ✅✅✅ Ebook 721 of 7961: "A Hard Day's Knight" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Katharine Kerr\Darkspell_-_Katharine_Kerr.epub
# 📚 Book 'Darkspell' inserted into MySQL successfully.
# ✅✅✅ Ebook 722 of 7961: "Darkspell" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Tamora Pierce\Battle_Magic_-_Tamora_Pierce.epub
# 📚 Book 'Battle Magic' inserted into MySQL successfully.
# ✅✅✅ Ebook 723 of 7961: "Battle Magic" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Caitlin Kittredge\Daemon's_Mark_-_Caitlin_Kittredge.epub
# 📚 Book 'Daemon's Mark' inserted into MySQL successfully.
# ✅✅✅ Ebook 724 of 7961: "Daemon's Mark" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Barb Hendee\Of_Truth_and_Beasts_-_Barb_Hendee.epub
# 📚 Book 'Of Truth and Beasts' inserted into MySQL successfully.
# ✅✅✅ Ebook 725 of 7961: "Of Truth and Beasts" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lee Child\Worth_Dying_For_-_Lee_Child.epub
# 📚 Book 'Worth Dying For' inserted into MySQL successfully.
# ✅✅✅ Ebook 726 of 7961: "Worth Dying For" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Maya Banks\Colters'_Daughter__Colters'_Leg_-_Maya_Banks.epub
# 📚 Book 'Colters' Daughter' inserted into MySQL successfully.
# ✅✅✅ Ebook 727 of 7961: "Colters' Daughter" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Judy Duarte\Triplets_Found_-_Judy_Duarte.epub
# 📚 Book 'Triplets Found' inserted into MySQL successfully.
# ✅✅✅ Ebook 728 of 7961: "Triplets Found" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Jackie Braun\America_s_Star-Crossed_Sweethea_-_Jackie_Braun.epub
# 📚 Book 'America's Star-Crossed Sweethearts' inserted into MySQL successfully.
# ✅✅✅ Ebook 729 of 7961: "America's Star-Crossed Sweethearts" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lisa Shearin\All_Spell_Breaks_Loose_-_Lisa_Shearin.epub
# 📚 Book 'All Spell Breaks Loose' inserted into MySQL successfully.
# ✅✅✅ Ebook 730 of 7961: "All Spell Breaks Loose" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Kim Lawrence\Sophie_and_the_Scorching_Sicili_-_Kim_Lawrence.epub
# 📚 Book 'Sophie and the Scorching Sicilian' inserted into MySQL successfully.
# ✅✅✅ Ebook 731 of 7961: "Sophie and the Scorching Sicilian" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Ian C. Esslemont\Stonewielder.ePub
# 📚 Book 'Stonewielder' inserted into MySQL successfully.
# ✅✅✅ Ebook 732 of 7961: "Stonewielder" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\James Patterson\Tick_Tock_-_James_Patterson.epub
# 📚 Book 'Tick Tock' inserted into MySQL successfully.
# ✅✅✅ Ebook 733 of 7961: "Tick Tock" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Valerie Parv\Man_Shy_by_Valerie_Parv_-_Unknown.epub
# 📚 Book 'Man Shy' inserted into MySQL successfully.
# ✅✅✅ Ebook 734 of 7961: "Man Shy" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Steven Erikson\The_Crippled_God_-_Steven_Erikson.epub
# 📚 Book 'The Crippled God' inserted into MySQL successfully.
# ✅✅✅ Ebook 735 of 7961: "The Crippled God" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\L.J. Smith\L_J_Smith_Vampire_Diaries_Stefan's_(2).epub
# 📚 Book 'Bloodlust' inserted into MySQL successfully.
# ✅✅✅ Ebook 736 of 7961: "Bloodlust" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Helen Bianchin\HAPPY_CHRISTMAS_LOVE_MILLS_&_BO_-_Sharon_Kendrick.epub
# 📚 Book 'Happy Christmas Love Mills & Boon' inserted into MySQL successfully.
# ✅✅✅ Ebook 737 of 7961: "Happy Christmas Love Mills & Boon" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Seanan McGuire\Late_Eclipses_-_Seanan_McGuire.epub
# 📚 Book 'Late Eclipses' inserted into MySQL successfully.
# ✅✅✅ Ebook 738 of 7961: "Late Eclipses" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lisa Shearin\Con_&_Conjure_-_Lisa_Shearin.epub
# 📚 Book 'Con & Conjure' inserted into MySQL successfully.
# ✅✅✅ Ebook 739 of 7961: "Con & Conjure" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Andre Norton\The_Knightof_the_Red_Beard_-_Andre_Norton.epub
# 📚 Book 'The Knight of the Red Beard' inserted into MySQL successfully.
# ✅✅✅ Ebook 740 of 7961: "The Knight of the Red Beard" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Kresley Cole\Dreams_of_a_Dark_Warrior_(Immor_-_Kresley_Cole.epub
# 📚 Book 'Dreams of a Dark Warrior' inserted into MySQL successfully.
# ✅✅✅ Ebook 741 of 7961: "Dreams of a Dark Warrior" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Alex Archer\Phantom_Prospect_-_Alex_Archer.epub
# 📚 Book 'Phantom Prospect' inserted into MySQL successfully.
# ✅✅✅ Ebook 742 of 7961: "Phantom Prospect" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Pamela Palmer\Hunger_Untamed_-_Pamela_Palmer.epub
# 📚 Book 'Hunger Untamed' inserted into MySQL successfully.
# ✅✅✅ Ebook 743 of 7961: "Hunger Untamed" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Kelley Armstrong\My_Big_Fat_Supernatural_Honeymo_-_Kelley_Armstrong.epub
# 📚 Book 'My Big Fat Supernatural Honeymoon' inserted into MySQL successfully.
# ✅✅✅ Ebook 744 of 7961: "My Big Fat Supernatural Honeymoon" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Jodi Meadows\Incarnate_-_Jodi_Meadows.epub
# 📚 Book 'Incarnate' inserted into MySQL successfully.
# ✅✅✅ Ebook 745 of 7961: "Incarnate" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Kelley Armstrong\Recruit_-_Kelley_Armstrong.epub
# 📚 Book 'Recruit' inserted into MySQL successfully.
# ✅✅✅ Ebook 746 of 7961: "Recruit" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Kelley Armstrong\Checkmate_-_Kelley_Armstrong.epub
# 📚 Book 'Checkmate' inserted into MySQL successfully.
# ✅✅✅ Ebook 747 of 7961: "Checkmate" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Terry Goodkind\The_Omen_Machine_-_Terry_Goodkind.epub
# 📚 Book 'The Omen Machine' inserted into MySQL successfully.
# ✅✅✅ Ebook 748 of 7961: "The Omen Machine" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\L.J. Smith\L._J._Smith_-_The_Vampire_Diaries_-_1_-_Phantom.ePub
# 📚 Book 'Phantom' inserted into MySQL successfully.
# ✅✅✅ Ebook 749 of 7961: "Phantom" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\J.D. Robb\Possession_in_Death_-_J._D._Robb.epub
# 📚 Book 'Possession in Death' inserted into MySQL successfully.
# ✅✅✅ Ebook 750 of 7961: "Possession in Death" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Teresa Southwick\Taming_the_Montana_Millionaire_-_Teresa_Southwick.epub
# 📚 Book 'Taming the Montana Millionaire' inserted into MySQL successfully.
# ✅✅✅ Ebook 751 of 7961: "Taming the Montana Millionaire" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Catherine Fisher\The_Dark_City_-_Catherine_Fisher.epub
# 📚 Book 'The Dark City' inserted into MySQL successfully.
# ✅✅✅ Ebook 752 of 7961: "The Dark City" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Elizabeth Lennox\Never_Dare_a_Tycoon_-_Elizabeth_Lennox.epub
# ...
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Sarah Morgan\The_Forbidden_Ferrara_-_Sarah_Morgan.epub
# 📚 Book 'The Forbidden Ferrara' inserted into MySQL successfully.
# ✅✅✅ Ebook 1136 of 7961: "The Forbidden Ferrara" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lynne Graham\A_Vow_of_Obligation_-_Lynne_Graham.epub
# 📚 Book 'A Vow of Obligation' inserted into MySQL successfully.
# ✅✅✅ Ebook 1137 of 7961: "A Vow of Obligation" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Terry Brooks\Wards_of_Faerie__The_Dark_Legac_-_Terry_Brooks.epub
# 📚 Book 'Wards of Faerie' inserted into MySQL successfully.
# ✅✅✅ Ebook 1138 of 7961: "Wards of Faerie" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Benedict Jacka\Alex_Verus_5__Hidden_-_Benedict_Jacka.epub
# 📚 Book 'Cursed' inserted into MySQL successfully.
# ✅✅✅ Ebook 1139 of 7961: "Cursed" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Carole Mortimer\A_Christmas_Betrothal_-_Carole_Mortimer.epub
# 📚 Book 'A Christmas Betrothal: Christmas at Mulberry Hall / Snowbound and Seduced / A Regency Christmas Carol' inserted into MySQL successfully.
# ✅✅✅ Ebook 1140 of 7961: "A Christmas Betrothal: Christmas at Mulberry Hall / Snowbound and Seduced / A Regency Christmas Carol" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Andre Norton\Voodoo_Planet_-_Andre_Norton.epub
# 📚 Book 'Voodoo Planet' inserted into MySQL successfully.
# ✅✅✅ Ebook 1141 of 7961: "Voodoo Planet" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Robin D. Owens\Heart_Secret_-_Robin_D._Owens.epub
# 📚 Book 'Heart Secret' inserted into MySQL successfully.
# ✅✅✅ Ebook 1142 of 7961: "Heart Secret" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Charlie Richards\Finding_Balance_-_Charlie_Richards.epub
# 📚 Book 'Finding Balance' inserted into MySQL successfully.
# ✅✅✅ Ebook 1143 of 7961: "Finding Balance" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lee Child\A_Wanted_Man_-_Lee_Child.epub
# 📚 Book 'A Wanted Man' inserted into MySQL successfully.
# ✅✅✅ Ebook 1144 of 7961: "A Wanted Man" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Maya Banks\Never_Seduce_a_Scot__The_Montgo_-_Maya_Banks.epub
# 📚 Book 'Never Seduce a Scot' inserted into MySQL successfully.
# ✅✅✅ Ebook 1145 of 7961: "Never Seduce a Scot" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Quinn Loftis\Just_One_Drop_-_Quinn_Loftis.epub
# 📚 Book 'Just One Drop' inserted into MySQL successfully.
# ✅✅✅ Ebook 1146 of 7961: "Just One Drop" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Chanda Hahn\Unenchanted_-_Chanda_Hahn.epub
# 📚 Book 'UnEnchanted' inserted into MySQL successfully.
# ✅✅✅ Ebook 1147 of 7961: "UnEnchanted" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Patricia Briggs\Frost_Burned_-_Patricia_Briggs.epub
# 📚 Book 'Frost Burned' inserted into MySQL successfully.
# ✅✅✅ Ebook 1148 of 7961: "Frost Burned" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Rachel Caine\13-Bitter_Blood_-_Rachel_Caine.epub
# 📚 Book 'Bitter Blood' inserted into MySQL successfully.
# ✅✅✅ Ebook 1149 of 7961: "Bitter Blood" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\C.C. Hunter\Whispers_at_Moonrise_-_C._C._Hunter.epub
# 📚 Book 'Whispers at Moonrise' inserted into MySQL successfully.
# ✅✅✅ Ebook 1150 of 7961: "Whispers at Moonrise" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Victoria Laurie\What_a_Ghoul_Wants_-_Victoria_Laurie.epub
# 📚 Book 'What a Ghoul Wants' inserted into MySQL successfully.
# ✅✅✅ Ebook 1151 of 7961: "What a Ghoul Wants" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Sam Crescent\The_Valentines__A_Box_Set_-_Sam_Crescent.epub
# 📚 Book 'Robert' inserted into MySQL successfully.
# ✅✅✅ Ebook 1152 of 7961: "Robert" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Sandra Hill\Kiss_of_Surrender_-_Sandra_Hill.epub
# 📚 Book 'Kiss of Surrender' inserted into MySQL successfully.
# ✅✅✅ Ebook 1153 of 7961: "Kiss of Surrender" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Terri Garey\Ghouls_Night_Out_-_Terri_Garey.epub
# 📚 Book 'Ghouls Night Out: From Weddings from Hell' inserted into MySQL successfully.
# ✅✅✅ Ebook 1154 of 7961: "Ghouls Night Out: From Weddings from Hell" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Dave Duncan\Against_the_Light_-_Dave_Duncan.epub
# 📚 Book 'Against the Light' inserted into MySQL successfully.
# ✅✅✅ Ebook 1155 of 7961: "Against the Light" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Dave Duncan\Against_the_Light_-_Dave_Duncan.epub
# 📚 Book 'Against the Light' inserted into MySQL successfully.
# ✅✅✅ Ebook 1156 of 7961: "Against the Light" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Richelle Mead\Gameboard_of_the_Gods_-_Richelle_Mead.epub
# 📚 Book 'Gameboard of the Gods' inserted into MySQL successfully.
# ✅✅✅ Ebook 1157 of 7961: "Gameboard of the Gods" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Megan Derr\The_Lost_Gods_(Box_Set)_-_Megan_Derr.epub
# 📚 Book 'Poison' inserted into MySQL successfully.
# ✅✅✅ Ebook 1158 of 7961: "Poison" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Anne Elisabeth Stengl\Starflower_-_Anne_Elisabeth_Stengl.epub
# 📚 Book 'Starflower' inserted into MySQL successfully.
# ✅✅✅ Ebook 1159 of 7961: "Starflower" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Stephen R. Lawhead\The_Spirit_Well_-_Stephen_R._Lawhead.epub
# 📚 Book 'The Spirit Well' inserted into MySQL successfully.
# ✅✅✅ Ebook 1160 of 7961: "The Spirit Well" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Seanan McGuire\Midnight_Blue-Light_Special_-_Seanan_McGuire.epub
# 📚 Book 'Midnight Blue-Light Special' inserted into MySQL successfully.
# ✅✅✅ Ebook 1161 of 7961: "Midnight Blue-Light Special" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Caitlin Crews\In_Defiance_of_Duty_(Mills_&_Bo_-_Caitlin_Crews.epub
# 📚 Book 'In Defiance of Duty' inserted into MySQL successfully.
# ✅✅✅ Ebook 1162 of 7961: "In Defiance of Duty" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Edward W. Robertson\The_Zombies_of_Hobbiton_-_Edward_W._Robertson.epub
# Added new subcategory: Zombies with id: 33, image: upload/zombies.png
# 📚 Book 'The Zombies of Hobbiton: A Martian Love Story' inserted into MySQL successfully.
# ✅✅✅ Ebook 1163 of 7961: "The Zombies of Hobbiton: A Martian Love Story" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Evangeline Anderson\Revealed_-_Evangeline_Anderson.epub
# 📚 Book 'Revealed' inserted into MySQL successfully.
# ✅✅✅ Ebook 1164 of 7961: "Revealed" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lucy Monroe\Dragon's_Moon_-_Lucy_Monroe.epub
# 📚 Book 'Dragon's Moon' inserted into MySQL successfully.
# ✅✅✅ Ebook 1165 of 7961: "Dragon's Moon" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Emma Darcy\Emma_Darcy_The_Wrong_Mirror_-_Unknown.epub
# 📚 Book 'The Emma Darcy Collection: The Wrong Mirror / The Unpredictable Man' inserted into MySQL successfully.
# ✅✅✅ Ebook 1166 of 7961: "The Emma Darcy Collection: The Wrong Mirror / The Unpredictable Man" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Catherine Fisher\Darkwater_-_Catherine_Fisher.epub
# 📚 Book 'Darkwater' inserted into MySQL successfully.
# ✅✅✅ Ebook 1167 of 7961: "Darkwater" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Melanie Milburne\Deserving_of_His_Diamonds__-_Melanie_Milburne.epub
# 📚 Book 'Deserving of His Diamonds?' inserted into MySQL successfully.
# ✅✅✅ Ebook 1168 of 7961: "Deserving of His Diamonds?" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Mercedes Lackey\Redoubt_-_Mercedes_Lackey.epub
# 📚 Book 'Redoubt' inserted into MySQL successfully.
# ✅✅✅ Ebook 1169 of 7961: "Redoubt" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Simon R. Green\Ghost_of_a_Dream_-_Simon_R._Green.epub
# 📚 Book 'Ghost of a Dream' inserted into MySQL successfully.
# ✅✅✅ Ebook 1170 of 7961: "Ghost of a Dream" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Pamela Palmer\A_Love_Untamed_-_Pamela_Palmer.epub
# 📚 Book 'A Love Untamed' inserted into MySQL successfully.
# ✅✅✅ Ebook 1171 of 7961: "A Love Untamed" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lindsay Buroker\Peacemaker_-_Lindsay_Buroker.epub
# 📚 Book 'Peacemaker' inserted into MySQL successfully.
# ✅✅✅ Ebook 1172 of 7961: "Peacemaker" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Marcia Binder Schmidt\Perfect_Clarity_A_Tibetan_Buddhist_Anthology_Of_Mahamudra_And_Dzogchen.epub
# Added new subcategory: Buddhism with id: 35, image: upload/buddhism.png
# 📚 Book 'Perfect Clarity: A Tibetan Buddhist Anthology of Mahamudra and Dzogchen' inserted into MySQL successfully.
# ✅✅✅ Ebook 1173 of 7961: "Perfect Clarity: A Tibetan Buddhist Anthology of Mahamudra and Dzogchen" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Danielle Steel\Danielle_Steel_-_The_Sins_of_the_Mother_-_2012.epub
# 📚 Book 'The Sins of the Mother' inserted into MySQL successfully.
# ✅✅✅ Ebook 1174 of 7961: "The Sins of the Mother" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Patricia Rice\McCloud's_Woman_-_Patricia_Rice.epub
# 📚 Book 'McCloud's Woman' inserted into MySQL successfully.
# ✅✅✅ Ebook 1175 of 7961: "McCloud's Woman" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Piers Anthony\Luck_of_the_Draw_(Xanth)_-_Piers_Anthony.epub
# 📚 Book 'Luck of the Draw' inserted into MySQL successfully.
# ✅✅✅ Ebook 1176 of 7961: "Luck of the Draw" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Kelly McCullough\Crossed_Blades_-_Kelly_McCullough.epub
# 📚 Book 'Crossed Blades' inserted into MySQL successfully.
# ✅✅✅ Ebook 1177 of 7961: "Crossed Blades" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Charlaine Harris\An_Apple_for_the_Creature_-_Charlaine_Harris.epub
# 📚 Book 'An Apple for the Creature' inserted into MySQL successfully.
# ✅✅✅ Ebook 1178 of 7961: "An Apple for the Creature" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Jennifer Estep\Widow's_Web_-_Jennifer_Estep.epub
# 📚 Book 'Widow's Web' inserted into MySQL successfully.
# ✅✅✅ Ebook 1179 of 7961: "Widow's Web" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Carole Mortimer\Defying_Drakon_-_Carole_Mortimer.epub
# 📚 Book 'Defying Drakon' inserted into MySQL successfully.
# ✅✅✅ Ebook 1180 of 7961: "Defying Drakon" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Diana Pharaoh Francis\Blood_Winter_-_Diana_Pharaoh_Francis.epub
# 📚 Book 'Blood Winter' inserted into MySQL successfully.
# ✅✅✅ Ebook 1181 of 7961: "Blood Winter" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Michelle Sagara\Cast_in_Peril_-_Michelle_Sagara.epub
# 📚 Book 'Cast in Peril' inserted into MySQL successfully.
# ✅✅✅ Ebook 1182 of 7961: "Cast in Peril" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Jennie Lucas\To_Love,_Honour_and_Betray_-_Jennie_Lucas.epub
# 📚 Book 'To Love, Honor and Betray' inserted into MySQL successfully.
# ✅✅✅ Ebook 1183 of 7961: "To Love, Honor and Betray" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Lola Dodge\Temptress_-_Lola_Dodge.epub
# 📚 Book 'Temptress' inserted into MySQL successfully.
# ✅✅✅ Ebook 1184 of 7961: "Temptress" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Cassandra Clare\ShadowhuntersCodex.epub
# 📚 Book 'The Shadowhunter's Codex' inserted into MySQL successfully.
# ✅✅✅ Ebook 1185 of 7961: "The Shadowhunter's Codex" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Anne Oliver\The_Morning_After_The_Wedding_B_-_Anne_Oliver.epub
# 📚 Book 'The Morning After the Wedding Before' inserted into MySQL successfully.
# ✅✅✅ Ebook 1186 of 7961: "The Morning After the Wedding Before" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\John Grisham\John_Grisham_-_[Novels_22]_-_The_Racketeer.epub
# 📚 Book 'The Racketeer' inserted into MySQL successfully.
# ✅✅✅ Ebook 1187 of 7961: "The Racketeer" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Ian C. Esslemont\Blood_and_Bone.ePub
# 📚 Book 'Blood and Bone' inserted into MySQL successfully.
# ✅✅✅ Ebook 1188 of 7961: "Blood and Bone" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Charles Dickens\Dickens_at_Christmas_-_Charles_Dickens.epub
# 📚 Book 'Dickens at Christmas' inserted into MySQL successfully.
# ✅✅✅ Ebook 1189 of 7961: "Dickens at Christmas" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Stephen King\Black_House_-_Stephen_King.epub
# 📚 Book 'Black House' inserted into MySQL successfully.
# ✅✅✅ Ebook 1190 of 7961: "Black House" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Brandon Sanderson\The_Emperor's_Soul_-_Brandon_Sanderson.epub
# 📚 Book 'The Emperor's Soul' inserted into MySQL successfully.
# ✅✅✅ Ebook 1191 of 7961: "The Emperor's Soul" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Robert Joseph Greene\The_Gay_Icon_Classics_Of_The_World_II_-_Robert_Joseph_Greene.epub
# 📚 Book 'The Gay Icon Classics Of The World II' inserted into MySQL successfully.
# ✅✅✅ Ebook 1192 of 7961: "The Gay Icon Classics Of The World II" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Daniel Arenson\Wand_of_the_Witch_-_Daniel_Arenson.epub
# 📚 Book 'Wand of the Witch' inserted into MySQL successfully.
# ✅✅✅ Ebook 1193 of 7961: "Wand of the Witch" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\R.L. Stine\Planet_of_the_Lawn_Gnomes.epub
# 📚 Book 'Planet of the Lawn Gnomes' inserted into MySQL successfully.
# ✅✅✅ Ebook 1194 of 7961: "Planet of the Lawn Gnomes" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Marie O'Regan\Anthology.The.Mammoth.Book.of.Ghost.Stories.by.Woman.Marie.O'Reagan.2012.epub
# 📚 Book 'The Mammoth Book of Ghost Stories by Women' inserted into MySQL successfully.
# ✅✅✅ Ebook 1195 of 7961: "The Mammoth Book of Ghost Stories by Women" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Mary Oliver\A_Thousand_Mornings_-_Mary_Oliver.epub
# 📚 Book 'A Thousand Mornings: Poems' inserted into MySQL successfully.
# ✅✅✅ Ebook 1196 of 7961: "A Thousand Mornings: Poems" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Mercedes Lackey\Elemental_Magic_-_Mercedes_Lackey.epub
# 📚 Book 'Elemental Magic: All-New Tales of the Elemental Masters' inserted into MySQL successfully.
# ✅✅✅ Ebook 1197 of 7961: "Elemental Magic: All-New Tales of the Elemental Masters" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Robert Greene\Mastery_-_Robert_Greene.epub
# 📚 Book 'Mastery' inserted into MySQL successfully.
# ✅✅✅ Ebook 1198 of 7961: "Mastery" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Dave Duncan\Wildcatter_-_Dave_Duncan.epub
# 📚 Book 'Wildcatter' inserted into MySQL successfully.
# ✅✅✅ Ebook 1199 of 7961: "Wildcatter" processed!
# ✅ Found: C:\xampp8.2\htdocs\php_web_services_final\public\upload\Robin Cook\Nano_-_Robin_Cook.epub
# 📚 Book 'Nano' inserted into MySQL successfully.
# ✅✅✅ Ebook 1200 of 7961: "Nano" processed!
# Total books processed: 1200

# %%
import mysql.connector
from mysql.connector import errorcode

# Update these connection params to match your XAMPP MySQL instance
config = {
    'user': 'root',          # or your MySQL username
    'password': '',            # your password (empty by default in many XAMPP setups)
    'host': '127.0.0.1',
    'port': 3306,              # default MySQL port
    'database': 'final_klaus_ebooks_library',
    'raise_on_warnings': True
}

def main():
    try:
        cnx = mysql.connector.connect(**config)
        cursor = cnx.cursor(dictionary=True)

        # Step 1: verify sub_categories table exists and fetch subcategory ids/names
        cursor.execute("""
            SELECT sc.id AS subcat_id, sc.sub_category_name
            FROM sub_categories AS sc
            WHERE sc.status = 1
            ORDER BY sc.id
        """)
        subcats = cursor.fetchall()

        # Step 2: count books per subcategory
        # Assuming 'books' table uses 'sub_cat_id' as foreign key to sub_categories.id
        counts = {}
        for sc in subcats:
            subcat_id = sc['subcat_id']
            subcat_name = sc['sub_category_name']

            cursor.execute("""
                SELECT COUNT(*) AS total
                FROM books
                WHERE sub_cat_id = %s
            """, (subcat_id,))
            row = cursor.fetchone()
            total = row['total'] if row else 0
            counts[subcat_name] = total

        # Step 3: print results
        print("Books per subcategory:")
        for name, total in counts.items():
            print(f" - {name}: {total}")

    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
            print("Access denied: check username/password.")
        elif err.errno == errorcode.ER_BAD_DB_ERROR:
            print("Database not found: ensure the database name is correct.")
        else:
            print(f"MySQL error: {err}")
    finally:
        if 'cursor' in locals() and cursor:
            cursor.close()
        if 'cnx' in locals() and cnx:
            cnx.close()

if __name__ == '__main__':
    main()
