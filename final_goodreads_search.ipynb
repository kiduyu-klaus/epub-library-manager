# %%
import csv
import logging
import os
import random
import re
import time
import urllib.parse
import urllib.request
from pathlib import Path
from urllib.parse import urlparse
from googlesearch import search
import bs4  # Optional: if you use `bs4.BeautifulSoup` instead of `from bs4 import BeautifulSoup`
import requests
from bs4 import BeautifulSoup
# Constants
GOODREADS_URL = 'https://www.goodreads.com'
import random
# List of user agents for rotation
LIST_OF_USER_AGENTS = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
    'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)'
]

import zipfile
from lxml import etree

from ebooklib import epub  # EPUB file manipulation library
import google.generativeai as genai
import csv

#import pandas as pd
Gemini_key = 'AIzaSyCASKQRxoOKw3ZLgGIdEQHUc2d-E0EXUHQ'
import pprint
import shutil
from bingsearch.bingsearch import BingSearch
import mysql.connector

# %%
# Configure Gemini AI with the API key from the environment variable
genai.configure(api_key=Gemini_key)

# Create the model configuration
generation_config = {
    "temperature": 0.7,  # Lower temperature for deterministic responses
    "top_p": 0.95,  # Use nucleus sampling
    "top_k": 40,  # Consider top-k tokens
    "max_output_tokens": 512,  # Limit response length
    "response_mime_type": "text/plain",  # Expect text response
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-2.0-flash-exp",  # Use the appropriate model name
    generation_config=generation_config,
)

genre_chat_session = model.start_chat(history=[])

def get_goodreads_title(book_title, author_name):
    """
    Passes a book title and author to Gemini AI to get the Goodreads official book link.

    Args:
        book_title (str): The title of the book.
        author_name (str): The name of the author.

    Returns:
        str: The Goodreads official book link or an error message.
    """
    # Start a new chat session
    chat_session = model.start_chat(history=[])

    # Construct the input prompt
    prompt = (
        f"Find the official Goodreads title for the book titled '{book_title}' "
        f"written by the author '{author_name}'. Return only the goodreads title."
    )

    # Send the message to the Gemini model
    response = chat_session.send_message(prompt)

    # Extract the text response
    response_text = response.text.strip()
    if response_text.strip().lower() == book_title.strip().lower():
        return None
    return response_text

def fix_ebook_title_with_gemini(unconfirmed_title: str, author_name: str) -> str | None:
    """
    Use Gemini AI to fix or verify an incorrect or approximate eBook title
    by matching it to the official Goodreads title, given the author.

    Args:
        unconfirmed_title (str): The guessed or unclean eBook title.
        author_name (str): The confirmed name of the author.

    Returns:
        str | None: The corrected official title if found, else None.
    """
    prompt = (
        f"this book called: '{unconfirmed_title}' "
        f"by the author '{author_name}' has an incorrect book title. Please return the correct official title "
        "of the book as it appears on Goodreads. Respond with only the exact title, no links or explanations. and make sure the book title is correct "
    )

    try:
        chat = model.start_chat()
        response = chat.send_message(prompt)
        result = response.text.strip()

        # Optionally avoid returning the same name if not corrected
        if result.lower() == unconfirmed_title.strip().lower():
            return None

        return result

    except Exception as e:
        print(f"[Gemini Error] Failed to fix title: {e}")
        return None
    
def get_author_name_with_gemini(unconfirmed_title: str) -> str | None:
    """
    Use Gemini AI to identify the official author of a book given only its title.

    Args:
        unconfirmed_title (str): The possibly incorrect or informal book title.

    Returns:
        str | None: The correct author's name if found, otherwise None.
    """
    prompt = (
        f"A book has the title '{unconfirmed_title}', but the author's name is unknown. "
        f"Please provide the full name of the primary author as listed on Goodreads. "
        "Respond with only the author's full name and nothing else."
    )

    try:
        chat = model.start_chat()
        response = chat.send_message(prompt)
        author_name = response.text.strip()

        # Basic validation
        if not author_name or len(author_name.split()) < 2:
            return None

        return author_name

    except Exception as e:
        print(f"[Gemini Error] Failed to get author: {e}")
        return None

def get_book_genre_with_gemini(ebook_title: str, author_name: str) -> str | None:
    """
    Use Gemini AI to determine the primary Goodreads genre of a book
    based on its title and author.

    Args:
        ebook_title (str): The title of the eBook.
        author_name (str): The name of the author.

    Returns:
        str | None: The most appropriate genre from Goodreads if found, else None.
    """
    prompt = (
        f"The book titled '{ebook_title}' by '{author_name}' is listed on Goodreads. "
        "Please return only the **primary** book genre as it appears on Goodreads "
        "(e.g., Fiction, Romance, Historical Fiction, Thriller, Fantasy, Non-Fiction, etc.). "
        "Do not include explanations, quotes, links, or multiple genres—respond with one genre only."
    )

    try:
        response = genre_chat_session.send_message(prompt)
        genre = response.text.strip()

        # Optional sanity check: ensure single-word or hyphenated genre
        if not genre or len(genre.split()) > 3:
            return None

        return genre

    except Exception as e:
        #print(f"[Gemini Error] Failed to get genre: {e}")
        return None

# %%
genre = get_book_genre_with_gemini("The Night Circus", "Erin Morgenstern")
print("Primary genre:", genre)

# %%
genre

# %%
book_title = "BreakingthePlayboysCurse"
author = get_author_name_with_gemini(book_title)
print("Author:", author)

# %%
corrected_title = fix_ebook_title_with_gemini("Casacelli Brides Four powerful", "Clare Connelly")
print("Corrected Title:", corrected_title)

# %% [markdown]
# ## 📘 Overview of Extracted Functions
#
# This part contains all the helper functions required by the `scrape_book` function, which scrapes detailed book information from a Goodreads book page. Below is a summary of each extracted function:
#
# ---
#
# ### 🔍 `scrape_book(book_url, book_url_local, random_header)`
# Main function that scrapes metadata from a Goodreads book page using the provided URL and request headers.
#
# Returns a dictionary with:
# - Book ID, title, description, category and subcategory IDs
# - Author ID, cover image, ratings, and local file reference
#
# ---
#
# ### 🏷️ `get_genre_list(soup)`
# Parses the Goodreads HTML page to extract the book's listed genres and returns them as a comma-separated string.
#
# ---
#
# ### 📂 `process_subcategories(sub_cat_id_string, csv_file='subcategories.csv')`
# Converts the genre string into internal category (`cat_id`) and subcategory (`sid`) IDs by matching against a CSV file. Falls back to default values if none found.
#
# ---
#
# ### 🆔 `get_id(bookid)`
# Extracts the numeric portion of the Goodreads book ID from its URL or slug.
#
# ---
#
# ### 🧑‍💻 `get_author_id(soup)`
# Finds and returns the Goodreads author ID by parsing the contributor link in the book page HTML.
#
# ---
#
# ### 📝 `get_book_description(soup)`
# Retrieves the book's description text from the Goodreads page. Returns a default message if none is found.
#
# ---
#
# ### 🖼️ `get_book_cover(soup)`
# Extracts the book's cover image URL. If no image is found, returns a placeholder image URL.
#
# ---
#
# ### 📇 `get_sub_category_id(sub_category_name, csv_file='subcategories.csv')`
# Helper for `process_subcategories` that looks up a single subcategory name in the CSV file and returns its associated IDs.
#
# ---
#
# These functions are modular and reusable across your scraping pipeline, and they are now grouped in a single file for maintainability and clarity.

# %%
def get_id(bookid):
    pattern = re.compile("([^.-]+)")
    bookdd = bookid.split('-')[0]
    bookdd = bookdd.split('.')[0]
    return bookdd

def get_genre_list(soup):
    genres = []
    genres_container = soup.find("div", {"data-testid": "genresList"})
    if genres_container:
        genre_links = genres_container.find("ul").find("span").find_all("a")
        for link in genre_links:
            genre = link.find("span").text
            genres.append(genre)
        return ', '.join(genres)
    return None


def get_sub_category_id(sub_category_name, csv_file='subcategories.csv'):
    sub_category_name = sub_category_name.strip().lower()
    try:
        with open(csv_file, mode='r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                if row['sub_category_name'].strip().lower() == sub_category_name.strip().lower():
                    return {
                        'sid': int(row['id']),  # Changed from 'sid' to 'id'
                        'cat_id': int(row['cat_id'])
                    }
        return None
    except FileNotFoundError:
        print(f"Error: The file {csv_file} does not exist.")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

def get_next_sid(csv_file='subcategories.csv'):
    """Get the next available id by finding the maximum existing id"""
    try:
        if not os.path.exists(csv_file):
            return 1
        
        with open(csv_file, mode='r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            max_id = 0
            for row in reader:
                if row['id'].isdigit():  # Changed from 'sid' to 'id'
                    max_id = max(max_id, int(row['id']))
            return max_id + 1
    except Exception as e:
        print(f"Error getting next id: {e}")
        return 1

def add_new_subcategory(sub_category_name, csv_file='subcategories.csv'):
    """Add a new subcategory to the CSV file and return its info"""
    try:
        next_id = get_next_sid(csv_file)
        
        # Create the image filename (same as subcategory name)
        sub_category_image = f"upload/{sub_category_name.lower()}.png"
        
        # Check if file exists, if not create with header
        file_exists = os.path.exists(csv_file) and os.path.getsize(csv_file) > 0
        
        with open(csv_file, mode='a', encoding='utf-8', newline='') as file:
            fieldnames = ['id', 'cat_id', 'sub_category_name', 'sub_category_image', 'status']
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            
            # Write header if file doesn't exist or is empty
            if not file_exists:
                writer.writeheader()
            
            writer.writerow({
                'id': next_id,  # Changed from 'sid' to 'id'
                'cat_id': 1,  # Default category ID
                'sub_category_name': sub_category_name,  # Changed from 'sub_cat_name'
                'sub_category_image': sub_category_image,
                'status': 1  # Added status field with default value
            })
        
        print(f"Added new subcategory: {sub_category_name} with id: {next_id}, image: {sub_category_image}")
        return {
            'sid': next_id,
            'cat_id': 1
        }
    
    except Exception as e:
        print(f"Error adding new subcategory: {e}")
        return None

def process_subcategories(sub_cat_id_string, csv_file='subcategories.csv'):
    if sub_cat_id_string:
        subcategories = [sub.strip() for sub in sub_cat_id_string.split(',')]
        
        # Define priority order (optional)
        priority_genres = ['Fiction', 'Fantasy', 'Psychology', 'Non-Fiction']
        
        # Check priority genres first
        for priority_genre in priority_genres:
            if priority_genre.lower() in [sub.lower() for sub in subcategories]:
                subcategory_info = get_sub_category_id(priority_genre, csv_file)
                if subcategory_info:
                    return {
                        'sid': subcategory_info['sid'],
                        'cat_id': subcategory_info['cat_id'],
                        'sub_cat_name': priority_genre
                    }
        
        # Then check all other subcategories
        for subcategory in subcategories:
            subcategory_info = get_sub_category_id(subcategory, csv_file)
            if subcategory_info:
                return {
                    'sid': subcategory_info['sid'],
                    'cat_id': subcategory_info['cat_id'],
                    'sub_cat_name': subcategory
                }
        
        # If none exist, add the first one
        first_subcategory = subcategories[0]
        new_subcategory_info = add_new_subcategory(first_subcategory, csv_file)
        if new_subcategory_info:
            return {
                'sid': new_subcategory_info['sid'],
                'cat_id': new_subcategory_info['cat_id'],
                'sub_cat_name': first_subcategory
            }
    
    return {
        'sid': 1,
        'cat_id': 1,
        'sub_cat_name': 'Default'
        }  

def get_author_id(soup):
    """
    Retrieves one or more author IDs from a Goodreads book page.

    Args:
        soup (bs4.BeautifulSoup): The BeautifulSoup object representing the HTML page.

    Returns:
        str: A single author ID or multiple author IDs separated by commas.
    """
    author_ids = []
    contributors_section = soup.find('div', class_='ContributorLinksList')

    if contributors_section:
        author_links = contributors_section.find_all('a', class_='ContributorLink')
        for link in author_links:
            author_url = link.get('href', '')
            if '/author/show/' in author_url:
                author_id = author_url.split('/')[-1].split('.')[0]
                author_ids.append(author_id)

    return ','.join(author_ids) if author_ids else None

def get_author_name(soup):
    author_name_span = soup.find('span', class_='ContributorLink__name', attrs={'data-testid': 'name'})
    if author_name_span:
        return author_name_span.text.strip()
    return 'Unknown Author'


def get_book_description(soup):
    try:
        desc = soup.find("div", {"class": "DetailsLayoutRightParagraph__widthConstrained"})
        return desc.get_text().strip() if desc else 'No Description available'
    except AttributeError:
        return 'No Description available'

def get_book_cover(soup):
    cover = soup.find('img', {'class': 'ResponsiveImage'})
    return cover['src'] if cover and 'src' in cover.attrs else 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/No-Image-Placeholder.svg/1665px-No-Image-Placeholder.svg.png'

def scrape_book(book_url, book_url_local, random_header):
    header = {
        "User-Agent": random.choice(LIST_OF_USER_AGENTS),
        "Accept-Language": "en-US,en;q=0.9",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp",
        "Referer": "https://www.google.com/"
    }
    
    source = requests.get(book_url, headers=header)
    time.sleep(2)
    soup = BeautifulSoup(source.content, 'html.parser')

    book_title_elem = soup.find('h1', class_='Text Text__title1', attrs={'data-testid': 'bookTitle'})
    book_title = ' '.join(book_title_elem.text.split()) if book_title_elem else 'Unknown Title'

    book_id_beta = book_url.replace(GOODREADS_URL + '/book/show/', '')
    book_id_beta1 = book_id_beta.replace(GOODREADS_URL + '/en/book/show/', '')
    a_name=get_author_name(soup)
    #print(a_name)

    genre_string = get_genre_list(soup)
    #print(genre_string)
    # try:
    #     genre_string = get_book_genre_with_gemini(book_title, get_author_name(soup))
    # except Exception as e:
    #     print(f"Gemini failed, using scraping fallback: {e}")
    #     genre_string = get_genre_list(soup)
    category_ids = process_subcategories(genre_string)
    #print(f"  📚 Genre: {genre_string}")
    
    bookinfo={
        'id': get_id(book_id_beta1),
        'cat_id': category_ids.get('cat_id'),
        'sub_cat_id': category_ids.get('sid'),
        'author_ids': get_author_id(soup),
        'book_access': 'Free',
        'title': book_title,
        'description': get_book_description(soup),
        'image': get_book_cover(soup),
        'url_type': 'server_url',
        'url': book_url_local,
        'download_enable': '1',
        'book_on_rent': '',
        'book_rent_price': '',
        'book_rent_time': '',
        'featured': '1',
        'status': '1'
    }

    return bookinfo,a_name

# %%
# Sample book page URL (public Goodreads book page)
book_url = "https://www.goodreads.com/book/show/5679963"
book_url_local = "books/the-great-gatsby.epub"

# Choose a random header
random_header = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}

# Run the function
book_data,a_name = scrape_book(book_url, book_url_local, random_header)

# Print output
import pprint
pprint.pprint(a_name)

# %%
book_data

# %% [markdown]
# ## 👩‍💻 Overview of Author Scraping Functions
# This part provides a comprehensive set of tools to scrape and enrich author profiles from Goodreads. These functions are used by the core `scrape_author()` function and include data extraction, parsing, and third-party enrichment via web search.
#
# ---
#
# ### 🧠 `scrape_author(author_id)`
# Main driver function that scrapes and assembles an author's metadata from Goodreads using their author ID (e.g., `2614.Lora_Leigh`). It fetches and parses the HTML, then compiles:
#
# - Author ID and name
# - Biography and place of birth
# - Author photo
# - Website and social media links (YouTube, Instagram, Facebook)
# - Status indicator for downstream processing
#
# ---
#
# ### 🔎 Helper Functions
#
# #### 🆔 `get_id_number(author_id)`
# Extracts the numeric portion from a combined author ID (e.g., `2614` from `2614.Lora_Leigh`).
#
# #### 📚 `get_author_info(soup)`
# Parses sidebar metadata from the author's profile page, including birth location, influences, and website.
#
# #### ✍️ `get_author_description(soup, id_number)`
# Finds and extracts the author's biography based on a unique HTML ID tied to the author ID.
#
# #### 🖼️ `get_author_image(soup, author_name)`
# Returns the URL of the author's profile image. If not found, falls back to a default placeholder image.
#
# ---
#
# ### 🌐 External Search Helpers
#
# These functions use Google search results to infer the author’s online presence:
#
# - 🔴 `author_youtube_search(author_name)` – Finds a likely YouTube channel
# - 🟣 `author_instagram_search(author_name)` – Finds their Instagram profile
# - 🔵 `author_facebook_search(author_name)` – Finds their Facebook page
# - 🌍 `author_website_search(author_name)` – Attempts to locate their official website
#
# All use the `googlesearch` package and return the first relevant result.
#
# ---
#
# ### 🛡️ Additional Notes
# - Each request to Goodreads uses a **rotating User-Agent** from `LIST_OF_USER_AGENTS` to mimic a browser and avoid blocks.
# - HTTP headers include `Referer` and `Accept` fields for better anti-bot evasion.
# - All major scrapers are modular and testable individually or in pipeline mode.

# %%
def get_id_number(author_id):
    pattern = re.compile("([^.-]+)")
    aid = pattern.search(author_id).group()
    author_split = aid.split(".")
    return author_split[0]

def get_author_info(soup):
    container = soup.find('div', attrs={'class': 'rightContainer'})
    author_info = {}
    data_div = container.find('br', attrs={'class': 'clear'})
    while data_div:
        if data_div.name:
            data_class = data_div.get('class')[0]
            if data_class == 'aboutAuthorInfo':
                break
            elif data_class == 'dataTitle':
                key = data_div.text.strip()
                author_info[key] = []
            if data_div.text == 'Born':
                data_div = data_div.next_sibling
                author_info[key].append(data_div.strip())
            elif data_div.text == 'Influences':
                data_div = data_div.next_sibling.next_sibling
                data_items = data_div.findAll('span')[-1].findAll('a')
                for data_a in data_items:
                    author_info[key].append(data_a.text.strip())
            elif data_div.text == 'Member Since':
                data_div = data_div.next_sibling.next_sibling
                author_info[key].append(data_div.text.strip())
            else:
                data_items = data_div.find_all('a')
                for data_a in data_items:
                    author_info[key].append(data_a.text.strip())
        data_div = data_div.next_sibling
    return author_info

def get_author_description(soup, id_number):
    cell = soup.find("span", {"id": f"freeTextContainerauthor{id_number}"})
    return cell.text.strip() if cell else None

def get_author_image(soup, author_name):
    cell = soup.find("img", {"alt": author_name, "itemprop": "image"})
    if cell:
        return cell.attrs.get("src")
    return 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/No-Image-Placeholder.svg/1665px-No-Image-Placeholder.svg.png'

def author_youtube_search(author_name):
    try:
        search_txt = author_name + ' channel youtube'
        results = search(search_txt, num_results=10)
        for url in results:
            if 'https://www.youtube.com' in url:
                return url
    except Exception as e:
        print(f"YouTube search error: {e}")
    return ''

def author_instagram_search(author_name):
    try:
        search_txt = author_name + ' instagram official'
        results = search(search_txt, num_results=10)
        for url in results:
            if 'https://www.instagram.com' in url:
                return url
    except Exception as e:
        print(f"Instagram search error: {e}")
    return ''

def author_facebook_search(author_name):
    try:
        search_txt = author_name + ' facebook official'
        results = search(search_txt, num_results=10)
        for url in results:
            if 'https://www.facebook.com' in url:
                return url
    except Exception as e:
        print(f"Facebook search error: {e}")
    return ''

def author_website_search(author_name):
    try:
        search_txt = author_name + ' official website'
        results = search(search_txt, num_results=10)
        for url in results:
            return url  # First valid hit
    except Exception as e:
        print(f"Website search error: {e}")
    return ''

def scrape_author(author_id):
        """
        Scrapes the author information from the Goodreads website.

        Args:
            author_id (str): The author ID.

        Returns:
            dict: A dictionary containing the scraped author information.
        """
        user_agent = random.choice(LIST_OF_USER_AGENTS)  # Select a random user agent
        random_header = {'User-Agent': user_agent}  # Create a header with the selected user agent

        url = "https://www.goodreads.com/author/show/" + author_id

        time.sleep(3)  # Pause execution for 3 seconds

        try:
            source = requests.get(url, headers=random_header).content  # Open the URL and retrieve the HTML source with the header
            soup = BeautifulSoup(source, "html.parser")  # Create a BeautifulSoup object for parsing the HTML

            author_name = soup.find("span", {"itemprop": "name"}).text.strip()  # Extract the author name from the HTML
            id_number = get_id_number(author_id)  # Call a helper function to get the ID number

            author_info = get_author_info(soup)  # Call a helper function to get additional author information
            if author_info:
                if 'Born' in author_info:
                    author_city_name = author_info["Born"][0]  # Extract the author's city name if available
                else:
                    author_city_name = 'No City Name Found'

                if 'Website' in author_info:
                    author_website = author_info["Website"]  # Extract the author's website if available
                else:
                    author_website = 'none'
            else:
                author_city_name = 'No City Name Found'
                author_website = 'none'

            #info["author_name"] = author_name  # Add the author name to the 'info' dictionary

            author_des = get_author_description(soup, id_number)
            if not author_des:  # Check if author_des is empty (None or empty string)
                author_des = "No Author Description"


            

        except AttributeError as e:
            print(f"An AttributeError occurred while scraping author information: {e}")
            return None
     
        #"id","name","description","image","facebook_url","instagram_url","youtube_url","website_url","status"
        return {
            "id": id_number,
            "name": author_name,
            "description": author_des,
            "image": get_author_image(soup, author_name),
            "facebook_url": author_facebook_search(author_name),
            "instagram_url": author_instagram_search(author_name),
            "youtube_url": author_youtube_search(author_name),
            "website_url": author_website_search(author_name),
            "status": '1'
        }

def is_author_id_in_csv(aid, csv_file= 'authors.csv'):
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.reader(file)
            for row in reader:
                if row[0] == str(aid):  # Check if the first column matches the author ID
                    return True
        return False
    except FileNotFoundError:
        print(f"File {csv_file} not found.")
        return False
    
    
def is_author_id_in_local_csv(aid, csv_file):
    """
    Checks if a given author ID exists in the specified CSV file.

    Args:
        aid (int or str): The author ID to search for.
        csv_file (str): The path to the CSV file where the author ID is stored.

    Returns:
        bool: True if the author ID is found in the CSV file, False otherwise.
    """
    try:
        # Open the CSV file in read mode, specifying UTF-8 encoding for compatibility
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.reader(file)  # Create a CSV reader object to read rows from the file
            for row in reader:
                # Check if the first column matches the provided author ID
                if row[0] == str(aid):  # Convert 'aid' to string for comparison
                    return True  # Return True if a matching author ID is found
        return False  # Return False if the author ID is not found after reading all rows
    except FileNotFoundError:
        # Handle the case where the CSV file does not exist
        print(f"File {csv_file} not found.")
        return False
    
def append_author_to_csv(file_name, author_data):
    """
    Appends the scraped author data to a CSV file.

    Args:
        file_name (str): The name of the CSV file.
        author_data (dict): A dictionary containing the scraped author information.
    """
    fieldnames = [
        'id', 'name', 'description', 'image',
        'facebook_url', 'instagram_url', 'youtube_url',
        'website_url', 'status'
    ]


    # Check if the file exists and write header if not
    try:
        with open(file_name, mode='r', newline='', encoding='utf-8') as file:
            pass
    except FileNotFoundError:
        with open(file_name, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()

    # Append author data to the CSV file
    with open(file_name, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writerow(author_data)

# %%
print(scrape_author('4601681'))

# %%
import re
def clean_url(url):
    return url.split('?')[0] if '?' in url else url
    
def simple_bing_search(name):
    try:
        search_txt = name + ' goodreads book show'
        
        headers = {
            "User-Agent": random.choice(LIST_OF_USER_AGENTS)
        }
        
        search_url = f"https://www.bing.com/search?q={search_txt.replace(' ', '+')}"
        response = requests.get(search_url, headers=headers)
        
        if response.status_code != 200:
            return ''
            
        soup = BeautifulSoup(response.text, "html.parser")
        results = soup.find_all("li", class_="b_algo", limit=10)
        
        if not results:
            return ''
        
        for result in results:
            link_element = result.find("a")
            if link_element and "href" in link_element.attrs:
                url = link_element["href"]
                
                # Handle Bing's redirect URLs
                if 'bing.com/ck/a' in url:
                    # Extract the actual URL from Bing's redirect parameter
                    import urllib.parse
                    parsed = urllib.parse.parse_qs(urllib.parse.urlparse(url).query)
                    if 'u' in parsed:
                        # Decode the base64-like encoding that Bing uses
                        encoded_url = parsed['u'][0]
                        if encoded_url.startswith('a1'):
                            # Remove Bing's encoding prefix and decode
                            import base64
                            try:
                                decoded_bytes = base64.b64decode(encoded_url[2:] + '==')
                                actual_url = decoded_bytes.decode('utf-8')
                                if 'https://www.goodreads.com/book/' in actual_url:
                                    #print(actual_url)
                                    return actual_url
                            except:
                                pass
                
                # Fallback: check if it's already a direct URL
                if 'https://www.goodreads.com/book/' in url:
                    return url
                    
    except Exception as e:
        print(f"goodreads search error: {e}")
    
    return ''
        
def simple_google_search(name):
    try:
        search_txt = name + ' goodreads book show'
        results = search(search_txt, num_results=10)
        for url in results:
            if 'https://www.goodreads.com/book/' in url:
                return url
    except Exception as e:
        print(f"goodreads search error: {e}")
    return ''

def get_cover_images(search_term):
    # Add headers to mimic browser request
    headers = {
            "User-Agent": random.choice(LIST_OF_USER_AGENTS)
        }
    
    # Format search URL
    search_term1=search_term+' cover'
    search_url = f'https://www.google.com/search?q={search_term1}&tbm=isch'
    
    # Get page content
    response = requests.get(search_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all images
    image_urls = set()
    
    # Look for image URLs in script tags
    for script in soup.find_all('script'):
        if script.string:
            urls = re.findall(r'https?://[^"\']+(?:jpg|jpeg|png|gif)', script.string)
            for url in urls:
                if not url.startswith('data:'):
                    image_urls.add(url)
    
    # Also check <img> tags
    for img in soup.find_all('img'):
        src = img.get('src', '')
        if src.startswith('http') and not src.startswith('data:'):
            image_urls.add(src)
            
    # Also check metadata
    for meta in soup.find_all('meta'):
        content = meta.get('content', '')
        if content.startswith('http') and any(ext in content.lower() for ext in ['.jpg', '.jpeg', '.png', '.gif']):
            image_urls.add(content)

    image_list = list(image_urls)

    # Check for Amazon image URLs
    amazon_patterns = [
        "https://m.media-amazon.com/images/",
        "https://images-na.ssl-images-amazon.com/images"
    ]
    
    for url in image_list:
        if any(url.startswith(pattern) for pattern in amazon_patterns):
            return url  # return first Amazon match
    
    # If no Amazon image, return first image found (if any)
    # If no Amazon image, return first image with a valid extension
    for url in image_list:
        print(url)
        if re.search(r'\.(jpg|jpeg|png|gif)$', url, re.IGNORECASE):
            return url
    return None
    
def extract_search_query(url):
    parsed_url = urllib.parse.urlparse(url)
    params = urllib.parse.parse_qs(parsed_url.query)
    return params.get('q', [''])[0]


def remove_extra_spaces(text):
    return ' '.join(text.split())


def remove_parentheses_content(title):
    cleaned_title = re.sub(r'\([^)]*\)', '', title)
    return remove_extra_spaces(cleaned_title)


def normalize_text(text):
    import string
    text = remove_parentheses_content(text)
    text = remove_extra_spaces(text.lower())
    return text.translate(str.maketrans('', '', string.punctuation))


def calculate_similarity_score(search_title, book_title):
    search_words = set(normalize_text(search_title).split())
    book_words = set(normalize_text(book_title).split())
    common_words = {'the', 'a', 'an', 'and', 'or', 'but', 'in', 'on', 'at', 'to', 'for', 'of', 'with', 'by'}
    search_words -= common_words
    book_words -= common_words
    if not search_words:
        return 0
    return len(search_words & book_words) / len(search_words | book_words)


def is_author_match(search_author, book_authors):
    search_author_norm = normalize_text(search_author)
    for author in book_authors:
        author_norm = normalize_text(author)
        if search_author_norm == author_norm or \
           search_author_norm in author_norm or \
           author_norm in search_author_norm:
            return True
        if len(search_author_norm.split()) >= 2 and len(author_norm.split()) >= 2:
            if search_author_norm.split()[0] in author_norm and \
               search_author_norm.split()[-1] in author_norm:
                return True
    return False

def clean_title_for_comparison(title):
    if not title:
        return title
    cleaned = re.sub(r'\([^)]*\)', '', title)
    cleaned = re.sub(r'\(.*$', '', cleaned)
    return ' '.join(cleaned.split()).strip()


def parse_filename(filename):
    name_without_ext = filename.replace('.epub', '')
    if ' - ' in name_without_ext:
        parts = name_without_ext.split(' - ')
        if len(parts) >= 2:
            return ' - '.join(parts[:-1]).strip(), parts[-1].strip()
    return None, None


def clean_search_query(book_title, author_name):
    """
    Cleans and formats the search query for Goodreads search.

    Args:
        book_title (str): The title of the book.
        author_name (str): The name of the author.

    Returns:
        str: A cleaned search query string suitable for Goodreads search.
    """
    # Remove parentheses and extra content from the book title
    cleaned_title = clean_title_for_comparison(book_title)
    # If author name is unknown or not provided, use only the title
    if author_name.lower().strip() in ['unknown', 'n/a', 'na', 'anonymous', '']:
        query = cleaned_title
    else:
        # Otherwise, combine title and author for better search accuracy
        query = f"{cleaned_title} by {author_name}"
    # Replace problematic characters with spaces and strip leading/trailing spaces
    return re.sub(r'[&<>"|{}\\^`\[\]#%]', ' ', query).strip()

def check_file_exists(relative_path, base_path=r"C:\xampp8.2\htdocs\php_web_services_final\public"):
    """
    Check if a file exists by combining relative path with base path
    
    Args:
        relative_path (str): Relative path like "upload\Stephen Deas\The_King_of_the_Crags_-_Stephen_Deas.epub"
        base_path (str): Base directory path
    
    Returns:
        dict: Contains 'exists' (bool), 'full_path' (str), 'size_bytes', 'size_mb', etc.
    """
    try:
        # Normalize the paths to handle different slash types
        relative_path = relative_path.replace('/', os.sep).replace('\\', os.sep)
        
        # Combine base path with relative path
        full_path = os.path.join(base_path, relative_path)
        
        # Normalize the full path
        normalized_path = os.path.normpath(full_path)
        
        # Check if file exists
        file_exists = os.path.exists(normalized_path) and os.path.isfile(normalized_path)
        
        size_bytes = None
        size_mb = None
        
        if file_exists:
            size_bytes = os.path.getsize(normalized_path)
            size_mb = round(size_bytes / (1024 * 1024), 2)  # Convert bytes to MB
        
        return {
            'exists': file_exists,
            'full_path': normalized_path,
            'relative_path': relative_path,
            'size_bytes': size_bytes,
            'size_mb': size_mb
        }
        
    except Exception as e:
        return {
            'exists': False,
            'full_path': None,
            'relative_path': relative_path,
            'error': str(e),
            'size_bytes': None,
            'size_mb': None
        }

def save_results_to_file(results, output_file="goodreads_search_results.txt"):
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write("Goodreads Search Results\n" + "=" * 50 + "\n\n")
            for filename, result in results.items():
                f.write(f"File: {filename}\n")
                for key, val in result.items():
                    f.write(f"{key.capitalize()}: {val}\n")
                f.write("\n")
        print(f"\n📄 Results saved to: {output_file}")
    except Exception as e:
        print(f"Error saving results: {e}")


def scrape_goodreads_books(url, author_name, book_title=None):
    try:
        headers = {
        "User-Agent": random.choice(LIST_OF_USER_AGENTS),
        "Accept-Language": "en-US,en;q=0.9",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp",
        "Referer": "https://www.google.com/"
        }
        request = urllib.request.Request(url, headers=headers)
        with urllib.request.urlopen(request) as response:
            source = response.read()

        soup = BeautifulSoup(source, "html.parser")
        book_containers = soup.find_all('tr', itemtype='http://schema.org/Book')

        if not book_containers:
            book_containers = soup.find_all('tr', {'itemtype': 'http://schema.org/Book'})
        if not book_containers:
            return None

        book_matches = []
        search_query = extract_search_query(url)
        search_title = book_title if book_title else search_query

        for container in book_containers:
            try:
                title_element = container.find('a', class_='bookTitle')
                if not title_element:
                    continue
                title_link = title_element.get("href")
                raw_title = title_element.text.strip()
                if not title_link:
                    continue

                cleaned_title = remove_parentheses_content(raw_title)
                authors = [a.text.strip() for a in container.find_all('a', class_='authorName')]
                complete_book_url = clean_url(GOODREADS_URL + title_link)
                author_match = is_author_match(author_name, authors)
                title_similarity = calculate_similarity_score(search_title, cleaned_title)
                score = 0.7 * (1.0 if author_match else 0.0) + 0.3 * title_similarity

                book_matches.append({
                    'title': raw_title,
                    'cleaned_title': cleaned_title,
                    'authors': authors,
                    'url': complete_book_url,
                    'author_match': author_match,
                    'title_similarity': title_similarity,
                    'score': score
                })
            except Exception as e:
                print(f"Error processing container: {e}")

        book_matches.sort(key=lambda x: x['score'], reverse=True)

        if book_matches:
            best_match = book_matches[0]
            confidence = (
                "High" if best_match['author_match'] and best_match['title_similarity'] > 0.5
                else "Medium" if best_match['author_match'] or best_match['title_similarity'] > 0.3
                else "Low"
            )
            return best_match['url']

        return None

    except Exception as e:
        return None

def scrape_goodreads_books_raw(url, author_name, book_title=None):
    try:
        headers = {
        "User-Agent": random.choice(LIST_OF_USER_AGENTS),
        "Accept-Language": "en-US,en;q=0.9",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp",
        "Referer": "https://www.google.com/"
        }
        request = urllib.request.Request(url, headers=headers)
        with urllib.request.urlopen(request) as response:
            source = response.read()

        soup = BeautifulSoup(source, "html.parser")
        book_containers = soup.find_all('tr', itemtype='http://schema.org/Book')

        if not book_containers:
            book_containers = soup.find_all('tr', {'itemtype': 'http://schema.org/Book'})
        if not book_containers:
            return None

        book_matches = []
        search_query = extract_search_query(url)
        search_title = book_title if book_title else search_query

        for container in book_containers:
            try:
                title_element = container.find('a', class_='bookTitle')
                if not title_element:
                    continue
                title_link = title_element.get("href")
                raw_title = title_element.text.strip()
                if not title_link:
                    continue

                cleaned_title = remove_parentheses_content(raw_title)
                authors = [a.text.strip() for a in container.find_all('a', class_='authorName')]
                complete_book_url = clean_url(GOODREADS_URL + title_link)
                author_match = is_author_match(author_name, authors)
                title_similarity = calculate_similarity_score(search_title, raw_title)
                score = 0.7 * (1.0 if author_match else 0.0) + 0.3 * title_similarity

                book_matches.append({
                    'title': raw_title,
                    'cleaned_title': cleaned_title,
                    'authors': authors,
                    'url': complete_book_url,
                    'author_match': author_match,
                    'title_similarity': title_similarity,
                    'score': score
                })
            except Exception as e:
                print(f"Error processing container: {e}")

        book_matches.sort(key=lambda x: x['score'], reverse=True)
        print(f"Found {len(book_matches)} matches for '{search_title}' by '{author_name}'")
        for match in book_matches:
            print(f"  - {match['title']} by {', '.join(match['authors'])} (Score: {match['score']:.2f})")

        if book_matches:
            best_match = book_matches[0]
            confidence = (
                "High" if best_match['author_match'] and best_match['title_similarity'] > 0.5
                else "Medium" if best_match['author_match'] or best_match['title_similarity'] > 0.3
                else "Low"
            )
            return best_match['url']

        return None

    except Exception as e:
        print(f"Error scraping Goodreads books: {e}")
        return None
    
    
def process_epub_folder(folder_path, delay_seconds=2):
    folder_path = Path(folder_path)
    if not folder_path.exists():
        return {}

    epub_files = list(folder_path.glob('*.epub'))
    if not epub_files:
        return {}

    results = {}
    for i, epub_file in enumerate(epub_files, 1):
        filename = epub_file.name
        book_title, author_name = parse_filename(filename)
        book_url_local = filename.replace(' ', '_')

        if not book_title or not author_name:
            results[filename] = {'status': 'failed', 'reason': 'Could not parse filename'}
            continue

        search_query = clean_search_query(book_title, author_name)
        search_url = GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': search_query})
        print(f"  🔍 Searching: {search_url} for '{book_title}' by '{author_name}'")
        goodreads_url = scrape_goodreads_books(search_url, author_name, book_title)

        if goodreads_url:
            headers = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}
            book_info = scrape_book(goodreads_url, book_url_local, headers)
            results[filename] = {'status': 'success', 'goodreads_url': goodreads_url, 'book_info': book_info}
        else:
            #results[filename] = extract_epub_metadata(fname)
            corrected_title = fix_ebook_title_with_gemini(book_title, author_name)
            search_query = clean_search_query(corrected_title, author_name)
            search_url = GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': search_query})
            print(f"  🔍 Searching again: {search_url} for '{book_title}' by '{author_name}'")
            goodreads_url = scrape_goodreads_books(search_url, author_name, corrected_title)
            if goodreads_url:
                headers = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}
                #book_info = scrape_book(goodreads_url, book_url_local, headers)
                results[filename] = {'status': 'success', 'goodreads_url': goodreads_url, 'book_info': book_info}
            else:
                results[filename] = {'status': 'not_found'}
            

        if i < len(epub_files):
            time.sleep(delay_seconds)

    return results



def search_book_id(book_id,csv_file = 'books.csv'):
    """
    Search for a specific book ID in the 'tbl_books.csv' file.

    Args:
        csv_file (str): Path to the CSV file containing book data.
        book_id (int or str): The book ID to search for in the CSV file.

    Returns:
        bool: True if the book ID is found, False otherwise.

    Raises:
        FileNotFoundError: If the CSV file cannot be found or opened.

    
    """
    
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            
            # Loop through each row in the CSV
            for row in reader:
                # Check if the current row's 'id' matches the given book_id
                if row['id'] == str(book_id):
                    return True  # Return True if the book_id is found
        return False  # Return False if not found
    except FileNotFoundError:
        print(f"Error: The file {csv_file} was not found.")
        return False            

def check_book_id(book_id,csv_file):
    """
    Search for a specific book ID in the 'tbl_books.csv' file.

    Args:
        csv_file (str): Path to the CSV file containing book data.
        book_id (int or str): The book ID to search for in the CSV file.

    Returns:
        bool: True if the book ID is found, False otherwise.

    Raises:
        FileNotFoundError: If the CSV file cannot be found or opened.

    
    """
    
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            
            # Loop through each row in the CSV
            for row in reader:
                # Check if the current row's 'id' matches the given book_id
                if row['id'] == str(book_id):
                    return True  # Return True if the book_id is found
        return False  # Return False if not found
    except FileNotFoundError:
        print(f"Error: The file {csv_file} was not found.")
        return False            


def check_and_append_aid(aid, csv_file='aid1.csv'):
    """
    Checks if an author ID exists in the CSV file, and if not, appends it on a new line.
    If the file is empty, adds a header before appending the ID.

    Args:
        aid (str): The author ID to search for.
        csv_file (str): The path to the CSV file (default is 'aid1.csv').

    Returns:
        bool: True if the ID was appended, False if it already existed.
    """
    aid_exists = False
    
    # Check if the file exists and is empty
    file_exists = os.path.exists(csv_file)
    file_empty = os.path.getsize(csv_file) == 0 if file_exists else True

    # Read the CSV and check if the ID exists
    if not file_empty:
        try:
            with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
                reader = csv.DictReader(file)
                for row in reader:
                    if row['aid'] == str(aid):
                        aid_exists = True
                        break
        except FileNotFoundError:
            print(f"File {csv_file} not found, creating a new one.")

    # If the ID doesn't exist, append it to the file
    if not aid_exists:
        with open(csv_file, mode='a', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            if file_empty:  # Add header if the file is empty or newly created
                writer.writerow(['aid'])
            writer.writerow([aid])  # Append the ID on a new line
        print(f"Appended ID {aid} to {csv_file}.")
        return True
    else:
        print(f"ID {aid} already exists in {csv_file}.")
        return False

def append_to_book_csv(book_data, csv_file):
    """
    Appends the book data to the specified CSV file.

    Args:
        book_data (dict): A dictionary containing book details.
        csv_file (str): The path to the CSV file where the data should be appended.
    """
    fieldnames = ['id', 'cat_id', 'sub_cat_id', 'author_ids', 'book_access', 'title', 
                  'description', 'image', 'url_type', 'url', 'download_enable',
                  'book_on_rent', 'book_rent_price', 'book_rent_time', 'featured', 'status']

    # Check if the file exists to write the header only if it's a new file
    try:
        with open(csv_file, mode='a', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)

            # Write header only if file is empty or does not exist
            if file.tell() == 0:
                writer.writeheader()

            # Write the book data
            writer.writerow(book_data)
            print(f"Appended data for book '{book_data['title']}' to {csv_file}.")
    
    except IOError as e:
        print(f"An I/O error occurred: {e}")

def move_and_rename_epub(source_path, destination_directory, new_name):
    """
    Move an EPUB file from the source path to the destination directory and rename it.

    Args:
        source_path (str): The path to the source EPUB file.
        destination_directory (str): The path to the destination directory.
        new_name (str): The new name for the EPUB file (including .epub extension).

    Returns:
        str: The path to the newly moved and renamed EPUB file.
    """
    if not os.path.isfile(source_path):
        print(f"Source file '{source_path}' does not exist.")
        return None

    if not os.path.isdir(destination_directory):
        print(f"Destination directory '{destination_directory}' does not exist.")
        return None

    new_file_path = os.path.join(destination_directory, new_name)

    try:
        shutil.move(source_path, new_file_path)
        print(f"File moved and renamed to '{new_file_path}'.")
        return new_file_path
    except Exception as e:
        print(f"Error moving or renaming file: {e}")
        return None

# %%
 # Example usage:
book_url = get_cover_images("The Great Gatsby")
print(book_url)

# %%
book='The Awakeni - Kelley Armstrong.epub'
book_title, author_name = parse_filename(book)
print(f"Book Title: {book_title}, Author Name: {author_name}")
bookname = f"{book_title} by {author_name}"
search_url = GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': bookname})
print(f"  🔍 Searching: {search_url} for '{book_title}' by '{author_name}'")


url=simple_bing_search(bookname)
if url:
    print(f"Found Goodreads URL via Google search: {url}")
    goodreads_url = url
else:
    print("No matching book found on Goodreads.")

# %%
def get_epub_info(fname):
    """
    Extracts metadata from an EPUB file.

    Args:
        fname (str): The path to the EPUB file.

    Returns:
        dict: A dictionary containing the extracted metadata, including 'title' and 'creator',
              or None if an error occurs.
    """
    ns = {
        # Namespace for the container.xml file
        'n': 'urn:oasis:names:tc:opendocument:xmlns:container',
        'pkg': 'http://www.idpf.org/2007/opf',  # Namespace for the package metadata
        'dc': 'http://purl.org/dc/elements/1.1/'  # Namespace for Dublin Core metadata
    }

    try:
        # Open the EPUB file
        zip = zipfile.ZipFile(fname)

        # Read the content of the container.xml file
        txt = zip.read('META-INF/container.xml')
        tree = etree.fromstring(txt)  # Parse the XML content
        
        # Extract the path of the contents metafile
        cfname = tree.xpath('n:rootfiles/n:rootfile/@full-path', namespaces=ns)[0]

        # Read the contents metafile
        cf = zip.read(cfname)  # Read the contents metafile
        tree = etree.fromstring(cf)  # Parse the XML content

        # Extract the metadata block
        p = tree.xpath('/pkg:package/pkg:metadata', namespaces=ns)[0]

        # Repackage the data
        res = {}  # Initialize a dictionary to store the metadata
        for s in ['title', 'creator']:
            # Extract the text content of each metadata element
            res[s] = p.xpath(f'dc:{s}/text()', namespaces=ns)[0]

        return res  # Return the metadata dictionary
    
    except (zipfile.BadZipFile, KeyError, etree.XMLSyntaxError, IndexError) as e:
        # Handle specific exceptions (e.g., invalid EPUB format, missing metadata)
        print(f"Error reading EPUB file '{fname}': {e}")
        return None
    except Exception as e:
        # Handle other unexpected exceptions
        print(f"An unexpected error occurred: {e}")
        return None
    
def extract_epub_metadata(fname):
    """
    Extract title and author from an EPUB file using ebooklib.

    Args:
        fname (str): Path to the EPUB file.

    Returns:
        dict: Dictionary with keys 'title' and 'creator' (author), or None if reading fails.
    """
    try:
        book = epub.read_epub(fname)
        title = book.get_metadata('DC', 'title')
        creator = book.get_metadata('DC', 'creator')

        return {
            'title': title[0][0] if title else None,
            'creator': creator[0][0] if creator else None
        }
    except Exception:
        return None


def is_book_id_in_books_csv(book_id, csv_file='books.csv'):
    """
    Check if a book ID exists in the specified books CSV file.

    Args:
        book_id (int or str): The book ID to search for.
        csv_file (str): Path to the CSV file containing book data.

    Returns:
        bool: True if the book ID is found, False otherwise.
    """
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                if row['id'] == str(book_id):
                    return True
        return False
    except FileNotFoundError:
        print(f"Error: The file '{csv_file}' was not found.")
        return False


def book_exists_in_csv(book_id, csv_file):
    """
    Same as is_book_id_in_books_csv but for generic use with explicit csv_file.

    Args:
        book_id (int or str): The book ID to search for.
        csv_file (str): Path to the CSV file containing book data.

    Returns:
        bool: True if found, False otherwise.
    """
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                if row['id'] == str(book_id):
                    return True
        return False
    except FileNotFoundError:
        print(f"Error: The file '{csv_file}' was not found.")
        return False


def is_author_id_in_authors_csv(aid, csv_file='authors.csv'):
    """
    Check if an author ID exists in the specified authors CSV file.

    Args:
        aid (int or str): Author ID to check.
        csv_file (str): Path to the author CSV file.

    Returns:
        bool: True if the author ID is found, False otherwise.
    """
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.reader(file)
            for row in reader:
                if row[0] == str(aid):
                    return True
        return False
    except FileNotFoundError:
        print(f"File '{csv_file}' not found.")
        return False

def is_book_in_csv(book_file_url, csv_file):
    """
    Checks if a book with the given file URL is present in the specified CSV file.

    Args:
        book_file_url (str): The file URL of the book to search for.
        csv_file (str): The path to the CSV file.

    Returns:
        bool: True if the book is found in the CSV file, otherwise False.
    """
    try:
        with open(csv_file, mode='r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)

            if 'url' not in reader.fieldnames:
                print("Error: The CSV file does not contain a 'url' column.")
                return False

            for row in reader:
                if row['url'].strip() == book_file_url.strip():
                    return True

        return False

    except FileNotFoundError:
        print(f"Error: The file '{csv_file}' does not exist.")
        return False
    except Exception as e:
        print(f"An error occurred while reading the CSV: {e}")
        return False

def search_epub_by_name(epub_name, root_dir=r'C:\xampp8.2\htdocs\php_web_services_final\public\upload'):
    """
    Searches for an EPUB file by name within the specified root directory and its subdirectories.
    
    Args:
        epub_name (str): The name of the EPUB file to search for (can be full name or partial match).
        root_dir (str): The root directory to start the search from.
        
    Returns:
        str: The full path to the EPUB file if found, otherwise None.
    """
    for dirpath, _, filenames in os.walk(root_dir):
        for file in filenames:
            if file.lower().endswith(".epub") and epub_name.lower() in file.lower():
                return os.path.join(dirpath, file)
    
    return None  # Not found

# %%
csv_file1 = 'authorsoceanofpdf.csv'
csv_file = csv.reader(open('aid1.csv', "r", encoding='utf-8'), delimiter=",")
next(csv_file)
for row in csv_file:
    try:
        if row:
            a_id = row[0].strip()
            if not is_author_id_in_csv(a_id) and not is_author_id_in_local_csv(a_id, csv_file1):
                print('========> adding author id '+a_id)
                author_data = scrape_author(a_id)  # Scrape author data
                append_author_to_csv('authorsoceanofpdf.csv', author_data)
                print(f"+++++++++> {author_data['name']} added")
                time.sleep(3)
            else:
                print(f"{a_id} is already in the CSV file.")
    except Exception as e:
        print(f"Error processing author ID {a_id}: {e}")
        continue

# %%
import os
import csv
import random
import urllib.parse
import time  # <-- Added for tracking execution time

# === Track start time ===
start_time = time.time()

# === Constants ===
START_DIR = r'C:\cracks\My_App\epub-library-manager\All_Books'
BOOKS_FOLDER = os.path.join(os.getcwd(), 'books')
CSV_FILE = os.path.join(BOOKS_FOLDER, 'allbooks.csv')
AUTHOR_ID_CSV = 'aid1.csv'
UPLOAD_FOLDER = 'upload'
GOODREADS_URL = 'https://www.goodreads.com'

# === Ensure required folders and files exist ===
os.makedirs(BOOKS_FOLDER, exist_ok=True)
if not os.path.exists(CSV_FILE):
    with open(CSV_FILE, mode='w', newline='') as f:
        pass

# === Counters ===
processed_books = 0
skipped_books = 0
already_added_books = 0

# === Count EPUBs ===
total_epub_files = sum(
    file.lower().endswith('.epub') for _, _, files in os.walk(START_DIR) for file in files
)

print(f"📚 Found {total_epub_files} EPUB files to process...")
print("=" * 50)

# === Helper function to process valid scraped book ===
def process_scraped_book(book_info, epub_path, current_csv, author_name, book_url_local):
    try:
        authorid = book_info["author_ids"]
        author_ids = authorid.split(',') if ',' in authorid else [authorid]

        for author in author_ids:
            check_and_append_aid(author.strip(), csv_file=AUTHOR_ID_CSV)

        if author_name.lower() == 'unknown':
            new_author_id = author_ids[0].strip()

        print('Book scraped ----> ' + book_info['id'])

        dest = os.path.join(UPLOAD_FOLDER, author_name)
        os.makedirs(dest, exist_ok=True)

        new_file_path = move_and_rename_epub(epub_path, dest, book_url_local)
        book_info['url'] = new_file_path

        append_to_book_csv(book_info, current_csv)
        return True

    except Exception as e:
        print(f"❌ Error during book processing: {e}")
        return False

# === Main EPUB Processing Loop ===
current_book = 0
for root, _, files in os.walk(START_DIR):
    for file in files:
        if not file.lower().endswith('.epub'):
            continue

        current_book += 1
        epub_path = os.path.join(root, file)
        book_title, author_name = parse_filename(file)

        if not book_title or not author_name:
            print(f"❌ Ebook {current_book} of {total_epub_files}: Skipping '{file}' due to missing title or author.")
            skipped_books += 1
            continue

        book_url_local = file.replace(' ', '_')
        url_book = os.path.join(UPLOAD_FOLDER, book_url_local)

        if is_book_in_csv(url_book, CSV_FILE):
            print(f"📋 Ebook {current_book} of {total_epub_files}: '{file}' already exists in CSV, skipping...")
            already_added_books += 1
            continue

        bookname = f"{book_title} by {author_name}"
        print(f'📖 Ebook {current_book} of {total_epub_files}: Working on {bookname}')

        search_url = GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': bookname})
        print(f"  🔍 Searching: {search_url} for '{book_title}' by '{author_name}'")

        # === Try multiple search methods with debug prints ===
        goodreads_url = None
        search_attempts = [
            ("Goodreads Search", lambda: scrape_goodreads_books(search_url, author_name, book_title)),
            ("Raw Goodreads Search", lambda: scrape_goodreads_books_raw(
                GOODREADS_URL + '/search?' + urllib.parse.urlencode({'q': clean_search_query(book_title, author_name)}),
                author_name, None
            )),
            ("Google Search", lambda: simple_google_search(bookname)),
            ("Bing Search", lambda: simple_bing_search(bookname))
        ]

        for label, method in search_attempts:
            print(f"🔍 Trying method: {label}")
            try:
                goodreads_url = method()
            except Exception as e:
                print(f"⚠️ Error during '{label}': {e}")
                goodreads_url = None

            if goodreads_url:
                print(f"✅ Method '{label}' succeeded with URL: {goodreads_url}")
                break
            else:
                print(f"❌ Method '{label}' failed to find a result.")

        if goodreads_url:
            try:
                headers = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}
                book_info, author_folder = scrape_book(goodreads_url, book_url_local, headers)

                if not search_book_id(book_info['id']) and not check_book_id(book_info['id'], CSV_FILE):
                    success = process_scraped_book(book_info, epub_path, CSV_FILE, author_folder, book_url_local)
                    if success:
                        processed_books += 1
                        print(f'✅ Ebook {current_book} of {total_epub_files}: Processing {bookname} completed! (Total processed: {processed_books})')
                    else:
                        skipped_books += 1
                else:
                    print(f"🔄 Ebook {current_book} of {total_epub_files}: {book_info['title']} already in database, deleting file...")
                    try:
                        os.remove(epub_path)
                    except Exception as e:
                        print(f"⚠️ Could not delete file {epub_path}: {e}")
                    already_added_books += 1
            except Exception as e:
                print(f"❌ Error scraping from Goodreads: {e}")
                skipped_books += 1
        else:
            print(f"❌ Ebook {current_book} of {total_epub_files}: No Goodreads URL found for '{bookname}'")
            skipped_books += 1

# === Final Summary ===
end_time = time.time()
duration = end_time - start_time
hours, remainder = divmod(duration, 3600)
minutes, seconds = divmod(remainder, 60)

print("\n" + "=" * 60)
print("📊 PROCESSING SUMMARY")
print("=" * 60)
print(f"📚 Total EPUB files found: {total_epub_files}")
print(f"✅ Successfully processed: {processed_books}")
print(f"🔄 Already in database (deleted): {already_added_books}")
print(f"⚠️  Skipped due to missing info or errors: {skipped_books}")
print(f"📈 Success rate: {(processed_books / total_epub_files * 100):.1f}%" if total_epub_files else "📈 Success rate: 0%")
print("=" * 60)
print(f"⏱️  Total time taken: {int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}")
print("=" * 60)

# %%
# ==== Your existing constants ====
BOOKS_FOLDER = os.path.join(os.getcwd(), 'books')
CSV_FILE = os.path.join(BOOKS_FOLDER, 'final_allbooks.csv')

# ==== MySQL Connection (XAMPP) ====
conn = mysql.connector.connect(
    host="localhost",     # XAMPP MySQL host
    user="root",          # XAMPP MySQL username
    password="",          # XAMPP MySQL password (empty by default)
    database="final_klaus_ebooks_library"
)
cursor = conn.cursor()

# ==== MySQL Check if Book Exists ====
def check_book_url_id(book_id):
    """
    Checks if a book with the given URL already exists in MySQL.
    """
    cursor.execute("SELECT COUNT(*) FROM books WHERE id = %s", (book_id,))
    count = cursor.fetchone()[0]
    return count > 0

# ==== MySQL Insert Function ====
def insert_book_to_mysql(book_data):
    try:
        insert_query = """
            INSERT INTO books (
                id, cat_id, sub_cat_id, author_ids, book_access,
                title, description, image, url_type, url,
                download_enable, book_on_rent, book_rent_price, book_rent_time,
                featured, status
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """
        cursor.execute(insert_query, (
            book_data.get("id", ""),
            book_data.get("cat_id", ""),
            book_data.get("sub_cat_id", ""),
            book_data.get("author_ids", ""),
            book_data.get("book_access", ""),
            book_data.get("title", ""),
            book_data.get("description", ""),
            book_data.get("image", ""),
            book_data.get("url_type", ""),
            book_data.get("url", ""),
            book_data.get("download_enable", ""),
            book_data.get("book_on_rent", ""),
            book_data.get("book_rent_price", ""),
            book_data.get("book_rent_time", ""),
            book_data.get("featured", ""),
            book_data.get("status", "")
        ))
        conn.commit()
        print(f"📚 Book '{book_data.get('title', '')}' inserted into MySQL successfully.")
    except Exception as e:
        print(f"❌ MySQL insert error: {e}")

# ==== Read CSV ====
csv_file = csv.reader(open('books_final2.csv', "r", encoding='utf-8'), delimiter=",")
next(csv_file)  # Skip header row

# Count total rows for progress display
with open('books_final2.csv', "r", encoding='utf-8') as f:
    total_epub_files = sum(1 for _ in f) - 1  # minus header

counter = 0

# ==== Main Loop ====
for i, row in enumerate(csv_file):
    if i >= 1200:  # Limit for testing
        break
    if row:
        counter += 1
        author_book_id = row[0].strip()
        cat_id = row[1].strip() if len(row) > 1 else ""
        sub_cat_id = row[2].strip() if len(row) > 2 else ""
        author_ids = row[3].strip() if len(row) > 3 else ""
        book_access = row[4].strip() if len(row) > 4 else ""
        title = row[5].strip() if len(row) > 5 else ""
        description = row[6].strip() if len(row) > 6 else ""
        image = row[7].strip() if len(row) > 7 else ""
        url_type = row[8].strip() if len(row) > 8 else ""
        book_url_local = row[9].strip() if len(row) > 9 else ""
        download_enable = row[10].strip() if len(row) > 10 else ""
        book_on_rent = row[11].strip() if len(row) > 11 else ""
        book_rent_price = row[12].strip() if len(row) > 12 else ""
        book_rent_time = row[13].strip() if len(row) > 13 else ""
        featured = row[14].strip() if len(row) > 14 else ""
        status = row[15].strip() if len(row) > 15 else ""

        try:
            goodreads_url = 'https://www.goodreads.com/book/show/' + author_book_id
            headers = {'User-Agent': random.choice(LIST_OF_USER_AGENTS)}
            filename = os.path.basename(book_url_local)

            if not check_book_url_id(author_book_id):
                result = search_epub_by_name(filename)
                if result:
                    print(f"✅ Found: {result}")
                    book_info, author_folder = scrape_book(goodreads_url, book_url_local, headers)

                    # Use the scraped book_info instead of CSV data
                    insert_book_to_mysql(book_info)
                    print(f'✅✅✅ Ebook {counter} of {total_epub_files}: "{book_info["title"]}" processed!')
                else:
                    print(f'❌❌ Ebook {counter} of {total_epub_files}: "{title}" not found.')
            else:
                print(f'⏩ Ebook "{title}" already in database.')

        except Exception as e:
            print(f"❌ Error processing row: {e}")

# ==== Close MySQL ====
cursor.close()
conn.close()

print(f'Total books processed: {counter}')
# Out:
# ⏩ Ebook "Murder Comes Calling" already in database.
# ⏩ Ebook "The Witch Elm" already in database.
# ⏩ Ebook "Divine Rival" already in database.
# ⏩ Ebook "Bound by Their Christmas Baby" already in database.
# ⏩ Ebook "The Faceless Woman" already in database.
# ⏩ Ebook "A Christmas Most Alien" already in database.
# ⏩ Ebook "Forgotten" already in database.
# ⏩ Ebook "A Curious Invasion" already in database.
# ⏩ Ebook "Chevelle" already in database.
# ⏩ Ebook "Baiting A Berserker" already in database.
# ⏩ Ebook "Runes of Mortality" already in database.
# ⏩ Ebook "Finding His Wife, Finding A Son" already in database.
# ⏩ Ebook "From Doctor To Princess?" already in database.
# ⏩ Ebook "The Shy Nurse's Rebel Doc" already in database.
# ⏩ Ebook "Allies" already in database.
# ⏩ Ebook "Gray Mountain: A Novel" already in database.
# ⏩ Ebook "An Innocent, A Seduction, A Secret" already in database.
# ⏩ Ebook "The Billionaire's Christmas Cinderella" already in database.
# ⏩ Ebook "A Justified Murder" already in database.
# ⏩ Ebook "Hell's Legacy" already in database.
# ⏩ Ebook "Billionaire Bachelor: Justin" already in database.
# ⏩ Ebook "Magic after Midnight (After the Fire, #2)" already in database.
# ⏩ Ebook "Reckoning of Fallen Gods" already in database.
# ⏩ Ebook "One Tough Cowboy" already in database.
# ⏩ Ebook "Dark Tribute" already in database.
# ⏩ Ebook "True Light" already in database.
# ⏩ Ebook "Want Me, Cowboy" already in database.
# ⏩ Ebook "Divine Ambrosia" already in database.
# ⏩ Ebook "Hard to Kill" already in database.
# ⏩ Ebook "Hitched" already in database.
# ⏩ Ebook "A Choice of Secrets" already in database.
# ⏩ Ebook "Alphas and Airships" already in database.
# ⏩ Ebook "Before the Raging Lion" already in database.
# ⏩ Ebook "The Reaper Rescues The Genie" already in database.
# ⏩ Ebook "A Voyage of Founders" already in database.
# ⏩ Ebook "Souls Tethered" already in database.
# ⏩ Ebook "By Earth" already in database.
# ⏩ Ebook "Bridging the Distance" already in database.
# ⏩ Ebook "Ascendant" already in database.
# ⏩ Ebook "Forgiving the Dragon" already in database.
# ⏩ Ebook "The Phoenix Illusion" already in database.
# ⏩ Ebook "Kellanved's Reach" already in database.
# ⏩ Ebook "Charmed" already in database.
# ⏩ Ebook "Devil's Legacy" already in database.
# ⏩ Ebook "Fire & Blood" already in database.
# ⏩ Ebook "Blood Moon" already in database.
# ⏩ Ebook "Mr. June" already in database.
# ⏩ Ebook "Rebuilding the Wolf" already in database.
# ⏩ Ebook "Beyond Love and Hate" already in database.
# ⏩ Ebook "A Winter's Promise" already in database.
# ⏩ Ebook "Portents" already in database.
# ⏩ Ebook "The 18th Abduction" already in database.
# ⏩ Ebook "Blood for Blood" already in database.
# ⏩ Ebook "A Tangled Fate" already in database.
# ⏩ Ebook "Imprison the Sky" already in database.
# ⏩ Ebook "Don’t Stop Bewitching" already in database.
# ⏩ Ebook "No Man Can Tame" already in database.
# ⏩ Ebook "Dark Fae F.B.I. Complete Series: An Urban Fantasy Boxed Set" already in database.
# ⏩ Ebook "Aimless Witch" already in database.
# ⏩ Ebook "Ash" already in database.
# ⏩ Ebook "Ten Two Jack" already in database.
# ⏩ Ebook "The Belial Sacrifice" already in database.
# ⏩ Ebook "Iron Maiden" already in database.
# ⏩ Ebook "The Princess in the Tower" already in database.
# ⏩ Ebook "Alpha's War" already in database.
# ⏩ Ebook "Happy Ever Afterlife, Part 2" already in database.
# ⏩ Ebook "Always a Demon" already in database.
# ⏩ Ebook "Xander" already in database.
# ⏩ Ebook "The Old Drift" already in database.
# ⏩ Ebook "Mr. July" already in database.
# ⏩ Ebook "Hunger of the Dragon" already in database.
# ⏩ Ebook "Revenge of the Dragon" already in database.
# ⏩ Ebook "Highlander's Stolen Destiny" already in database.
# ⏩ Ebook "The Summer Sword" already in database.
# ⏩ Ebook "Royal Weddings" already in database.
# ⏩ Ebook "Southern Sorcery" already in database.
# ⏩ Ebook "I Walk the Bloody Line" already in database.
# ⏩ Ebook "Long, Tall Texans: Jobe" already in database.
# ⏩ Ebook "Princess in Lingerie" already in database.
# ⏩ Ebook "Loving a Stranger" already in database.
# ⏩ Ebook "Don't Cheat Me" already in database.
# ⏩ Ebook "Division 5" already in database.
# ⏩ Ebook "Connections in Death" already in database.
# ⏩ Ebook "Autumn Magic" already in database.
# ⏩ Ebook "Safe Haven" already in database.
# ⏩ Ebook "Adelaide's Fate" already in database.
# ⏩ Ebook "Captivity" already in database.
# ⏩ Ebook "Lassoed" already in database.
# ⏩ Ebook "Theodore" already in database.
# ⏩ Ebook "Viking King's Vendetta" already in database.
# ⏩ Ebook "Invaders" already in database.
# ⏩ Ebook "Murder in the Dark" already in database.
# ⏩ Ebook "You Will Suffer" already in database.
# ⏩ Ebook "Whiskey Ginger" already in database.
# ⏩ Ebook "Ten Little Girls" already in database.
# ⏩ Ebook "The Overstory" already in database.
# ⏩ Ebook "Blood Promise" already in database.
# ⏩ Ebook "Scorched Fury" already in database.
# ⏩ Ebook "The Severed Realm" already in database.
# ⏩ Ebook "Shallow Grave" already in database.
# ⏩ Ebook "Cosmopolitan" already in database.
# ⏩ Ebook "Old Fashioned" already in database.
# ⏩ Ebook "Dark and Stormy" already in database.
# ⏩ Ebook "Gambler" already in database.
# ⏩ Ebook "His Rogue Bear" already in database.
# ⏩ Ebook "Fatal Dawn" already in database.
# ⏩ Ebook "Alpha Rises" already in database.
# ⏩ Ebook "Kaiden" already in database.
# ⏩ Ebook "A Land of Perfects" already in database.
# ⏩ Ebook "The Fifth Britain" already in database.
# ⏩ Ebook "Tree of Ages" already in database.
# ⏩ Ebook "Misfits, Gemstones, and Other Shattered Magic" already in database.
# ⏩ Ebook "Queen of the Shining Sea" already in database.
# ⏩ Ebook "The River" already in database.
# ⏩ Ebook "Defending His Mate's Honor" already in database.
# ⏩ Ebook "Dragon Prophecy" already in database.
# ⏩ Ebook "Dracula Night" already in database.
# ⏩ Ebook "Awakening: The Balance Bringer" already in database.
# ⏩ Ebook "Survivor Skills" already in database.
# ⏩ Ebook "Can't Be Love" already in database.
# ⏩ Ebook "Witchy See, Witchy Do" already in database.
# ⏩ Ebook "Born into Darkness" already in database.
# ⏩ Ebook "Mr. August" already in database.
# ⏩ Ebook "The Night Universe Collection" already in database.
# ⏩ Ebook "The First Lady" already in database.
# ⏩ Ebook "Dirty Rich Obsession" already in database.
# ⏩ Ebook "Shadow on the Wing" already in database.
# ⏩ Ebook "Hour of Darkness" already in database.
# ⏩ Ebook "The Hybrid Sovereign" already in database.
# ⏩ Ebook "The Billionaire's Marriage Deal: Her Little White Lie\The Couple who Fooled the World" already in database.
# ⏩ Ebook "Stratus" already in database.
# ⏩ Ebook "The Scorpion and His Prey" already in database.
# ⏩ Ebook "Entangled" already in database.
# ⏩ Ebook "Bolivar's Sword" already in database.
# ⏩ Ebook "Varina" already in database.
# ⏩ Ebook "Southern Curses" already in database.
# ⏩ Ebook "Devil's Daughter" already in database.
# ⏩ Ebook "The Ink Master's Silence" already in database.
# ⏩ Ebook "Antigen" already in database.
# ⏩ Ebook "The Price of Paradise" already in database.
# ⏩ Ebook "Craft Circle Cozy Mystery Boxed Set: Books 1 - 9" already in database.
# ⏩ Ebook "The Spear of Stars" already in database.
# ⏩ Ebook "Ghostly Despair" already in database.
# ⏩ Ebook "Oracle's Haunt" already in database.
# ⏩ Ebook "Wild Country" already in database.
# ⏩ Ebook "Alexis: A Clone Crisis Prequel" already in database.
# ⏩ Ebook "Handle With Care" already in database.
# ⏩ Ebook "Steel and Stone" already in database.
# ⏩ Ebook "Harley Merlin and the Secret Coven" already in database.
# ⏩ Ebook "Life with a Dragon" already in database.
# ⏩ Ebook "The Librarian and the Dragon" already in database.
# ⏩ Ebook "Driven" already in database.
# ⏩ Ebook "Deviant Warrior" already in database.
# ⏩ Ebook "Scarred Warrior" already in database.
# ⏩ Ebook "Hellbound Warrior" already in database.
# ⏩ Ebook "Claiming his Secret Baby" already in database.
# ⏩ Ebook "Killer Instinct" already in database.
# ⏩ Ebook "Heart Surgeon to Single Dad" already in database.
# ⏩ Ebook "Knight Shift" already in database.
# ⏩ Ebook "North's Nikki" already in database.
# ⏩ Ebook "Ashes of Retribution" already in database.
# ⏩ Ebook "Alien Evolution" already in database.
# ⏩ Ebook "Channeling the Womanizer's Lust" already in database.
# ⏩ Ebook "Stargazers" already in database.
# ⏩ Ebook "Rejected Royalty" already in database.
# ⏩ Ebook "Anders's Angel" already in database.
# ⏩ Ebook "The Scary Godmother" already in database.
# ⏩ Ebook "Gone Witch" already in database.
# ⏩ Ebook "The Dawn of the Iron Dragon" already in database.
# ⏩ Ebook "Obsession" already in database.
# ⏩ Ebook "An American Summer" already in database.
# ⏩ Ebook "Darkblade Outcast" already in database.
# ⏩ Ebook "Darkblade Assassin" already in database.
# ⏩ Ebook "Daisy Jones & The Six" already in database.
# ⏩ Ebook "Finding the Jewel" already in database.
# ⏩ Ebook "Cemetery Road" already in database.
# ⏩ Ebook "The Guilty" already in database.
# ⏩ Ebook "Fool's Quest" already in database.
# ⏩ Ebook "A Shout in the Ruins" already in database.
# ⏩ Ebook "The Lincoln Lawyer" already in database.
# ⏩ Ebook "Instinct" already in database.
# ⏩ Ebook "Winter Magic" already in database.
# ⏩ Ebook "Dragon's Echo" already in database.
# ⏩ Ebook "Goosebumps Most Wanted (10 Books) [Paperback] R.l Stine" already in database.
# ⏩ Ebook "Secret Justice" already in database.
# ⏩ Ebook "Raw Justice" already in database.
# ⏩ Ebook "I hope this reaches her in time/She Felt Like Feeling Nothing/I hope this reaches her too][3 Book Set by r. h. Sin]" already in database.
# ⏩ Ebook "Need to Know" already in database.
# ⏩ Ebook "A Citadel of Captives" already in database.
# ⏩ Ebook "The Deer Camp: A Memoir of a Father, a Family, and the Land that Healed Them" already in database.
# ⏩ Ebook "Guilty as Sin" already in database.
# ⏩ Ebook "Reveling in Sin" already in database.
# ⏩ Ebook "Throne of Fire" already in database.
# ⏩ Ebook "Lucky Witches" already in database.
# ⏩ Ebook "Graveyards, Visions, and Other Things that Byte" already in database.
# ⏩ Ebook "Mr Drake and My Lady Silver" already in database.
# ⏩ Ebook "A Court of Lies" already in database.
# ⏩ Ebook "Royalty and Ruin" already in database.
# ⏩ Ebook "Runes of Black Magic" already in database.
# ⏩ Ebook "Arrows of Ladis" already in database.
# ⏩ Ebook "Adler" already in database.
# ⏩ Ebook "Ballad of Blood" already in database.
# ⏩ Ebook "No Quarter" already in database.
# ⏩ Ebook "Breathe Again" already in database.
# ⏩ Ebook "Broken With You" already in database.
# ⏩ Ebook "The Rancher's Bargain" already in database.
# ⏩ Ebook "Rivaled Warrior" already in database.
# ⏩ Ebook "Shield Knight: Gavin's Tale" already in database.
# ⏩ Ebook "The Parisian" already in database.
# ⏩ Ebook "Hunted" already in database.
# ⏩ Ebook "Embodied" already in database.
# ⏩ Ebook "The Greek Claims His Shock Heir" already in database.
# ⏩ Ebook "Animal, Vegetable, Miracle: A Year of Food Life" already in database.
# ⏩ Ebook "Stalking Jack the Ripper" already in database.
# ⏩ Ebook "The Oracle Year" already in database.
# ⏩ Ebook "Venus and Adonis by William Shakespeare" already in database.
# ⏩ Ebook "Highlander's Fate" already in database.
# ⏩ Ebook "Chosen" already in database.
# ⏩ Ebook "Viking Legacy" already in database.
# ⏩ Ebook "Invading Alpha" already in database.
# ⏩ Ebook "August Moon: Humor and Hijinks" already in database.
# ⏩ Ebook "The Spaniard's Untouched Bride" already in database.
# ⏩ Ebook "The Lost Sisters" already in database.
# ⏩ Ebook "Hot Mess 6" already in database.
# ⏩ Ebook "Awake in Shadows" already in database.
# ⏩ Ebook "Divine Evil" already in database.
# ⏩ Ebook "Ruined With You" already in database.
# ⏩ Ebook "Darkblade Slayer" already in database.
# ⏩ Ebook "The Palace of Lost Memories" already in database.
# ⏩ Ebook "Hail to the King" already in database.
# ⏩ Ebook "Peace in the Valley" already in database.
# ⏩ Ebook "How Great Thou Art" already in database.
# ⏩ Ebook "The Avatar's Flames" already in database.
# ⏩ Ebook "Collide and Seek" already in database.
# ⏩ Ebook "Mysterious Ways" already in database.
# ⏩ Ebook "Dark Is The Night" already in database.
# ⏩ Ebook "Fairy Rings and Dragon Kings" already in database.
# ⏩ Ebook "Quintus" already in database.
# ⏩ Ebook "Siren Falling" already in database.
# ⏩ Ebook "A. I. Uprising" already in database.
# ⏩ Ebook "The Chain" already in database.
# ⏩ Ebook "Drums of Autumn" already in database.
# ⏩ Ebook "The Chef" already in database.
# ⏩ Ebook "Garrett" already in database.
# ⏩ Ebook "The Princess Must Die" already in database.
# ⏩ Ebook "Unmasked" already in database.
# ⏩ Ebook "All For You" already in database.
# ⏩ Ebook "The Lawman's Convenient Family" already in database.
# ⏩ Ebook "Monster" already in database.
# ⏩ Ebook "First Lessons" already in database.
# ⏩ Ebook "Seed: The Reaping Book One" already in database.
# ⏩ Ebook "The Price of Mason" already in database.
# ⏩ Ebook "Stopping Time" already in database.
# ⏩ Ebook "Legal Passion" already in database.
# ⏩ Ebook "An Assassin's Death" already in database.
# ⏩ Ebook "The Incubus Detective: Hell of a Ride" already in database.
# ⏩ Ebook "The Cowboy's Lesson in Love" already in database.
# ⏩ Ebook "The Trouble With Vampires" already in database.
# ⏩ Ebook "A Court of Blood and Void" already in database.
# ⏩ Ebook "The Complete Freak House Series" already in database.
# ⏩ Ebook "A Jungle of Rogues" already in database.
# ⏩ Ebook "Beren and Lúthien" already in database.
# ⏩ Ebook "Fool's Assassin" already in database.
# ⏩ Ebook "The Risk" already in database.
# ⏩ Ebook "Losing Anora" already in database.
# ⏩ Ebook "Dim Glows The Horizon" already in database.
# ⏩ Ebook "The Eleventh Hour" already in database.
# ⏩ Ebook "Shadow on the Water" already in database.
# ⏩ Ebook "Horseman" already in database.
# ⏩ Ebook "Blood Ring" already in database.
# ⏩ Ebook "Mage Fall" already in database.
# ⏩ Ebook "Legend Hunter" already in database.
# ⏩ Ebook "In the Nyx of Time" already in database.
# ⏩ Ebook "Gareth" already in database.
# ⏩ Ebook "DIVIDE: A Legends of Arestina Prequel Novella" already in database.
# ⏩ Ebook "Redemption" already in database.
# ⏩ Ebook "Love Spells Trouble" already in database.
# ⏩ Ebook "A Camp of Savages" already in database.
# ⏩ Ebook "A Jungle of Rogues" already in database.
# ⏩ Ebook "Alex's Quest" already in database.
# ⏩ Ebook "A Twist of Fate" already in database.
# ⏩ Ebook "Imprisoned" already in database.
# ⏩ Ebook "Viking's Valor" already in database.
# ⏩ Ebook "Music and Misadventure" already in database.
# ⏩ Ebook "The Devil to Pay" already in database.
# ⏩ Ebook "Zodiac Dragon Boxset: Books 1-9" already in database.
# ⏩ Ebook "Resurrection" already in database.
# ⏩ Ebook "Blackout" already in database.
# ⏩ Ebook "The Guest Book" already in database.
# ⏩ Ebook "Tangled Web" already in database.
# ⏩ Ebook "Blood Lust" already in database.
# ⏩ Ebook "A Ghostly Ride in Gulfport" already in database.
# ⏩ Ebook "Cursed" already in database.
# ⏩ Ebook "Queen of Ice" already in database.
# ⏩ Ebook "Dragon Crown" already in database.
# ⏩ Ebook "On Leopard Rock" already in database.
# ⏩ Ebook "Witcher Series 6 Books Set Collection" already in database.
# ⏩ Ebook "Annalise's Quest" already in database.
# ⏩ Ebook "A Reign of Thieves" already in database.
# ⏩ Ebook "Wicked Haunts" already in database.
# ⏩ Ebook "The Italian Demands His Heirs" already in database.
# ⏩ Ebook "A Passage of Time" already in database.
# ⏩ Ebook "Once More We Saw Stars: A Memoir" already in database.
# ⏩ Ebook "Blade Breaker" already in database.
# ⏩ Ebook "Bitcoin Billionaires: A True Story of Genius, Betrayal, and Redemption" already in database.
# ⏩ Ebook "Surrender" already in database.
# ⏩ Ebook "A Deal Made in Texas" already in database.
# ⏩ Ebook "The Oath Keeper" already in database.
# ⏩ Ebook "The Witch of Shadowmarsh" already in database.
# ⏩ Ebook "The Scribbly Man" already in database.
# ⏩ Ebook "Hateful Things" already in database.
# ⏩ Ebook "A Brightness Long Ago" already in database.
# ⏩ Ebook "Bound by the Sheik's Ring" already in database.
# ⏩ Ebook "The Witches of White Willow" already in database.
# ⏩ Ebook "Harley Merlin and the Mystery Twins" already in database.
# ⏩ Ebook "Witch's Shadow" already in database.
# ⏩ Ebook "Witch's Soul" already in database.
# ⏩ Ebook "Crew" already in database.
# ⏩ Ebook "The Venetian One-Night Baby" already in database.
# ⏩ Ebook "Dirty Sexy Player" already in database.
# ⏩ Ebook "Wizard Defender" already in database.
# ⏩ Ebook "Homecoming" already in database.
# ⏩ Ebook "The God is Not Willing" already in database.
# ⏩ Ebook "The Red-Stained Wings" already in database.
# ⏩ Ebook "Prince of Secrets and Shadows" already in database.
# ⏩ Ebook "Birds of a Feather" already in database.
# ⏩ Ebook "Stolen Wishes" already in database.
# ⏩ Ebook "A Nurse to Heal His Heart" already in database.
# ⏩ Ebook "Late Fees" already in database.
# ⏩ Ebook "Stone Heart" already in database.
# ⏩ Ebook "A Court of Fire and Metal" already in database.
# ⏩ Ebook "Shield Knight: Duel" already in database.
# ⏩ Ebook "Save Me the Plums: My Gourmet Memoir" already in database.
# ⏩ Ebook "On Deadline & Under Fire" already in database.
# ⏩ Ebook "Secret Millionaire for the Surrogate" already in database.
# ⏩ Ebook "Hired by the Mysterious Millionaire" already in database.
# ⏩ Ebook "The Baby They Longed For" already in database.
# ⏩ Ebook "Fate's Fools" already in database.
# ⏩ Ebook "Dark Water" already in database.
# ⏩ Ebook "Dragon Heartstring" already in database.
# ⏩ Ebook "Indecent" already in database.
# ⏩ Ebook "A Man Beyond the Law" already in database.
# ⏩ Ebook "The Complete Tempted Series" already in database.
# ⏩ Ebook "Soul of the Sword" already in database.
# ⏩ Ebook "A Shadow of Crows" already in database.
# ⏩ Ebook "Dark Arts and a Daiquiri" already in database.
# ⏩ Ebook "A Deadly Duet" already in database.
# ⏩ Ebook "A Wedding at the Italian's Demand" already in database.
# ⏩ Ebook "Blood Brothers" already in database.
# ⏩ Ebook "Jack of Spades" already in database.
# ⏩ Ebook "The Elfstones of Shannara" already in database.
# ⏩ Ebook "A Plague of Deceit" already in database.
# ⏩ Ebook "Claimed for the Billionaire's Convenience" already in database.
# ⏩ Ebook "Craving" already in database.
# ⏩ Ebook "Stone and Claw" already in database.
# ⏩ Ebook "Jack Addison vs. Man-Ravishing Spider" already in database.
# ⏩ Ebook "Bonded by Accident" already in database.
# ⏩ Ebook "Weight of the Crown" already in database.
# ⏩ Ebook "Dirty Rich Obsession: All Mine" already in database.
# ⏩ Ebook "Subversive Giants" already in database.
# ⏩ Ebook "Tinsel" already in database.
# ⏩ Ebook "A Curse Awakened" already in database.
# ⏩ Ebook "Vortex Visions" already in database.
# ⏩ Ebook "The Infernal Devices Series Collection" already in database.
# ⏩ Ebook "Kisses and Curses" already in database.
# ⏩ Ebook "The Echo of Broken Dreams" already in database.
# ⏩ Ebook "Unleashed" already in database.
# ⏩ Ebook "T-Bone" already in database.
# ⏩ Ebook "As You Witch" already in database.
# ⏩ Ebook "Feral Heart" already in database.
# ⏩ Ebook "The Shadow Collector" already in database.
# ⏩ Ebook "The Stiehl Assassin" already in database.
# ⏩ Ebook "A Warehouse, a Witch Doctor, and a Wedding" already in database.
# ⏩ Ebook "Upheaval" already in database.
# ⏩ Ebook "Ascend" already in database.
# ⏩ Ebook "The Hunter Brothers Box Set" already in database.
# ⏩ Ebook "Fractured Stars" already in database.
# ⏩ Ebook "Harley Merlin and the Stolen Magicals" already in database.
# ⏩ Ebook "Mr. November" already in database.
# ⏩ Ebook "Marked for Them" already in database.
# ⏩ Ebook "The Raven's Ballad" already in database.
# ⏩ Ebook "Roll the Bones: An Urban Fantasy Fae Romance" already in database.
# ⏩ Ebook "The Turn of the Key" already in database.
# ⏩ Ebook "Broken Throne" already in database.
# ⏩ Ebook "Lost Gate" already in database.
# ⏩ Ebook "The Gladiator's Downfall" already in database.
# ⏩ Ebook "Insurrection" already in database.
# ⏩ Ebook "13-Minute Murder: Dead Man Running / 113 Minutes / 13 Minute Murder" already in database.
# ⏩ Ebook "Lost and Found" already in database.
# ⏩ Ebook "Cari Mora" already in database.
# ⏩ Ebook "Migrations" already in database.
# ⏩ Ebook "Highland Queen" already in database.
# ⏩ Ebook "Their Unexpected Babies" already in database.
# ⏩ Ebook "Billion Dollar Wolves: The Complete Series" already in database.
# ⏩ Ebook "Shiver Me Witches" already in database.
# ⏩ Ebook "An Edge of Malice" already in database.
# ⏩ Ebook "Witches Just Want to Have Fun" already in database.
# ⏩ Ebook "A Little Siren" already in database.
# ⏩ Ebook "The Last Stone" already in database.
# ⏩ Ebook "Juntto" already in database.
# ⏩ Ebook "A Canyon Road Christmas" already in database.
# ⏩ Ebook "Releasing the Dragon" already in database.
# ⏩ Ebook "Sin & Chocolate" already in database.
# ⏩ Ebook "Riots I Have Known" already in database.
# ⏩ Ebook "Ghostly Holiday" already in database.
# ⏩ Ebook "Moscow Mule" already in database.
# ⏩ Ebook "A Job You Mostly Won't Know How to Do" already in database.
# ⏩ Ebook "Belle and the Pirate" already in database.
# ⏩ Ebook "The Beautiful" already in database.
# ⏩ Ebook "Memoirs of a Lagos Wedding Planner" already in database.
# ⏩ Ebook "Overworld Apocalypse" already in database.
# ⏩ Ebook "Pack's Promise" already in database.
# ⏩ Ebook "Recovering the Siren" already in database.
# ⏩ Ebook "The Quite Nice and Fairly Accurate Good Omens Script Book" already in database.
# ⏩ Ebook "Target: Alex Cross" already in database.
# ⏩ Ebook "Shadow and Flame" already in database.
# ⏩ Ebook "Under Currents" already in database.
# ⏩ Ebook "Unsolved" already in database.
# ⏩ Ebook "Untouched Until Her Ultra-Rich Husband" already in database.
# ⏩ Ebook "Legacy Awakened" already in database.
# ⏩ Ebook "Witch's Spirit" already in database.
# ⏩ Ebook "A Dome of Blood" already in database.
# ⏩ Ebook "Correspondents" already in database.
# ⏩ Ebook "Darkness Returns" already in database.
# ⏩ Ebook "The Sheikh Crowns His Virgin" already in database.
# ⏩ Ebook "Crucifix" already in database.
# ⏩ Ebook "Dragon Knight of Khoth" already in database.
# ⏩ Ebook "Broken Sorcery" already in database.
# ⏩ Ebook "Jackson" already in database.
# ⏩ Ebook "Mr. December" already in database.
# ⏩ Ebook "Highlander's Secret Nun" already in database.
# ⏩ Ebook "Sea Witch and the Magician" already in database.
# ⏩ Ebook "Cruel Fate" already in database.
# ⏩ Ebook "Fae on a Roll" already in database.
# ⏩ Ebook "Alpha Born" already in database.
# ⏩ Ebook "The Voyage of the Iron Dragon" already in database.
# ⏩ Ebook "Shock Heir for the King" already in database.
# ⏩ Ebook "Renegade" already in database.
# ⏩ Ebook "Brimstone Nightmares" already in database.
# ⏩ Ebook "Claiming His Christmas Wife" already in database.
# ⏩ Ebook "Storm a-Brewin'" already in database.
# ⏩ Ebook "Harley Merlin and the First Ritual" already in database.
# ⏩ Ebook "Savage Salvation" already in database.
# ⏩ Ebook "The Gate to Oblivion" already in database.
# ⏩ Ebook "The Dragon Sickness" already in database.
# ⏩ Ebook "All That Glitters" already in database.
# ⏩ Ebook "Bedlam" already in database.
# ⏩ Ebook "Viking's Intent" already in database.
# ⏩ Ebook "The Breadth of Creation" already in database.
# ⏩ Ebook "Cursed and Finding Honor: Twisted Eventide-8.5" already in database.
# ⏩ Ebook "Southern Magic Christmas" already in database.
# ⏩ Ebook "Lost Shadow" already in database.
# ⏩ Ebook "Archangel's War" already in database.
# ⏩ Ebook "The Ruthless" already in database.
# ⏩ Ebook "Seducing His Convenient Innocent" already in database.
# ⏩ Ebook "Demon Born" already in database.
# ⏩ Ebook "A Killer Retreat" already in database.
# ⏩ Ebook "The Darkest Revenge" already in database.
# ⏩ Ebook "Logan" already in database.
# ⏩ Ebook "Sharing a Mate" already in database.
# ⏩ Ebook "Yours to Command" already in database.
# ⏩ Ebook "Wedding Gems" already in database.
# ⏩ Ebook "Alpha's Bane" already in database.
# ⏩ Ebook "Dragon Astray" already in database.
# ⏩ Ebook "High Country Cowgirl" already in database.
# ⏩ Ebook "A Virgin to Redeem the Billionaire" already in database.
# ⏩ Ebook "A Nerdy Holiday" already in database.
# ⏩ Ebook "Prophet of the Badlands" already in database.
# ⏩ Ebook "Gemstones, Elves, and Other Insidious Magic" already in database.
# ⏩ Ebook "Goosebumps: Most Wanted: Dr Maniac Will" already in database.
# ⏩ Ebook "Texas Lily" already in database.
# ⏩ Ebook "Arsenic in the Azaleas" already in database.
# ⏩ Ebook "Secrets Among the Tides" already in database.
# ⏩ Ebook "The Obsidian Palace" already in database.
# ⏩ Ebook "Patrolling the Neighborhood" already in database.
# ⏩ Ebook "Reyes's Raina" already in database.
# ⏩ Ebook "A Tiger's Claim" already in database.
# ⏩ Ebook "A Shifter's Curse" already in database.
# ⏩ Ebook "Her Surprise Baby Christmas" already in database.
# ⏩ Ebook "Dezi's Diamond" already in database.
# ⏩ Ebook "Nelson" already in database.
# ⏩ Ebook "Acacia: Hidden Realms of Silver Lake" already in database.
# ⏩ Ebook "Lee" already in database.
# ⏩ Ebook "Kevin" already in database.
# ⏩ Ebook "A Shifter's Rage" already in database.
# ⏩ Ebook "Two Witches and a Whiskey" already in database.
# ⏩ Ebook "Guns and Graveyards" already in database.
# ⏩ Ebook "Run Free" already in database.
# ⏩ Ebook "Starsight" already in database.
# ⏩ Ebook "Supernova" already in database.
# ⏩ Ebook "A Purge of Nature" already in database.
# ⏩ Ebook "Apostle" already in database.
# ⏩ Ebook "Smokescreen" already in database.
# ⏩ Ebook "Beyond the Point" already in database.
# ⏩ Ebook "Striking Out" already in database.
# ⏩ Ebook "Determination: A Magi Saga Series" already in database.
# ⏩ Ebook "The 13th Month" already in database.
# ⏩ Ebook "Deep Beneath" already in database.
# ⏩ Ebook "A Layer of Ash" already in database.
# ⏩ Ebook "Highlander’s Dark Enemy" already in database.
# ⏩ Ebook "Echoes of a Fallen Kingdom" already in database.
# ⏩ Ebook "Divided Paths" already in database.
# ⏩ Ebook "Fracture" already in database.
# ⏩ Ebook "Ghostly Worries" already in database.
# ⏩ Ebook "Fixing Forever" already in database.
# ⏩ Ebook "Legend" already in database.
# ⏩ Ebook "Crop: The Reaping Book Two" already in database.
# ⏩ Ebook "By Sun" already in database.
# ⏩ Ebook "Hot Mess 7" already in database.
# ⏩ Ebook "The Orb of Kandra" already in database.
# ⏩ Ebook "A Sacred Pact" already in database.
# ⏩ Ebook "A Court of Ice and Wind" already in database.
# ⏩ Ebook "Sin & Magic" already in database.
# ⏩ Ebook "Harvest: The Reaping Book Three" already in database.
# ⏩ Ebook "A Heart So Fierce and Broken" already in database.
# ⏩ Ebook "A Fae's Honor" already in database.
# ⏩ Ebook "Greed" already in database.
# ⏩ Ebook "Harley Merlin and the Broken Spell" already in database.
# ⏩ Ebook "Dark Seduction" already in database.
# ⏩ Ebook "Crazy Wanda: An Angela Constantine Novella" already in database.
# ⏩ Ebook "Rekindled Magic" already in database.
# ⏩ Ebook "Beware the Darkness" already in database.
# ⏩ Ebook "A Passionate Night with the Greek" already in database.
# ⏩ Ebook "Secrets in Time" already in database.
# ⏩ Ebook "Confusing Hearts" already in database.
# ⏩ Ebook "Her Father’s Daughter" already in database.
# ⏩ Ebook "The Beekeeper of Aleppo" already in database.
# ⏩ Ebook "Atmosphere" already in database.
# ⏩ Ebook "Magic Bite" already in database.
# ⏩ Ebook "A Birth of Fire" already in database.
# ⏩ Ebook "A Cursed Moon" already in database.
# ⏩ Ebook "No Claim" already in database.
# ⏩ Ebook "Wicked Delight" already in database.
# ⏩ Ebook "Freaky Deaky Tiki" already in database.
# ⏩ Ebook "The Princess and the Peacock" already in database.
# ⏩ Ebook "Dirty Blood" already in database.
# ⏩ Ebook "A Shifter's Revenge" already in database.
# ⏩ Ebook "An Old-Fashioned Man" already in database.
# ⏩ Ebook "The Banker" already in database.
# ⏩ Ebook "The Dictator" already in database.
# ⏩ Ebook "Apocalyptic" already in database.
# ⏩ Ebook "Sweet Sorrow" already in database.
# ⏩ Ebook "Beguiling His Timid Waiter" already in database.
# ⏩ Ebook "A Very Hot Mess Christmas" already in database.
# ⏩ Ebook "Stephan" already in database.
# ⏩ Ebook "The Dragon Throne" already in database.
# ⏩ Ebook "Dark Illusion" already in database.
# ⏩ Ebook "Macabre Melody" already in database.
# ⏩ Ebook "Half-Demon's Revenge" already in database.
# ⏩ Ebook "The Apology" already in database.
# ⏩ Ebook "Prince of Persuasion" already in database.
# ⏩ Ebook "Guarding His Witness" already in database.
# ⏩ Ebook "The Cheater's Game" already in database.
# ⏩ Ebook "The Dark Side" already in database.
# ⏩ Ebook "A Breed of Elements" already in database.
# ⏩ Ebook "The Storm" already in database.
# ⏩ Ebook "The Unkindest Tide" already in database.
# ⏩ Ebook "Above the Fold & Below the Belt" already in database.
# ⏩ Ebook "Rebel Cell" already in database.
# ⏩ Ebook "Marty's Horrible, Terrible, Very Bad Day" already in database.
# ⏩ Ebook "Thrown to her Wolves" already in database.
# ⏩ Ebook "Bounty Hunters and Black Magic" already in database.
# ⏩ Ebook "So Very Unfae" already in database.
# ⏩ Ebook "Bought Bride for the Argentinian" already in database.
# ⏩ Ebook "Blaine" already in database.
# ⏩ Ebook "Ascension's Lure: Magical Realism Fantasy" already in database.
# ⏩ Ebook "Bones in the Begonias" already in database.
# ⏩ Ebook "The Burning Shadow" already in database.
# ⏩ Ebook "Rebel Writers: The Accidental Feminists: Shelagh Delaney • Edna O’Brien • Lynne Reid Banks • Charlotte Bingham • Nell Dunn • Virginia Ironside • Margaret Forster" already in database.
# ⏩ Ebook "The Rise of Magicks" already in database.
# ⏩ Ebook "Orphan Witch" already in database.
# ⏩ Ebook "Dead Jolly" already in database.
# ⏩ Ebook "Fool’s Paradise" already in database.
# ⏩ Ebook "Witches Brew" already in database.
# ⏩ Ebook "Hallow's Faire in Love and War" already in database.
# ⏩ Ebook "Whispers Beneath the Deep" already in database.
# ⏩ Ebook "Katie’s War" already in database.
# ⏩ Ebook "The Mercenary: A Warren Parish Story" already in database.
# ⏩ Ebook "The Tyrant" already in database.
# ⏩ Ebook "A Vampire's Tale" already in database.
# ⏩ Ebook "Sebastian" already in database.
# ⏩ Ebook "Shadow in the Ether" already in database.
# ⏩ Ebook "Dragon Spirit: Cry of Revenge: Morrigan's Prequel" already in database.
# ⏩ Ebook "On Her Own" already in database.
# ⏩ Ebook "Cold Waters" already in database.
# ⏩ Ebook "A Fall of Secrets" already in database.
# ⏩ Ebook "Magic Sight" already in database.
# ⏩ Ebook "A Trail of Echoes" already in database.
# ⏩ Ebook "Shadows Within the Flame" already in database.
# ⏩ Ebook "Baby Me" already in database.
# ⏩ Ebook "Viking Clan" already in database.
# ⏩ Ebook "Tri-Tip" already in database.
# ⏩ Ebook "Dagger in the Dahlias" already in database.
# ⏩ Ebook "Corpse in the Carnations" already in database.
# ⏩ Ebook "The Heartstone Thief" already in database.
# ⏩ Ebook "Demon Divine" already in database.
# ⏩ Ebook "Blood Moon Magic" already in database.
# ⏩ Ebook "Soul Laid Bare" already in database.
# ⏩ Ebook "Fallen Academy: Year Three and a Half" already in database.
# ⏩ Ebook "A Sacrifice of Flames" already in database.
# ⏩ Ebook "Instructing the Novice" already in database.
# ⏩ Ebook "Curse of the Troll" already in database.
# ⏩ Ebook "The Lost Vampire Prince" already in database.
# ⏩ Ebook "A Boat, a Banshee, and a Breakdown" already in database.
# ⏩ Ebook "Junkyard" already in database.
# ⏩ Ebook "The Vampire Villain" already in database.
# ⏩ Ebook "The Man Who Strikes Fear" already in database.
# ⏩ Ebook "The Empire" already in database.
# ⏩ Ebook "Special Witch of the FBI" already in database.
# ⏩ Ebook "A Place to Call Home" already in database.
# ⏩ Ebook "Sin & Salvation" already in database.
# ⏩ Ebook "The Book of Peril" already in database.
# ⏩ Ebook "Tenfold" already in database.
# ⏩ Ebook "The Sky People" already in database.
# ⏩ Ebook "Her Very Own Demon" already in database.
# ⏩ Ebook "It Ends Here" already in database.
# ⏩ Ebook "Southern Fortunes" already in database.
# ⏩ Ebook "Bastian" already in database.
# ⏩ Ebook "A Vampire's Bane" already in database.
# ⏩ Ebook "My Name is Alison" already in database.
# ⏩ Ebook "Watchers of the Gray Box Set: Books 1 - 3" already in database.
# ⏩ Ebook "Viking's Ransom" already in database.
# ⏩ Ebook "Earth Machines" already in database.
# ⏩ Ebook "The Hallowed Hunt" already in database.
# ⏩ Ebook "Don't Bait Me" already in database.
# ⏩ Ebook "Born in Fire" already in database.
# ⏩ Ebook "Baylahn" already in database.
# ⏩ Ebook "Gabriel" already in database.
# ⏩ Ebook "The Malveaux Curse Full Book Bundle" already in database.
# ⏩ Ebook "Witch's Secret" already in database.
# ⏩ Ebook "The Mercenary's Bounty" already in database.
# ⏩ Ebook "The Werewolf and the Siren" already in database.
# ⏩ Ebook "Maestro of Gold" already in database.
# ⏩ Ebook "Fallen" already in database.
# ⏩ Ebook "Sevenfold Sword: Maze" already in database.
# ⏩ Ebook "Harley Merlin and the Cult of Eris" already in database.
# ⏩ Ebook "Hotter Than Hades" already in database.
# ⏩ Ebook "A. I. Apocalypse" already in database.
# ⏩ Ebook "Enlightening the Lab Assistant" already in database.
# ⏩ Ebook "Tales of the Feisty Druid Omnibus (Books 1-7):" already in database.
# ⏩ Ebook "Shield Knight: Rhodruthain" already in database.
# ⏩ Ebook "Footprints in the Ferns" already in database.
# ⏩ Ebook "Evidence in the Echinacea" already in database.
# ⏩ Ebook "The Mister" already in database.
# ⏩ Ebook "Anthelion" already in database.
# ⏩ Ebook "Dragon Engaged" already in database.
# ⏩ Ebook "A Conspiracy of Realms" already in database.
# ⏩ Ebook "The Guardians" already in database.
# ⏩ Ebook "Forgotten" already in database.
# ⏩ Ebook "Ayil" already in database.
# ⏩ Ebook "A Passionate Reunion in Fiji" already in database.
# ⏩ Ebook "Blood of the Wolf" already in database.
# ⏩ Ebook "Alpha's Secret" already in database.
# ⏩ Ebook "Supernatural Academy: Year One" already in database.
# ⏩ Ebook "Assassin's Bond" already in database.
# ⏩ Ebook "Gone So Long" already in database.
# ⏩ Ebook "Religion as We Know It: An Origin Story" already in database.
# ⏩ Ebook "Awakened Love" already in database.
# ⏩ Ebook "Dragon Guard" already in database.
# ⏩ Ebook "Fate Abandoned" already in database.
# ⏩ Ebook "The Institute" already in database.
# ⏩ Ebook "The Rebellious Sister" already in database.
# ⏩ Ebook "Antibody" already in database.
# ⏩ Ebook "Ignite" already in database.
# ⏩ Ebook "Chosen Champion" already in database.
# ⏩ Ebook "Demon Magic and a Martini" already in database.
# ⏩ Ebook "Runes of Truth" already in database.
# ⏩ Ebook "The Sheikh's Secret Baby" already in database.
# ⏩ Ebook "Chase" already in database.
# ⏩ Ebook "A Search for Death" already in database.
# ⏩ Ebook "Azure Secrets" already in database.
# ⏩ Ebook "Shattered" already in database.
# ⏩ Ebook "Starting Over" already in database.
# ⏩ Ebook "The 19th Christmas" already in database.
# ⏩ Ebook "Remnants of the Lost" already in database.
# ⏩ Ebook "Wolf Love" already in database.
# ⏩ Ebook "Chains" already in database.
# ⏩ Ebook "Witch Blues" already in database.
# ⏩ Ebook "Curse of the Akkeri" already in database.
# ⏩ Ebook "The Scepter of Fire" already in database.
# ⏩ Ebook "Son of Chaos" already in database.
# ⏩ Ebook "Blue Moon" already in database.
# ⏩ Ebook "Sky Keeper" already in database.
# ⏩ Ebook "Time in the City" already in database.
# ⏩ Ebook "Librarian's Legend" already in database.
# ⏩ Ebook "Stained" already in database.
# ⏩ Ebook "Awakened by the Giant" already in database.
# ⏩ Ebook "Leopard's Wrath" already in database.
# ⏩ Ebook "Among Ash and Ember" already in database.
# ⏩ Ebook "Ghostly Ordeal" already in database.
# ⏩ Ebook "Oath of the Witch" already in database.
# ⏩ Ebook "Toric's Dagger" already in database.
# ⏩ Ebook "Broken" already in database.
# ⏩ Ebook "The Pearl Brooch" already in database.
# ⏩ Ebook "Alpha Challenge" already in database.
# ⏩ Ebook "Command the Moon" already in database.
# ⏩ Ebook "Awakened by the Scarred Italian" already in database.
# ⏩ Ebook "Unholy Ground" already in database.
# ⏩ Ebook "Unquiet Souls" already in database.
# ⏩ Ebook "One Good Deed" already in database.
# ⏩ Ebook "Annihilation" already in database.
# ⏩ Ebook "Caresses Between the Sand" already in database.
# ⏩ Ebook "A Conspiracy of Realms" already in database.
# ⏩ Ebook "The Warrior Race Trilogy Box Set" already in database.
# ⏩ Ebook "Chances Are..." already in database.
# ⏩ Ebook "After Darkness Falls" already in database.
# ⏩ Ebook "Love Heals" already in database.
# ⏩ Ebook "The Southern Book Club's Guide to Slaying Vampires" already in database.
# ⏩ Ebook "The Jalakh Bow" already in database.
# ⏩ Ebook "Fae's Captive" already in database.
# ⏩ Ebook "Road To Winter" already in database.
# ⏩ Ebook "There Will Be Blood" already in database.
# ⏩ Ebook "Bite of Winter" already in database.
# ⏩ Ebook "Harley Merlin and the Detector Fix" already in database.
# ⏩ Ebook "Abduction" already in database.
# ⏩ Ebook "Night Visions" already in database.
# ⏩ Ebook "Godspring" already in database.
# ⏩ Ebook "Blood of My Enemies" already in database.
# ⏩ Ebook "Assassin of Amethyst" already in database.
# ⏩ Ebook "A Turn of Pandemonium" already in database.
# ⏩ Ebook "Darkness Unleashed" already in database.
# ⏩ Ebook "The Brownstone Effect" already in database.
# ⏩ Ebook "Peace, Blood, and Understanding" already in database.
# ⏩ Ebook "Highlander's Burning Desire" already in database.
# ⏩ Ebook "A Study in Seduction" already in database.
# ⏩ Ebook "Extraterrestrial Civilizations" already in database.
# ⏩ Ebook "Framing of the Witch" already in database.
# ⏩ Ebook "Axeviathon: Son of Dragons" already in database.
# ⏩ Ebook "The Defiant Magician" already in database.
# ⏩ Ebook "Reign of Dragons" already in database.
# ⏩ Ebook "Cold Case of the Witch" already in database.
# ⏩ Ebook "Bare Fangs" already in database.
# ⏩ Ebook "Perception - Three Book Boxed Set" already in database.
# ⏩ Ebook "The Whisper of Silenced Voices" already in database.
# ⏩ Ebook "Sadistic Games 7 & 8" already in database.
# ⏩ Ebook "A Monster's Death" already in database.
# ⏩ Ebook "Dawn of Ash" already in database.
# ⏩ Ebook "Space Pirate Charlie" already in database.
# ⏩ Ebook "Night Justice" already in database.
# ⏩ Ebook "Merlin Redux" already in database.
# ⏩ Ebook "Through Glass: The Dark" already in database.
# ⏩ Ebook "Through Glass: The Rose" already in database.
# ⏩ Ebook "Fairy-Struck" already in database.
# ⏩ Ebook "Pixie-Led" already in database.
# ⏩ Ebook "Raven-Mocking" already in database.
# ⏩ Ebook "Here There be Dragons" already in database.
# ⏩ Ebook "Harvest of the Gods" already in database.
# ⏩ Ebook "Into the Void" already in database.
# ⏩ Ebook "Out of the Darkness" already in database.
# ⏩ Ebook "Tracing Thunder" already in database.
# ⏩ Ebook "A Symphony of Sirens" already in database.
# ⏩ Ebook "Eye of Re" already in database.
# ⏩ Ebook "Fairy Rings and Dragon Kings" already in database.
# ⏩ Ebook "Crown of Contempt" already in database.
# ⏩ Ebook "Porterhouse" already in database.
# Total books processed: 755
